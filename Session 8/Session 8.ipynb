# %% [markdown]
# # Sessions 8 and 9: Opinion Extraction

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li><span style="color:#8B0000">The first thing you need to do is run the following cell. This will give you access to the Sussex NLTK package.</span></li>
# </ul>
# </div>

# %%
import sys
sys.path.append(r'C:\Users\Oliver\Documents\LanguageEngineering')

# %% [markdown]
# In labs 8 and 9 you will be looking at ways to extract opinion bearing words from DVD Amazon reviews. The goal is to find words that describe particular aspects of the film being reviewed. The specific aspects of films that we will be considering are: the <b>plot</b>, the <b>characters</b>, the <b>cinematography</b> and the <b>dialogue</b>. We are, in other words, interested in finding all of those words in a review that express the reviewers opinion about one of these aspects of the film. The idea is that this will provide a fine-grained characterisation of the opinion being expressed by the author of the review. We will refer to the words we are looking for as <b>opinion words</b>, and refer to the words used for particular aspects of the review as <b>aspect words</b>.
#
# Following on from last week's session on dependency parsing, you will use the output of a dependency parser as the basis for identifying opinion words. This is based on the assumption that the opinion words we are looking for are words that occur in a sentence in the review in a particular (dependency) relationship to one of our aspect words (plot, characters, cinematography and dialogue).
#
# For example, the opinion word "amazing" might be found because it is used in a sentence where it is an adjective modifying the aspect word "plot", as in the sentence "I thought it had an amazing plot.".

# %% [markdown]
# ## Acquiring parsed sentences

# %% [markdown]
# As you may have noticed from the previous session, loading a dependency parser into memory is quite a slow task on the lab machines over the network. So we have pre-parsed a collection of relevant DVD sentences for you. The code snippet below shows you how to get access to the pre-parsed sentences.

# %%
from sussex_nltk.parse import load_parsed_dvd_sentences

aspect = "dialogue"  # Our aspect word
parsed_sentences = load_parsed_dvd_sentences(aspect)

# To inspect the sentences, you could print them straight out
for parsed_sentence in parsed_sentences:
    print "--- Sentence ---"
    print parsed_sentence
            
# parsed_sentences is a list of ParsedSentence objects, where each sentence
# contains the word "dialogue" and was found in a DVD review.
# Out:
# --- Sentence ---
# 1	The	DT	2	det
# 2	performances	NNS	4	nsubj
# 3	are	VBP	4	cop
# 4	thin	JJ	0	root
# 5	and	CC	4	cc
# 6	uneven	JJ	4	conj
# 7	,	,	4	punct
# 8	the	DT	9	det
# 9	plot	NN	11	nsubj
# 10	is	VBZ	11	cop
# 11	inconsistent	NN	4	conj
# 12	,	,	11	punct
# 13	and	CC	11	cc
# 14	the	DT	15	det
# 15	dialogue	NN	16	nsubj
# 16	sounds	VBZ	11	conj
# 17	like	IN	16	prep
# 18	it	PRP	17	pobj
# 19	was	VBD	20	auxpass
# 20	pulled	VBN	4	dep
# 21	from	IN	20	prep
# 22	fortune	NN	23	nn
# 23	cookies	NNS	21	pobj
# 24	made	VBN	23	partmod
# 25	by	IN	24	prep
# 26	the	DT	27	det
# 27	cast	JJ	25	pobj
# 28	of	IN	27	prep
# 29	Friends	NNPS	28	pobj
# 30	.	.	4	punct
# --- Sentence ---
# 1	Her	PRP$	2	poss
# 2	dialogue	NN	4	nsubjpass
# 3	is	VBZ	4	auxpass
# 4	kept	VBN	0	root
# 5	short	JJ	4	acomp
# 6	and	CC	5	cc
# 7	simple	JJ	5	conj
# 8	,	,	4	punct
# 9	and	CC	4	cc
# 10	when	WRB	13	advmod
# 11	she	PRP	13	nsubj
# 12	does	VBZ	13	aux
# 13	have	VB	33	advcl
# 14	more	JJR	15	mwe
# 15	than	IN	16	quantmod
# 16	3	CD	17	num
# 17	lines	NNS	13	dobj
# 18	at	IN	13	advmod
# 19	once	RB	18	advmod
# 20	,	,	33	punct
# 21	the	DT	23	det
# 22	complete	JJ	23	amod
# 23	lack	NN	33	nsubj
# 24	of	IN	23	prep
# 25	feeling	VBG	24	pcomp
# 26	,	,	25	punct
# 27	expression	NN	25	dobj
# 28	&	CC	27	cc
# 29	emotion	NN	27	conj
# 30	in	IN	25	prep
# 31	her	PRP$	32	poss
# 32	voice	NN	30	pobj
# 33	makes	VBZ	4	conj
# 34	you	PRP	36	nsubj
# 35	consider	JJR	36	aux
# 36	turning	VBG	33	ccomp
# 37	off	RP	36	prt
# 38	the	DT	39	det
# 39	movie	NN	36	dobj
# 40	and	CC	36	cc
# 41	doing	VBG	36	conj
# 42	something	NN	43	nn
# 43	worthwhile	NN	41	dobj
# 44	,	,	36	punct
# 45	like	IN	36	prep
# 46	cleaning	NN	45	pobj
# 47	out	IN	36	prep
# 48	the	DT	49	det
# 49	fridge	NN	47	pobj
# 50	or	CC	36	cc
# 51	picking	VBG	36	conj
# 52	at	IN	51	prep
# 53	your	PRP$	54	poss
# 54	hang-nails	NNS	52	pobj
# 55	.	.	4	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	3	nsubj
# 3	is	VBZ	0	root
# 4	at	IN	3	prep
# 5	a	DT	8	det
# 6	much	JJ	8	amod
# 7	lower	NN	8	nn
# 8	volume	NN	4	pobj
# 9	than	IN	8	prep
# 10	the	DT	11	det
# 11	music	NN	9	pobj
# 12	and	CC	3	cc
# 13	sound	VB	14	dep
# 14	effects	NNS	3	conj
# 15	,	,	3	punct
# 16	making	VBG	3	xcomp
# 17	it	PRP	20	nsubj
# 18	impossible	JJ	20	dep
# 19	to	TO	20	aux
# 20	view	VB	16	xcomp
# 21	without	IN	20	prep
# 22	constantly	RB	23	advmod
# 23	tinkering	VBG	21	pcomp
# 24	.	.	3	punct
# --- Sentence ---
# 1	Having	VBG	2	aux
# 2	mentioned	VBN	0	root
# 3	it	PRP	6	nsubj
# 4	's	VBZ	6	cop
# 5	good	JJ	6	amod
# 6	points	NNS	2	ccomp
# 7	I	PRP	8	nsubj
# 8	have	VBP	6	ccomp
# 9	to	TO	10	aux
# 10	say	VB	8	xcomp
# 11	I	PRP	14	nsubjpass
# 12	was	VBD	14	auxpass
# 13	enormously	RB	14	advmod
# 14	disappointed	VBN	10	ccomp
# 15	with	IN	14	prep
# 16	the	DT	17	det
# 17	dialogue	NN	15	pobj
# 18	and	CC	17	cc
# 19	some	DT	17	conj
# 20	of	IN	19	prep
# 21	the	DT	23	det
# 22	story	NN	23	nn
# 23	adaptation	NN	20	pobj
# 24	to	TO	25	aux
# 25	screen	VB	23	infmod
# 26	.	.	2	erased
# --- Sentence ---
# 1	For	IN	16	prep
# 2	the	DT	4	det
# 3	most	JJS	4	amod
# 4	part	NN	1	pobj
# 5	the	DT	7	det
# 6	bad	JJ	7	amod
# 7	dialogue	NN	4	dep
# 8	and	CC	7	cc
# 9	some	DT	7	conj
# 10	of	IN	9	prep
# 11	the	DT	13	det
# 12	terrible	JJ	13	amod
# 13	acting	NN	10	pobj
# 14	in	IN	4	prep
# 15	parts	NNS	14	pobj
# 16	were	VBD	0	root
# 17	just	RB	19	advmod
# 18	too	RB	19	advmod
# 19	painful	JJ	16	nsubj
# 20	to	TO	21	aux
# 21	sit	VB	19	infmod
# 22	through	IN	21	prt
# 23	.	.	16	punct
# --- Sentence ---
# 1	All	DT	3	predet
# 2	the	DT	3	det
# 3	characters	NNS	5	nsubj
# 4	were	VBD	5	cop
# 5	severely	RB	0	root
# 6	and	CC	5	cc
# 7	tragically	RB	8	advmod
# 8	2-dimensional	JJ	5	conj
# 9	with	IN	8	prep
# 10	none	NN	9	pobj
# 11	of	IN	10	prep
# 12	the	DT	13	det
# 13	depth	NN	11	pobj
# 14	you	PRP	15	nsubj
# 15	get	VBP	10	rcmod
# 16	from	IN	15	prep
# 17	reading	NN	16	pobj
# 18	the	DT	20	det
# 19	graphic	JJ	20	amod
# 20	novel	NN	16	tmod
# 21	and	CC	15	cc
# 22	very	RB	23	advmod
# 23	little	RB	24	amod
# 24	attention	NN	15	conj
# 25	was	VBD	26	auxpass
# 26	paid	VBN	5	dep
# 27	to	TO	26	prep
# 28	developing	VBG	27	pcomp
# 29	better	JJR	30	amod
# 30	dialogue	NN	28	dobj
# 31	suitable	JJ	30	amod
# 32	for	IN	30	prep
# 33	a	DT	36	det
# 34	big	JJ	36	amod
# 35	screen	NN	36	nn
# 36	experience	NN	32	pobj
# 37	.	.	5	punct
# --- Sentence ---
# 1	Purists	NNS	11	nsubj
# 2	and	CC	1	cc
# 3	rabid	VBD	1	conj
# 4	fans	NNS	3	dobj
# 5	of	IN	4	prep
# 6	the	DT	8	det
# 7	graphic	JJ	8	amod
# 8	novel	NN	5	pobj
# 9	may	MD	11	aux
# 10	be	VB	11	cop
# 11	capable	JJ	0	root
# 12	of	IN	11	prep
# 13	somehow	NN	14	nn
# 14	finding	NN	12	pobj
# 15	a	DT	16	det
# 16	way	NN	14	dep
# 17	to	TO	18	aux
# 18	look	VB	16	infmod
# 19	past	JJ	18	acomp
# 20	all	DT	26	det
# 21	the	DT	23	det
# 22	terrible	JJ	23	amod
# 23	acting	NN	26	nn
# 24	and	CC	23	cc
# 25	awful	JJ	23	conj
# 26	dialogue	NN	18	dobj
# 27	that	WDT	29	nsubj
# 28	is	VBZ	29	cop
# 29	rife	VBP	26	rcmod
# 30	throughout	IN	29	prep
# 31	the	DT	32	det
# 32	film	NN	30	pobj
# 33	.	.	11	punct
# --- Sentence ---
# 1	Some	DT	7	nsubjpass
# 2	of	IN	1	prep
# 3	my	PRP$	5	poss
# 4	favorite	JJ	5	amod
# 5	actors	NNS	2	pobj
# 6	are	VBP	7	auxpass
# 7	wasted	VBN	21	ccomp
# 8	,	,	21	punct
# 9	either	DT	21	nsubj
# 10	by	IN	9	prep
# 11	being	VBG	12	auxpass
# 12	given	VBN	10	pcomp
# 13	cliched	JJ	14	amod
# 14	dialogue	NN	12	dobj
# 15	,	,	21	punct
# 16	over	IN	21	prep
# 17	acting	JJ	16	pobj
# 18	,	,	21	punct
# 19	or	CC	21	cc
# 20	being	VBG	21	auxpass
# 21	put	VBN	0	root
# 22	there	EX	21	dobj
# 23	merely	RB	21	advmod
# 24	for	IN	21	prep
# 25	their	PRP$	27	poss
# 26	brand	NN	27	nn
# 27	name	NN	24	pobj
# 28	with	IN	21	prep
# 29	no	DT	30	det
# 30	script	NN	28	pobj
# 31	to	TO	32	aux
# 32	support	VB	21	xcomp
# 33	their	PRP$	34	poss
# 34	presence	NN	32	dobj
# 35	.	.	21	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	resolution	NN	5	nsubj
# 3	is	VBZ	5	cop
# 4	an	DT	5	det
# 5	afterthought	NN	0	root
# 6	(	:	5	punct
# 7	a	DT	9	det
# 8	quick	NN	9	nn
# 9	fix	NN	5	dep
# 10	in	IN	9	prep
# 11	the	DT	12	det
# 12	extreme	NN	10	pobj
# 13	)	:	5	punct
# 14	,	,	5	punct
# 15	and	CC	5	cc
# 16	barely	RB	18	advmod
# 17	even	RB	18	advmod
# 18	mentioned	VBN	5	conj
# 19	in	IN	18	prep
# 20	about	IN	22	amod
# 21	two	CD	22	num
# 22	lines	NNS	19	pobj
# 23	of	IN	22	prep
# 24	dialogue	NN	23	pobj
# 25	after	IN	18	prep
# 26	the	DT	28	det
# 27	artificial	JJ	28	amod
# 28	danger	NN	25	pobj
# 29	is	VBZ	33	aux
# 30	(	:	33	punct
# 31	narrowly	RB	33	advmod
# 32	,	,	33	punct
# 33	whew	VB	5	dep
# 34	!	.	5	punct
# --- Sentence ---
# 1	Not	RB	2	neg
# 2	only	RB	5	preconj
# 3	was	VBD	5	cop
# 4	the	DT	5	det
# 5	dialogue	NN	25	nsubj
# 6	of	IN	5	prep
# 7	the	DT	9	det
# 8	film	NN	9	nn
# 9	trite	NN	6	pobj
# 10	and	CC	9	cc
# 11	the	DT	12	det
# 12	plot	NN	9	conj
# 13	much	RB	14	advmod
# 14	like	IN	5	prep
# 15	a	DT	16	det
# 16	pornographic	JJ	14	pobj
# 17	after	IN	5	prep
# 18	school	NN	17	pcomp
# 19	special	JJ	18	dobj
# 20	,	,	5	punct
# 21	but	CC	5	cc
# 22	the	DT	23	det
# 23	movie	NN	5	conj
# 24	unfortunately	RB	25	advmod
# 25	reinforces	VBZ	0	root
# 26	a	DT	27	det
# 27	worldview	NN	25	dobj
# 28	which	WDT	31	dobj
# 29	anti-homosexual	JJ	30	amod
# 30	groups	NNS	31	nsubj
# 31	been	VBN	27	rcmod
# 32	touting	VBG	31	xcomp
# 33	for	IN	32	prep
# 34	years	NNS	33	pobj
# 35	--	:	25	punct
# 36	If	IN	39	mark
# 37	you	PRP	39	nsubj
# 38	're	VBP	39	aux
# 39	thinking	VBG	48	advcl
# 40	turning	VBG	39	conj
# 41	your	PRP$	43	poss
# 42	female	JJ	43	amod
# 43	frienship	NN	40	dobj
# 44	into	IN	40	prep
# 45	a	DT	46	det
# 46	relationship	NN	44	pobj
# 47	,	,	48	punct
# 48	do	VBP	25	parataxis
# 49	n't	RB	48	neg
# 50	.	.	25	punct
# --- Sentence ---
# 1	Loud	NNP	2	nn
# 2	popping	NN	3	nsubj
# 3	sounds	VBZ	0	root
# 4	completely	RB	5	advmod
# 5	cover	RB	3	advmod
# 6	up	IN	3	prep
# 7	the	DT	8	det
# 8	dialogue	NN	6	pobj
# 9	in	IN	8	prep
# 10	an	DT	12	det
# 11	entire	JJ	12	amod
# 12	scene	NN	9	pobj
# 13	.	.	3	punct
# --- Sentence ---
# 1	Some	DT	7	nsubjpass
# 2	of	IN	1	prep
# 3	my	PRP$	5	poss
# 4	favorite	JJ	5	amod
# 5	actors	NNS	2	pobj
# 6	are	VBP	7	auxpass
# 7	wasted	VBN	21	ccomp
# 8	,	,	21	punct
# 9	either	DT	21	nsubj
# 10	by	IN	9	prep
# 11	being	VBG	12	auxpass
# 12	given	VBN	10	pcomp
# 13	cliched	JJ	14	amod
# 14	dialogue	NN	12	dobj
# 15	,	,	21	punct
# 16	over	IN	21	prep
# 17	acting	JJ	16	pobj
# 18	,	,	21	punct
# 19	or	CC	21	cc
# 20	being	VBG	21	auxpass
# 21	put	VBN	0	root
# 22	there	EX	21	dobj
# 23	merely	RB	21	advmod
# 24	for	IN	21	prep
# 25	their	PRP$	27	poss
# 26	brand	NN	27	nn
# 27	name	NN	24	pobj
# 28	with	IN	21	prep
# 29	no	DT	30	det
# 30	script	NN	28	pobj
# 31	to	TO	32	aux
# 32	support	VB	21	xcomp
# 33	their	PRP$	34	poss
# 34	presence	NN	32	dobj
# 35	.	.	21	punct
# --- Sentence ---
# 1	It	PRP	6	nsubj
# 2	is	VBZ	6	cop
# 3	a	DT	6	det
# 4	very	RB	5	advmod
# 5	dialogue-heavy	JJ	6	amod
# 6	film	NN	0	root
# 7	and	CC	6	cc
# 8	the	DT	9	det
# 9	dialogue	NN	12	nsubj
# 10	is	VBZ	12	cop
# 11	not	RB	12	neg
# 12	well-written	JJ	6	conj
# 13	enough	RB	12	advmod
# 14	to	TO	15	aux
# 15	carry	VB	12	xcomp
# 16	it	PRP	15	dobj
# 17	off	IN	15	prt
# 18	.	.	6	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	4	nsubjpass
# 3	seems	VBZ	4	auxpass
# 4	forced	VBN	0	root
# 5	,	,	4	punct
# 6	funnier	RB	4	advmod
# 7	on	IN	4	prep
# 8	the	DT	9	det
# 9	script	NN	7	pobj
# 10	than	IN	9	prep
# 11	on	IN	10	pcomp
# 12	the	DT	13	det
# 13	screen	NN	11	pobj
# 14	and	CC	9	cc
# 15	most	JJS	16	amod
# 16	scenes	NNS	9	conj
# 17	feel	VBP	18	auxpass
# 18	posed	VBN	4	dep
# 19	and	CC	18	cc
# 20	sterile	JJ	18	conj
# 21	.	.	4	punct
# --- Sentence ---
# 1	Their	PRP$	2	poss
# 2	scenes	NNS	7	nsubj
# 3	and	CC	2	cc
# 4	dialogue	NN	2	conj
# 5	were	VBD	7	cop
# 6	so	RB	7	advmod
# 7	horrible	JJ	0	root
# 8	that	IN	14	complm
# 9	fast	JJ	10	amod
# 10	forward	NN	14	nsubj
# 11	was	VBD	14	cop
# 12	the	DT	14	det
# 13	only	JJ	14	amod
# 14	way	NN	7	ccomp
# 15	to	TO	16	aux
# 16	get	VB	14	infmod
# 17	through	IN	16	prep
# 18	the	DT	19	det
# 19	movie	NN	17	pobj
# 20	.	.	7	punct
# --- Sentence ---
# 1	Besides	IN	7	advmod
# 2	,	,	7	punct
# 3	this	DT	7	nsubj
# 4	is	VBZ	7	cop
# 5	not	RB	7	neg
# 6	the	DT	7	det
# 7	kind	NN	0	root
# 8	of	IN	7	prep
# 9	movie	NN	8	pobj
# 10	that	IN	13	complm
# 11	you	PRP	13	nsubj
# 12	really	RB	13	advmod
# 13	need	VBP	7	ccomp
# 14	their	PRP$	15	poss
# 15	dialogue	NN	13	dobj
# 16	to	TO	17	aux
# 17	understand	VB	13	xcomp
# 18	or	CC	17	cc
# 19	enjoy	VB	17	conj
# 20	it	PRP	19	dobj
# 21	.	.	7	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	sound	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	murky	JJ	0	root
# 5	and	CC	4	cc
# 6	undecipherable	JJ	4	conj
# 7	,	,	4	punct
# 8	the	DT	9	det
# 9	acting	JJ	13	nsubj
# 10	is	VBZ	13	cop
# 11	strictly	RB	13	advmod
# 12	amateur	JJ	13	amod
# 13	hour	NN	4	ccomp
# 14	,	,	4	punct
# 15	the	DT	16	det
# 16	characters	NNS	18	nsubj
# 17	are	VBP	18	cop
# 18	paper-thin	JJ	4	ccomp
# 19	with	IN	18	prep
# 20	no	DT	21	det
# 21	distinction	NN	19	pobj
# 22	or	CC	21	cc
# 23	purpose	NN	21	conj
# 24	,	,	4	punct
# 25	the	DT	26	det
# 26	story	NN	28	nsubj
# 27	is	VBZ	28	cop
# 28	non-existent	JJ	4	ccomp
# 29	,	,	4	punct
# 30	the	DT	31	det
# 31	dialogue	NN	35	nsubj
# 32	is	VBZ	35	cop
# 33	a	DT	35	det
# 34	completely	RB	35	advmod
# 35	worthless	NN	4	ccomp
# 36	bore	IN	35	advmod
# 37	,	,	4	punct
# 38	there	EX	39	expl
# 39	's	VBZ	4	ccomp
# 40	nothing	NN	39	nsubj
# 41	remotely	RB	42	advmod
# 42	scary	JJ	40	amod
# 43	,	,	4	punct
# 44	and	CC	4	cc
# 45	the	DT	47	det
# 46	special	JJ	47	amod
# 47	effects	NNS	60	nsubjpass
# 48	(	:	49	punct
# 49	including	VBG	47	dep
# 50	a	DT	51	det
# 51	couple	NN	49	pobj
# 52	of	IN	51	prep
# 53	computer	NN	54	nn
# 54	effects	NNS	52	pobj
# 55	that	WDT	56	nsubj
# 56	look	NN	54	rcmod
# 57	like	IN	56	prep
# 58	they	PRP	57	pobj
# 59	were	VBD	60	auxpass
# 60	made	VBN	4	conj
# 61	on	IN	60	prep
# 62	a	DT	67	det
# 63	Commodore	NNP	67	nsubj
# 64	64	CD	63	num
# 65	)	CD	63	num
# 66	are	VBP	67	cop
# 67	laughable	JJ	61	pobj
# 68	.	.	4	punct
# --- Sentence ---
# 1	Throw	NNP	11	nsubj
# 2	in	IN	1	prep
# 3	lots	NNS	2	pobj
# 4	of	IN	3	prep
# 5	tortured	VBN	6	amod
# 6	dialogue	NN	4	pobj
# 7	about	IN	6	prep
# 8	alternative	JJ	10	amod
# 9	consciousnesses/universes/fuel	NN	10	nn
# 10	supplies/sugar	NN	7	pobj
# 11	substitutes	VBZ	0	root
# 12	.	.	11	punct
# --- Sentence ---
# 1	Make	NNP	2	nn
# 2	sure	NN	6	nn
# 3	all	DT	6	predet
# 4	the	DT	6	det
# 5	bad	JJ	6	amod
# 6	guys	NNS	7	nsubj
# 7	bite	VBP	0	root
# 8	off	RP	7	prt
# 9	their	PRP$	10	poss
# 10	dialogue	NN	7	dobj
# 11	and	CC	7	cc
# 12	sound	VB	7	conj
# 13	mean	JJ	12	acomp
# 14	.	.	7	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	difficult	JJ	0	root
# 5	to	TO	6	aux
# 6	follow	VB	4	xcomp
# 7	especially	RB	8	advmod
# 8	since	IN	6	prep
# 9	most	JJS	8	pobj
# 10	of	IN	9	prep
# 11	it	PRP	10	pobj
# 12	is	VBZ	14	cop
# 13	meaningless	NN	14	nn
# 14	anyway	NN	4	dep
# 15	,	,	14	punct
# 16	and	CC	14	cc
# 17	the	DT	18	det
# 18	film	NN	14	conj
# 19	never	RB	14	neg
# 20	really	RB	21	advmod
# 21	follows	VBZ	4	dep
# 22	it	PRP	24	nsubj
# 23	's	VBZ	24	cop
# 24	premise	NN	21	ccomp
# 25	as	IN	24	prep
# 26	much	JJ	25	pobj
# 27	as	IN	29	mark
# 28	it	PRP	29	nsubj
# 29	should	MD	26	dep
# 30	:	:	24	punct
# 31	the	DT	32	det
# 32	rise	NN	24	dep
# 33	of	IN	32	prep
# 34	Factory	NNP	33	pobj
# 35	.	.	4	punct
# --- Sentence ---
# 1	Characters	NNS	4	nsubjpass
# 2	are	VBP	4	auxpass
# 3	marginally	RB	4	advmod
# 4	defined	VBN	0	root
# 5	and	CC	4	cc
# 6	the	DT	8	det
# 7	dialogue	NN	8	nn
# 8	wavers	NNS	12	nsubj
# 9	between	IN	8	prep
# 10	witty	NN	9	pobj
# 11	to	TO	12	aux
# 12	irrelevant	VB	4	conj
# 13	or	CC	14	cc
# 14	inexpressive	JJ	12	dep
# 15	.	.	4	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	6	nsubj
# 3	is	VBZ	6	cop
# 4	completely	RB	5	advmod
# 5	unbelievable	JJ	6	amod
# 6	considering	NN	0	root
# 7	the	DT	8	det
# 8	age	NN	6	dep
# 9	of	IN	8	prep
# 10	these	DT	11	det
# 11	kids	NNS	9	pobj
# 12	.	.	6	punct
# --- Sentence ---
# 1	The	DT	3	det
# 2	production	NN	3	nn
# 3	design	NN	7	nsubj
# 4	and	CC	3	cc
# 5	cinematopraphy	NN	3	conj
# 6	are	VBP	7	cop
# 7	sumptuos	NNS	0	root
# 8	,	,	7	punct
# 9	but	CC	7	cc
# 10	the	DT	11	det
# 11	script	NN	7	conj
# 12	and	CC	7	cc
# 13	dialogue	NN	7	conj
# 14	are	VBP	16	cop
# 15	so	RB	16	advmod
# 16	banal	JJ	7	dep
# 17	,	,	7	punct
# 18	the	DT	20	det
# 19	fine	NN	20	nn
# 20	cast	NN	7	appos
# 21	delivering	VBG	20	partmod
# 22	one	CD	24	num
# 23	empty	NN	24	nn
# 24	performance	NN	21	dobj
# 25	after	IN	26	mark
# 26	another	DT	20	dep
# 27	.	.	7	punct
# --- Sentence ---
# 1	``	``	0	root
# 2	mostly	RB	3	advmod
# 3	for	IN	0	root
# 4	the	DT	6	det
# 5	engaging	JJ	6	amod
# 6	snippets	NNS	3	pobj
# 7	of	IN	6	prep
# 8	dialogue	NN	7	pobj
# 9	from	IN	8	prep
# 10	scientists	NNS	9	pobj
# 11	,	,	10	punct
# 12	theologians	NNS	10	conj
# 13	,	,	3	punct
# 14	and	CC	3	cc
# 15	mystics	NNS	3	conj
# 16	.	.	3	erased
# --- Sentence ---
# 1	I	PRP	2	nsubj
# 2	understood	VBD	0	root
# 3	the	DT	4	det
# 4	plot	NN	2	dobj
# 5	,	,	2	punct
# 6	and	CC	2	cc
# 7	enjoyed	VBD	2	conj
# 8	some	DT	7	dobj
# 9	of	IN	8	prep
# 10	the	DT	11	det
# 11	thoughts	NNS	9	pobj
# 12	raised	VBD	2	dep
# 13	near	IN	12	prep
# 14	the	DT	15	det
# 15	end	NN	13	pobj
# 16	,	,	2	punct
# 17	but	CC	2	cc
# 18	overall	JJ	20	nsubjpass
# 19	was	VBD	20	auxpass
# 20	bored	VBN	2	conj
# 21	silly	RB	20	advmod
# 22	by	IN	20	prep
# 23	stilted	VBN	22	pobj
# 24	,	,	20	punct
# 25	pointless	NN	26	nn
# 26	dialogue	NN	20	dobj
# 27	.	.	2	punct
# --- Sentence ---
# 1	While	IN	9	mark
# 2	Baldwin	NNP	9	nsubj
# 3	and	CC	2	cc
# 4	the	DT	5	det
# 5	rest	NN	2	conj
# 6	of	IN	5	prep
# 7	the	DT	8	det
# 8	cast	JJ	6	pobj
# 9	did	VBD	26	advcl
# 10	well	RB	9	advmod
# 11	in	IN	9	prep
# 12	fleshing	NN	11	pobj
# 13	out	IN	9	prep
# 14	Burke	NNP	16	poss
# 15	's	POS	14	possessive
# 16	characters	NNS	13	pobj
# 17	and	CC	9	cc
# 18	have	VBP	9	conj
# 19	some	DT	22	det
# 20	tangy	NN	22	nn
# 21	tough-guy/gal	JJ	22	amod
# 22	dialogue	NN	18	dobj
# 23	,	,	26	punct
# 24	they	PRP	26	nsubjpass
# 25	're	VBP	26	auxpass
# 26	hampered	VBN	0	root
# 27	by	IN	26	prep
# 28	two	CD	29	num
# 29	things	NNS	27	pobj
# 30	:	:	26	punct
# 31	1	LS	0	root
# 32	.	.	31	erased
# --- Sentence ---
# 1	Despite	IN	4	prep
# 2	the	DT	3	det
# 3	sexy	NN	1	pobj
# 4	promises	VBZ	0	root
# 5	in	IN	4	prep
# 6	the	DT	7	det
# 7	movie	NN	9	poss
# 8	's	POS	7	possessive
# 9	ads	NNS	5	pobj
# 10	,	,	4	punct
# 11	none	NN	4	nsubj
# 12	of	IN	11	prep
# 13	the	DT	16	det
# 14	ladies	NNS	15	nn
# 15	share	NN	16	nn
# 16	anything	NN	12	pobj
# 17	with	IN	16	prep
# 18	Baldwin	NNP	17	pobj
# 19	but	CC	16	cc
# 20	dialogue	NN	16	conj
# 21	and	CC	16	cc
# 22	some	DT	23	det
# 23	kisses	NNS	16	conj
# 24	and/or	JJ	25	amod
# 25	embraces	NNS	16	rcmod
# 26	.	.	4	punct
# --- Sentence ---
# 1	The	DT	4	det
# 2	English	JJ	4	amod
# 3	voice	NN	4	nn
# 4	acting	NN	7	nsubj
# 5	is	VBZ	7	cop
# 6	embarassingly	RB	7	advmod
# 7	bad	JJ	0	root
# 8	,	,	7	punct
# 9	especially	RB	12	advmod
# 10	the	DT	12	det
# 11	main	JJ	12	amod
# 12	character	NN	7	ccomp
# 13	,	,	7	punct
# 14	but	CC	7	cc
# 15	not	RB	17	neg
# 16	as	IN	17	dep
# 17	bad	JJ	7	conj
# 18	as	IN	7	prep
# 19	the	DT	20	det
# 20	dialogue	NN	18	pobj
# 21	,	,	20	punct
# 22	internal	JJ	20	amod
# 23	and	CC	22	cc
# 24	vocalized	JJ	22	conj
# 25	,	,	7	punct
# 26	that	IN	31	complm
# 27	this	DT	28	det
# 28	character	NN	31	nsubjpass
# 29	has	VBZ	31	aux
# 30	been	VBN	31	auxpass
# 31	given	VBN	7	ccomp
# 32	to	TO	33	aux
# 33	speak	VB	31	xcomp
# 34	.	.	7	punct
# --- Sentence ---
# 1	The	DT	3	det
# 2	sight	NN	3	nn
# 3	gags	NNS	5	nsubj
# 4	are	VBP	5	cop
# 5	plentiful	JJ	0	root
# 6	,	,	5	punct
# 7	the	DT	10	det
# 8	physical	JJ	9	amod
# 9	comedy	NN	10	nn
# 10	abundant	NN	5	conj
# 11	and	CC	5	cc
# 12	often	RB	13	advmod
# 13	cruel	NN	5	conj
# 14	,	,	5	punct
# 15	and	CC	5	cc
# 16	the	DT	17	det
# 17	dialogue	NN	19	nsubj
# 18	absurdly	RB	19	advmod
# 19	unrealistic	JJ	5	conj
# 20	.	.	5	punct
# --- Sentence ---
# 1	This	DT	2	det
# 2	movie	NN	3	nsubj
# 3	tries	VBZ	0	root
# 4	to	TO	5	aux
# 5	deal	VB	3	xcomp
# 6	with	IN	5	prep
# 7	alot	NN	6	pobj
# 8	and	CC	3	cc
# 9	does	VBZ	3	conj
# 10	alot	NN	9	dobj
# 11	of	IN	10	prep
# 12	it	PRP	11	pobj
# 13	well	RB	9	dep
# 14	BUT	CC	13	cc
# 15	as	IN	13	conj
# 16	a	DT	17	det
# 17	viewer	NN	15	pobj
# 18	,	,	3	punct
# 19	I	PRP	22	nsubjpass
# 20	am	VBP	22	auxpass
# 21	hugely	RB	22	advmod
# 22	distracted	VBN	3	ccomp
# 23	by	IN	22	prep
# 24	Mamet	NNP	26	poss
# 25	's	POS	24	possessive
# 26	dialogue	NN	23	pobj
# 27	.	.	3	punct
# --- Sentence ---
# 1	Good	NNP	2	nn
# 2	dialogue	NN	3	nsubj
# 3	is	VBZ	0	root
# 4	like	IN	3	prep
# 5	good	JJ	6	amod
# 6	acting	NN	4	pobj
# 7	:	:	3	punct
# 8	if	IN	12	mark
# 9	it	PRP	12	nsubj
# 10	's	VBZ	12	cop
# 11	really	RB	12	advmod
# 12	good	JJ	17	advcl
# 13	,	,	17	punct
# 14	you	PRP	17	nsubj
# 15	do	VBP	17	aux
# 16	n't	RB	17	neg
# 17	notice	VB	3	parataxis
# 18	it	PRP	17	dobj
# 19	until	IN	23	mark
# 20	the	DT	21	det
# 21	show	NN	23	poss
# 22	's	POS	21	possessive
# 23	over	IN	17	advcl
# 24	.	.	3	punct
# --- Sentence ---
# 1	Anachronism	NNP	0	root
# 2	,	,	1	punct
# 3	bad	JJ	4	amod
# 4	dialogue	NN	1	appos
# 5	,	,	1	punct
# 6	bad	JJ	7	amod
# 7	plot	NN	1	appos
# 8	and	CC	7	cc
# 9	plain	NN	13	nn
# 10	old	JJ	13	amod
# 11	bad	JJ	13	amod
# 12	acting	NN	13	nn
# 13	plague	NN	7	conj
# 14	this	DT	16	det
# 15	``	``	16	punct
# 16	sequel	NN	1	dep
# 17	``	``	16	punct
# 18	.	.	1	punct
# --- Sentence ---
# 1	The	DT	5	det
# 2	plot	NN	5	nn
# 3	and	CC	2	cc
# 4	dialogue	NN	2	conj
# 5	dehumanizies	NNS	8	nsubj
# 6	and	CC	5	cc
# 7	insults	NNS	5	conj
# 8	many	JJ	0	root
# 9	.	.	8	punct
# --- Sentence ---
# 1	so	IN	4	mark
# 2	I	PRP	4	nsubjpass
# 3	'm	VBP	4	auxpass
# 4	supposed	VBN	28	advcl
# 5	to	TO	6	aux
# 6	believe	VB	4	xcomp
# 7	that	IN	18	complm
# 8	the	DT	10	det
# 9	horrible	JJ	10	amod
# 10	dialogue	NN	18	nsubj
# 11	,	,	10	punct
# 12	bad	JJ	13	amod
# 13	acting	NN	10	conj
# 14	,	,	10	punct
# 15	and	CC	10	cc
# 16	ridiculous	JJ	17	amod
# 17	plotting	NN	10	conj
# 18	is	VBZ	6	ccomp
# 19	on	IN	18	prep
# 20	purpose	NN	19	pobj
# 21	just	RB	27	advmod
# 22	because	IN	27	dep
# 23	Mamet	NNP	27	nsubj
# 24	is	VBZ	27	cop
# 25	a	DT	27	det
# 26	respected	VBN	27	amod
# 27	guy	NN	18	nsubj
# 28	?	.	0	root
# --- Sentence ---
# 1	``	``	9	punct
# 2	The	DT	3	det
# 3	dialogue	NN	9	nsubj
# 4	would	MD	9	aux
# 5	have	VB	9	aux
# 6	been	VBN	9	cop
# 7	1000	CD	8	number
# 8	times	NNS	9	num
# 9	better	JJR	0	root
# 10	.	.	9	punct
# --- Sentence ---
# 1	My	PRP$	3	poss
# 2	real	JJ	3	amod
# 3	gripe	NN	9	nsubj
# 4	about	IN	3	prep
# 5	the	DT	6	det
# 6	movie	NN	4	pobj
# 7	was	VBD	9	cop
# 8	the	DT	9	det
# 9	dialogue	NN	0	root
# 10	and	CC	9	cc
# 11	the	DT	12	det
# 12	acting	JJ	9	conj
# 13	.	.	9	punct
# --- Sentence ---
# 1	They	PRP	4	nsubj
# 2	were	VBD	4	cop
# 3	not	RB	4	neg
# 4	believable	JJ	0	root
# 5	and	CC	4	cc
# 6	the	DT	7	det
# 7	dialogue	NN	9	nsubj
# 8	just	RB	9	advmod
# 9	sounded	VBD	4	conj
# 10	like	IN	9	prep
# 11	something	NN	10	pobj
# 12	that	IN	20	complm
# 13	came	NN	20	nsubj
# 14	out	IN	13	prep
# 15	of	IN	14	pcomp
# 16	book	NN	15	pobj
# 17	for	IN	16	prep
# 18	young	JJ	19	amod
# 19	readers	NNS	17	pobj
# 20	.	.	11	ccomp
# --- Sentence ---
# 1	It	PRP	4	nsubj
# 2	's	VBZ	4	cop
# 3	the	DT	4	det
# 4	way	NN	0	root
# 5	the	DT	6	det
# 6	story	NN	8	nsubjpass
# 7	is	VBZ	8	auxpass
# 8	told	VBN	4	rcmod
# 9	-	:	8	punct
# 10	its	PRP$	12	poss
# 11	ham-fisted	JJ	12	amod
# 12	dialogue	NN	27	dep
# 13	and	CC	12	cc
# 14	plot	NN	12	conj
# 15	,	,	12	punct
# 16	its	PRP$	18	poss
# 17	forced	VBN	18	amod
# 18	obscenity	NN	12	conj
# 19	at	IN	12	prep
# 20	every	DT	21	det
# 21	turn	NN	19	pobj
# 22	-	:	12	punct
# 23	that	IN	27	amod
# 24	reveals	NNS	27	nn
# 25	its	PRP$	27	poss
# 26	teen	NN	27	nn
# 27	sensibilities	NNS	8	parataxis
# 28	.	.	4	punct
# --- Sentence ---
# 1	The	DT	3	det
# 2	second	JJ	3	amod
# 3	set	NN	6	nsubjpass
# 4	is	VBZ	6	auxpass
# 5	strictly	RB	6	advmod
# 6	played	VBN	0	root
# 7	for	IN	6	prep
# 8	laughs	NNS	7	pobj
# 9	--	:	6	punct
# 10	there	RB	6	advmod
# 11	is	VBZ	16	cop
# 12	little	RB	16	nn
# 13	or	CC	12	cc
# 14	no	DT	12	conj
# 15	character	NN	16	nn
# 16	development	NN	6	xcomp
# 17	and	CC	16	cc
# 18	the	DT	19	det
# 19	plots	NNS	16	conj
# 20	and	CC	16	cc
# 21	dialogue	NN	16	conj
# 22	run	VBN	21	partmod
# 23	rather	RB	24	advmod
# 24	thin	JJ	22	advmod
# 25	.	.	6	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	writing	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	atrocious	JJ	0	root
# 5	,	,	4	punct
# 6	and	CC	4	cc
# 7	while	IN	12	mark
# 8	the	DT	9	det
# 9	actors	NNS	12	nsubjpass
# 10	should	MD	12	aux
# 11	be	VB	12	auxpass
# 12	given	VBN	28	advcl
# 13	credit	NN	12	dep
# 14	for	IN	13	prep
# 15	not	RB	16	neg
# 16	choking	VBG	14	pcomp
# 17	on	IN	16	prep
# 18	the	DT	19	det
# 19	swill	NN	17	pobj
# 20	they	PRP	21	nsubj
# 21	have	VBP	19	rcmod
# 22	for	IN	21	prep
# 23	dialogue	NN	22	pobj
# 24	,	,	28	punct
# 25	they	PRP	28	nsubj
# 26	are	VBP	28	cop
# 27	completely	RB	28	advmod
# 28	unbelievable	JJ	4	conj
# 29	.	.	4	punct
# --- Sentence ---
# 1	The	DT	3	det
# 2	supporting	NN	3	nn
# 3	actors	NNS	4	nsubj
# 4	give	VBP	0	root
# 5	such	JJ	8	amod
# 6	a	DT	8	det
# 7	bland/typical	JJ	8	amod
# 8	performance	NN	4	dobj
# 9	that	WDT	16	dobj
# 10	not	RB	13	neg
# 11	even	RB	13	advmod
# 12	Jamie	NNP	13	nn
# 13	Lee	NNP	16	nsubj
# 14	could	MD	16	aux
# 15	have	VB	16	aux
# 16	saved	VBN	8	rcmod
# 17	the	DT	18	det
# 18	dialogue	NN	16	dobj
# 19	.	.	4	punct
# --- Sentence ---
# 1	Amatuerish	JJ	10	amod
# 2	in	IN	1	prep
# 3	dialogue	NN	2	pobj
# 4	,	,	1	punct
# 5	acting	VBG	1	xcomp
# 6	,	,	1	punct
# 7	plot	NN	8	nn
# 8	direction	NN	10	nn
# 9	etc	NN	10	nn
# 10	etc	NN	0	root
# 11	...	:	15	punct
# 12	.sure	JJ	15	amod
# 13	it	PRP	15	nsubj
# 14	's	VBZ	15	cop
# 15	bubblegum	NN	10	dep
# 16	for	IN	15	prep
# 17	late	JJ	16	pobj
# 18	at	IN	15	prep
# 19	night	NN	18	pobj
# 20	but	CC	10	cc
# 21	it	PRP	25	nsubj
# 22	's	VBZ	25	cop
# 23	really	RB	24	advmod
# 24	breathtakingly	RB	25	advmod
# 25	awful	JJ	10	conj
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	5	nsubj
# 3	does	VBZ	5	aux
# 4	n't	RB	5	neg
# 5	fair	VB	0	root
# 6	any	DT	7	det
# 7	better	JJR	5	dobj
# 8	,	,	5	punct
# 9	it	PRP	12	nsubj
# 10	's	VBZ	12	cop
# 11	also	RB	12	advmod
# 12	dull	JJ	5	xcomp
# 13	and	CC	5	cc
# 14	uninspired	VBD	5	conj
# 15	.	.	5	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	stupid	JJ	0	root
# 5	,	,	4	punct
# 6	and	CC	4	cc
# 7	the	DT	8	det
# 8	dialogue	NN	11	nsubj
# 9	is	VBZ	11	cop
# 10	so	RB	11	advmod
# 11	bad	JJ	4	conj
# 12	it	PRP	13	nsubj
# 13	's	VBZ	11	ccomp
# 14	over	IN	13	prep
# 15	the	DT	16	det
# 16	top	JJ	14	pobj
# 17	.	.	4	punct
# --- Sentence ---
# 1	There	EX	2	expl
# 2	's	VBZ	0	root
# 3	no	DT	4	det
# 4	joke	NN	2	nsubj
# 5	too	RB	6	advmod
# 6	hackneyed	VBN	4	partmod
# 7	,	,	4	punct
# 8	no	DT	9	det
# 9	visual	JJ	4	appos
# 10	too	RB	11	advmod
# 11	disgusting	VBG	9	amod
# 12	,	,	4	punct
# 13	and	CC	4	cc
# 14	no	DT	15	det
# 15	dialogue	NN	4	conj
# 16	too	RB	17	advmod
# 17	stupid	JJ	15	amod
# 18	to	TO	19	aux
# 19	throw	VB	17	xcomp
# 20	in	IN	19	prep
# 21	the	DT	22	det
# 22	mix	NN	20	pobj
# 23	.	.	2	punct
# --- Sentence ---
# 1	She	PRP	2	nsubj
# 2	thinks	VBZ	0	root
# 3	everything	NN	9	nsubj
# 4	and	CC	3	cc
# 5	everyone	NN	3	conj
# 6	is	VBZ	9	cop
# 7	really	RB	9	advmod
# 8	really	RB	9	advmod
# 9	stupid	JJ	2	ccomp
# 10	,	,	2	punct
# 11	she	PRP	12	nsubj
# 12	does	VBZ	2	ccomp
# 13	nothing	NN	12	dobj
# 14	but	CC	12	cc
# 15	argue	JJ	12	conj
# 16	with	IN	12	prep
# 17	everyone	NN	16	pobj
# 18	all	DT	20	predet
# 19	the	DT	20	det
# 20	time	NN	17	dep
# 21	,	,	2	punct
# 22	it	PRP	27	nsubj
# 23	's	VBZ	27	cop
# 24	all	DT	27	dep
# 25	her	PRP$	27	poss
# 26	parents	NNS	27	nn
# 27	fault	NN	2	ccomp
# 28	of	IN	27	prep
# 29	course	NN	28	pobj
# 30	because	IN	33	mark
# 31	she	PRP	33	nsubj
# 32	's	VBZ	33	cop
# 33	perfect	JJ	27	advcl
# 34	,	,	27	punct
# 35	her	PRP$	37	poss
# 36	dialogue	NN	37	nn
# 37	consists	NNS	27	conj
# 38	of	IN	37	prep
# 39	nothing	NN	38	pobj
# 40	but	CC	39	cc
# 41	smart-aleck	JJ	42	amod
# 42	remarks	NNS	39	conj
# 43	that	WDT	45	dobj
# 44	she	PRP	45	nsubj
# 45	says	VBZ	42	rcmod
# 46	in	IN	45	prep
# 47	that	DT	49	complm
# 48	``	``	49	punct
# 49	oh	NN	46	pobj
# 50	so	RB	51	advmod
# 51	cute	JJ	53	amod
# 52	``	``	53	punct
# 53	way	NN	49	dep
# 54	that	IN	60	dobj
# 55	fans	NNS	60	nsubj
# 56	of	IN	55	prep
# 57	Lizzie	NNP	58	nn
# 58	McGuire	NNP	56	pobj
# 59	may	MD	60	aux
# 60	find	VB	53	rcmod
# 61	clever	RB	60	advmod
# 62	...	:	49	punct
# 63	good	JJ	64	amod
# 64	grief	NN	49	dep
# 65	.	.	2	punct
# --- Sentence ---
# 1	The	DT	6	det
# 2	two	CD	6	num
# 3	dimensional	JJ	6	amod
# 4	nice	NN	6	nn
# 5	old	JJ	6	amod
# 6	brother	NN	10	nsubjpass
# 7	and	CC	6	cc
# 8	sister	NN	6	conj
# 9	are	VBP	10	auxpass
# 10	treated	VBN	0	root
# 11	horribly	RB	10	advmod
# 12	,	,	10	punct
# 13	for	IN	10	prep
# 14	no	DT	16	det
# 15	good	JJ	16	amod
# 16	reason	NN	13	pobj
# 17	with	IN	16	prep
# 18	no	DT	19	det
# 19	motivation	NN	17	pobj
# 20	or	CC	17	cc
# 21	payoff	IN	17	conj
# 22	,	,	10	punct
# 23	the	DT	24	det
# 24	songs	NNS	26	nsubj
# 25	are	VBP	26	cop
# 26	unlistnable	JJ	10	xcomp
# 27	and	CC	10	cc
# 28	the	DT	29	det
# 29	dialogue	NN	31	nsubj
# 30	is	VBZ	31	cop
# 31	hard	JJ	10	conj
# 32	to	TO	33	aux
# 33	understand	VB	31	dep
# 34	,	,	41	punct
# 35	this	DT	41	nsubj
# 36	is	VBZ	41	cop
# 37	not	RB	41	neg
# 38	always	RB	41	advmod
# 39	a	DT	41	det
# 40	bad	JJ	41	amod
# 41	thing	NN	10	parataxis
# 42	.	.	10	punct
# --- Sentence ---
# 1	The	DT	5	det
# 2	only	JJ	5	amod
# 3	really	RB	4	advmod
# 4	good	JJ	5	amod
# 5	thing	NN	27	nsubj
# 6	in	IN	5	prep
# 7	there	EX	8	expl
# 8	is	VBZ	6	pcomp
# 9	Leo	NNP	10	nn
# 10	McKern	NNP	8	nsubj
# 11	,	,	10	punct
# 12	who	WP	14	rel
# 13	shines	NNS	14	nsubj
# 14	forth	VBP	10	rcmod
# 15	like	IN	14	prep
# 16	a	DT	17	det
# 17	beacon	NN	15	pobj
# 18	in	IN	17	prep
# 19	a	DT	20	det
# 20	fog	NN	18	pobj
# 21	of	IN	20	prep
# 22	wooden	NN	21	pobj
# 23	acting	VBG	17	partmod
# 24	and	CC	14	cc
# 25	stilted	VBD	14	conj
# 26	dialogue	NN	25	dobj
# 27	.	.	0	root
# --- Sentence ---
# 1	You	PRP	4	nsubj
# 2	do	VBP	4	aux
# 3	n't	RB	4	neg
# 4	go	VB	0	root
# 5	to	TO	4	prep
# 6	these	DT	7	det
# 7	movies	NNS	5	pobj
# 8	to	TO	9	aux
# 9	expect	VB	4	xcomp
# 10	well-written	JJ	11	amod
# 11	dialogue	NN	9	dobj
# 12	,	,	11	punct
# 13	character	NN	14	nn
# 14	depth	NN	11	conj
# 15	or	CC	11	cc
# 16	anything	NN	11	conj
# 17	,	,	4	punct
# 18	you	PRP	19	nsubj
# 19	come	VBP	4	ccomp
# 20	for	IN	19	prep
# 21	the	DT	22	det
# 22	kills	NNS	20	pobj
# 23	and	CC	4	cc
# 24	to	TO	25	aux
# 25	tell	VB	4	conj
# 26	you	PRP	25	iobj
# 27	the	DT	28	det
# 28	truth	NN	25	dobj
# 29	,	,	33	punct
# 30	they	PRP	33	nsubj
# 31	're	VBP	33	cop
# 32	slightly	RB	33	advmod
# 33	disappointing	JJ	4	parataxis
# 34	.	.	4	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	script	NN	6	nsubj
# 3	and	CC	2	cc
# 4	dialogue	NN	2	conj
# 5	are	VBP	6	cop
# 6	lousy	JJ	0	root
# 7	.	.	6	punct
# --- Sentence ---
# 1	The	DT	4	det
# 2	unwitty	NN	3	nn
# 3	dialogue	NN	4	nn
# 4	tries	NNS	8	nsubj
# 5	to	TO	8	aux
# 6	be	VB	8	cop
# 7	clever	RB	8	advmod
# 8	all	DT	0	root
# 9	throughout	IN	8	prep
# 10	the	DT	11	det
# 11	movie	NN	9	pobj
# 12	and	CC	8	cc
# 13	is	VBZ	16	aux
# 14	just	RB	15	advmod
# 15	sooo	RB	16	advmod
# 16	boring	VBG	8	conj
# 17	.	.	8	punct
# --- Sentence ---
# 1	There	EX	2	expl
# 2	is	VBZ	0	root
# 3	almost	RB	5	advmod
# 4	no	DT	5	det
# 5	script	NN	2	nsubj
# 6	to	TO	7	aux
# 7	speak	VB	5	infmod
# 8	of	IN	7	prep
# 9	,	,	5	punct
# 10	and	CC	5	cc
# 11	what	WP	15	nsubj
# 12	little	RB	13	advmod
# 13	there	RB	11	advmod
# 14	is	VBZ	15	cop
# 15	consists	NNS	5	conj
# 16	of	IN	15	prep
# 17	trite	JJ	18	amod
# 18	exchanges	NNS	16	pobj
# 19	and	CC	18	cc
# 20	banter	NN	18	conj
# 21	with	IN	15	prep
# 22	barely	RB	23	quantmod
# 23	2	CD	25	num
# 24	memorable	JJ	25	amod
# 25	lines	NNS	21	pobj
# 26	of	IN	25	prep
# 27	dialogue	NN	26	pobj
# 28	.	.	2	punct
# --- Sentence ---
# 1	There	EX	2	expl
# 2	are	VBP	0	root
# 3	endless	JJ	4	amod
# 4	shots	NNS	2	nsubj
# 5	of	IN	4	prep
# 6	open	JJ	7	amod
# 7	seas	NNS	5	pobj
# 8	or	CC	7	cc
# 9	country	NN	7	conj
# 10	,	,	2	punct
# 11	followed	VBD	2	nsubj
# 12	by	IN	2	prep
# 13	about	RB	14	quantmod
# 14	30	CD	15	num
# 15	seconds	NNS	12	pobj
# 16	of	IN	15	prep
# 17	dialogue	NN	16	pobj
# 18	,	,	15	punct
# 19	followed	VBN	15	partmod
# 20	by	IN	19	prep
# 21	EVEN	NNP	22	nn
# 22	MORE	NNP	24	nn
# 23	endless	NN	24	nn
# 24	footage	NN	20	pobj
# 25	of	IN	24	prep
# 26	different	JJ	27	amod
# 27	locales	NNS	25	pobj
# 28	.	.	2	punct
# --- Sentence ---
# 1	I	PRP	2	nsubj
# 2	found	VBD	0	root
# 3	myself	PRP	4	nsubj
# 4	hitting	VBG	2	ccomp
# 5	the	DT	9	det
# 6	``	``	9	punct
# 7	fast-foward	JJ	9	amod
# 8	``	``	9	punct
# 9	button	NN	4	dobj
# 10	on	IN	9	prep
# 11	my	PRP$	12	poss
# 12	remote	NN	10	pobj
# 13	on	IN	4	prep
# 14	more	JJR	13	pobj
# 15	than	IN	14	prep
# 16	a	DT	18	det
# 17	few	JJ	18	amod
# 18	occasions	NNS	15	pobj
# 19	,	,	2	punct
# 20	simply	RB	23	advmod
# 21	because	IN	23	dep
# 22	I	PRP	23	nsubj
# 23	knew	VBD	2	dep
# 24	I	PRP	27	nsubj
# 25	was	VBD	27	aux
# 26	n't	RB	27	neg
# 27	missing	VBG	23	ccomp
# 28	any	DT	29	det
# 29	dialogue	NN	27	dobj
# 30	and	CC	29	cc
# 31	the	DT	33	det
# 32	establishing	NN	33	nn
# 33	shots	NNS	29	conj
# 34	would	MD	35	aux
# 35	go	VB	23	dep
# 36	on	IN	35	prep
# 37	for	IN	42	amod
# 38	1	CD	41	num
# 39	or	CC	38	cc
# 40	2	CD	38	conj
# 41	minutes	NNS	42	nn
# 42	STRAIGHT	NNP	36	pobj
# 43	!	.	2	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	4	nsubj
# 3	was	VBD	4	cop
# 4	sharp	JJ	0	root
# 5	and	CC	4	cc
# 6	you	PRP	8	nsubj
# 7	might	MD	8	aux
# 8	have	VB	4	conj
# 9	to	TO	10	aux
# 10	watch	VB	8	xcomp
# 11	twice	NN	10	dobj
# 12	to	TO	13	aux
# 13	get	VB	10	xcomp
# 14	all	DT	16	predet
# 15	the	DT	16	det
# 16	subtle	NN	17	nsubj
# 17	quips	VBZ	13	xcomp
# 18	.	.	4	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	5	nsubj
# 3	is	VBZ	5	cop
# 4	wonderfully	RB	5	advmod
# 5	expressive	JJ	0	root
# 6	and	CC	5	cc
# 7	gives	VBZ	5	conj
# 8	us	PRP	7	iobj
# 9	the	DT	10	det
# 10	sense	NN	7	dobj
# 11	of	IN	10	prep
# 12	authenticity	NN	11	pobj
# 13	and	CC	10	cc
# 14	the	DT	15	det
# 15	kind	NN	10	conj
# 16	of	IN	15	prep
# 17	realistic	JJ	18	amod
# 18	effect	NN	16	pobj
# 19	seen	IN	7	prep
# 20	only	RB	21	advmod
# 21	in	IN	19	pcomp
# 22	the	DT	25	det
# 23	very	JJ	24	amod
# 24	best	JJS	25	amod
# 25	films	NNS	21	pobj
# 26	.	.	5	punct
# --- Sentence ---
# 1	Gould	NNP	2	nsubj
# 2	creates	VBZ	0	root
# 3	a	DT	16	det
# 4	sharp	JJ	14	amod
# 5	,	,	14	punct
# 6	amiable	JJ	14	amod
# 7	,	,	14	punct
# 8	chain-smoking	JJ	14	amod
# 9	,	,	14	punct
# 10	wise-cracking	JJ	14	amod
# 11	70s	CD	14	num
# 12	detective	JJ	14	amod
# 13	whose	NN	14	nn
# 14	'quirky-alone	NN	16	nn
# 15	'	''	16	punct
# 16	livestyle	NN	2	dobj
# 17	allow	RB	2	advmod
# 18	him	PRP	2	iobj
# 19	the	DT	20	det
# 20	freedom	NN	2	dobj
# 21	to	TO	22	aux
# 22	give	VB	20	infmod
# 23	his	PRP$	25	poss
# 24	own	JJ	25	amod
# 25	Chandleresque	NNP	22	dobj
# 26	,	,	25	punct
# 27	talking-to-himself	JJ	28	amod
# 28	dialogue	NN	25	appos
# 29	(	:	25	punct
# 30	...	:	25	punct
# 31	'it	JJ	32	amod
# 32	's	POS	33	poss
# 33	alright	NN	25	dep
# 34	by	IN	33	prep
# 35	me	PRP	34	pobj
# 36	...	:	25	punct
# 37	'	''	25	punct
# 38	)	:	25	punct
# 39	whilst	NN	40	nn
# 40	interacting	NN	25	dep
# 41	with	IN	40	prep
# 42	a	DT	44	det
# 43	diverse	JJ	44	amod
# 44	range	NN	41	pobj
# 45	of	IN	44	prep
# 46	characters	NNS	45	pobj
# 47	within	IN	40	prep
# 48	the	DT	49	det
# 49	narrative	JJ	47	pobj
# 50	.	.	2	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	colors	NNS	4	nsubj
# 3	are	VBP	4	cop
# 4	dark	JJ	0	root
# 5	,	,	4	punct
# 6	the	DT	7	det
# 7	dialogue	NN	12	nsubj
# 8	between	IN	7	prep
# 9	the	DT	10	det
# 10	characters	NNS	8	pobj
# 11	is	VBZ	12	cop
# 12	honest	JJS	4	ccomp
# 13	,	,	12	punct
# 14	real	JJ	12	conj
# 15	and	CC	12	cc
# 16	simply	RB	17	advmod
# 17	wonderful	JJ	12	conj
# 18	.	.	4	punct
# --- Sentence ---
# 1	While	IN	7	mark
# 2	the	DT	4	det
# 3	whole	JJ	4	amod
# 4	film	NN	7	nsubjpass
# 5	is	VBZ	7	auxpass
# 6	beautifully	RB	7	advmod
# 7	executed	VBN	33	advcl
# 8	thanks	NNS	7	dobj
# 9	to	TO	8	prep
# 10	Kazan	NNP	13	poss
# 11	's	POS	10	possessive
# 12	sure	NN	13	nn
# 13	hand	NN	9	pobj
# 14	and	CC	8	cc
# 15	William	NNP	16	nn
# 16	Inge	NNP	18	poss
# 17	's	POS	16	possessive
# 18	screenplay	NN	8	conj
# 19	(	:	8	punct
# 20	his	PRP$	21	poss
# 21	first	JJ	8	dep
# 22	directly	RB	21	advmod
# 23	for	IN	21	prep
# 24	the	DT	25	det
# 25	screen	NN	23	pobj
# 26	)	:	8	punct
# 27	,	,	33	punct
# 28	it	PRP	33	nsubj
# 29	's	VBZ	33	cop
# 30	the	DT	33	det
# 31	last	JJ	33	amod
# 32	fifteen	NN	33	nn
# 33	minutes	NNS	0	root
# 34	that	WDT	36	nsubj
# 35	really	RB	36	advmod
# 36	resonate	VBP	33	rcmod
# 37	with	IN	36	prep
# 38	the	DT	39	det
# 39	characters	NNS	37	pobj
# 40	expressing	VBG	39	partmod
# 41	their	PRP$	42	poss
# 42	emotions	NNS	40	dobj
# 43	with	IN	40	prep
# 44	a	DT	45	det
# 45	minimum	JJ	43	pobj
# 46	of	IN	45	prep
# 47	dialogue	NN	46	pobj
# 48	.	.	33	punct
# --- Sentence ---
# 1	Having	VBG	2	aux
# 2	proven	VBN	0	root
# 3	her	PRP$	4	poss
# 4	ability	NN	2	dobj
# 5	to	TO	8	aux
# 6	be	VB	8	cop
# 7	a	DT	8	det
# 8	convincing	NN	4	infmod
# 9	Southerner	NNP	8	tmod
# 10	in	IN	8	prep
# 11	``	``	10	punct
# 12	Gone	NNP	13	nn
# 13	With	NNP	10	pobj
# 14	the	DT	15	det
# 15	Wind	NNP	21	nsubj
# 16	``	``	21	punct
# 17	,	,	21	punct
# 18	Vivien	NNP	19	nn
# 19	Leigh	NNP	21	nsubj
# 20	expertly	RB	21	advmod
# 21	handles	VBZ	13	rcmod
# 22	all	DT	25	predet
# 23	the	DT	25	det
# 24	florid	JJ	25	amod
# 25	dialogue	NN	21	dobj
# 26	with	IN	25	prep
# 27	her	PRP$	29	poss
# 28	particular	JJ	29	amod
# 29	blend	NN	26	pobj
# 30	of	IN	29	prep
# 31	defiance	NN	30	pobj
# 32	and	CC	31	cc
# 33	vulnerability	NN	31	conj
# 34	.	.	2	erased
# --- Sentence ---
# 1	)	NN	3	nsubj
# 2	would	MD	3	aux
# 3	do	VB	0	root
# 4	a	DT	5	det
# 5	REMAKE	NNP	3	dobj
# 6	of	IN	3	prep
# 7	this	DT	9	det
# 8	entire	JJ	9	amod
# 9	project	NN	6	pobj
# 10	--	:	3	punct
# 11	making	VBG	3	parataxis
# 12	it	PRP	11	dobj
# 13	into	IN	11	prep
# 14	a	DT	18	det
# 15	4	CD	18	num
# 16	hour	NN	17	nn
# 17	feature	NN	18	nn
# 18	movie	NN	13	pobj
# 19	--	:	3	punct
# 20	tightening	VBG	3	parataxis
# 21	up	RP	20	prt
# 22	the	DT	23	det
# 23	script	NN	20	dobj
# 24	entirely	RB	20	advmod
# 25	(	.	3	punct
# 26	apologies	NNS	3	dobj
# 27	to	TO	3	prep
# 28	Mr.	NNP	29	nn
# 29	Wouk	NNP	27	pobj
# 30	who	WP	31	nsubj
# 31	wrote	VBD	3	ccomp
# 32	the	DT	33	det
# 33	teleplay	NN	31	dobj
# 34	)	:	3	punct
# 35	--	:	3	punct
# 36	mostly	RB	37	advmod
# 37	keep	VB	3	parataxis
# 38	in	IN	37	prep
# 39	the	DT	41	det
# 40	historical	JJ	41	amod
# 41	scenes	NNS	38	pobj
# 42	--	:	3	punct
# 43	but	CC	3	cc
# 44	more	JJR	47	amod
# 45	realistic	JJ	47	amod
# 46	battle	NN	47	nn
# 47	scenes	NNS	49	nsubj
# 48	especially	RB	49	advmod
# 49	those	DT	3	conj
# 50	at	IN	49	prep
# 51	sea	NN	50	pobj
# 52	--	:	3	punct
# 53	and	CC	3	cc
# 54	do	VBP	3	conj
# 55	away	RB	3	advmod
# 56	with	IN	3	prep
# 57	some	DT	56	pobj
# 58	of	IN	57	prep
# 59	the	DT	65	det
# 60	long	JJ	65	amod
# 61	,	,	65	punct
# 62	soap	NN	65	nn
# 63	opera	NN	64	nn
# 64	dialogue	NN	65	nn
# 65	scenes	NNS	58	pobj
# 66	.	.	3	punct
# --- Sentence ---
# 1	this	DT	2	det
# 2	episode	NN	3	nsubj
# 3	has	VBZ	0	root
# 4	a	DT	5	det
# 5	lot	NN	3	dobj
# 6	of	IN	5	prep
# 7	funny	JJ	8	amod
# 8	dialogue	NN	6	pobj
# 9	,	,	3	punct
# 10	but	CC	3	cc
# 11	that	IN	15	nsubj
# 12	's	VBZ	15	cop
# 13	the	DT	15	det
# 14	only	JJ	15	amod
# 15	thing	NN	3	conj
# 16	it	PRP	17	nsubj
# 17	has	VBZ	15	rcmod
# 18	working	VBG	17	dobj
# 19	for	IN	18	prep
# 20	it	PRP	19	pobj
# 21	.	.	3	punct
# --- Sentence ---
# 1	In	IN	7	prep
# 2	conclusion	NN	1	pobj
# 3	,	,	7	punct
# 4	this	DT	6	det
# 5	TV	NN	6	nn
# 6	show	NN	7	nsubj
# 7	has	VBZ	0	root
# 8	it	PRP	7	dobj
# 9	all	DT	8	det
# 10	:	:	7	punct
# 11	good	JJ	13	amod
# 12	background	NN	13	nn
# 13	music	NN	7	dobj
# 14	,	,	13	punct
# 15	great	JJ	16	amod
# 16	dialogue	NN	13	conj
# 17	,	,	13	punct
# 18	interesting	JJ	19	amod
# 19	stories	NNS	13	conj
# 20	,	,	19	punct
# 21	good	JJ	22	amod
# 22	acting	NN	19	appos
# 23	,	,	19	punct
# 24	and	CC	19	cc
# 25	interesting	JJ	26	amod
# 26	cinematography	NN	19	conj
# 27	.	.	7	punct
# --- Sentence ---
# 1	This	DT	2	det
# 2	film	NN	6	nsubjpass
# 3	is	VBZ	6	auxpass
# 4	so	RB	5	advmod
# 5	well	RB	6	advmod
# 6	done	VBN	0	root
# 7	,	,	6	punct
# 8	from	IN	6	prep
# 9	the	DT	10	det
# 10	characters	NNS	8	pobj
# 11	,	,	6	punct
# 12	the	DT	13	det
# 13	actors	NNS	6	dobj
# 14	,	,	6	punct
# 15	the	DT	16	det
# 16	dialogue	NN	6	dobj
# 17	and	CC	16	cc
# 18	the	DT	19	det
# 19	stories	NNS	16	conj
# 20	.	.	6	punct
# --- Sentence ---
# 1	This	DT	5	nsubj
# 2	is	VBZ	5	cop
# 3	a	DT	5	det
# 4	wonderful	JJ	5	amod
# 5	film	NN	0	root
# 6	,	,	5	punct
# 7	with	IN	5	prep
# 8	a	DT	0	root
# 9	silly	RB	21	advmod
# 10	but	CC	9	cc
# 11	extremley	NN	13	nn
# 12	funny	NN	13	nn
# 13	plot	NN	9	conj
# 14	,	,	9	punct
# 15	and	CC	9	cc
# 16	some	DT	18	det
# 17	wonderful	JJ	18	amod
# 18	dialogue	NN	9	conj
# 19	,	,	21	punct
# 20	particularly	RB	21	advmod
# 21	between	IN	8	prep
# 22	Horton	NNP	21	pobj
# 23	and	CC	22	cc
# 24	Brady	NNP	22	conj
# 25	,	,	22	punct
# 26	who	WP	28	nsubj
# 27	somehow	RB	28	advmod
# 28	manage	VBP	22	rcmod
# 29	to	TO	30	aux
# 30	end	VB	28	xcomp
# 31	up	RP	30	prt
# 32	married	VBN	30	ccomp
# 33	to	TO	32	prep
# 34	each	DT	35	det
# 35	other	JJ	33	pobj
# 36	,	,	22	punct
# 37	much	JJ	22	amod
# 38	to	TO	37	prep
# 39	their	PRP$	40	poss
# 40	surprise	NN	38	pobj
# 41	.	.	8	erased
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	sharp	JJ	0	root
# 5	and	CC	4	cc
# 6	witty	JJ	4	conj
# 7	,	,	4	punct
# 8	although	IN	10	mark
# 9	there	EX	10	expl
# 10	's	VBZ	4	advcl
# 11	alot	NN	10	nsubj
# 12	of	IN	11	prep
# 13	swearing	VBG	12	pobj
# 14	,	,	4	punct
# 15	that	IN	18	nsubj
# 16	does	VBZ	18	aux
# 17	n't	RB	18	neg
# 18	mean	VB	4	ccomp
# 19	the	DT	20	det
# 20	humour	NN	18	dobj
# 21	is	VBZ	23	cop
# 22	just	RB	23	advmod
# 23	fowl	NN	4	dep
# 24	mouthed	VBD	23	dep
# 25	,	,	23	punct
# 26	it	PRP	28	nsubj
# 27	's	VBZ	28	cop
# 28	hillarious	JJ	23	rcmod
# 29	,	,	23	punct
# 30	some	DT	23	dep
# 31	of	IN	30	prep
# 32	the	DT	33	det
# 33	lines	NNS	31	pobj
# 34	go	VBP	23	dep
# 35	down	RB	34	advmod
# 36	in	IN	34	prep
# 37	history	NN	36	pobj
# 38	as	IN	23	prep
# 39	some	DT	38	pobj
# 40	of	IN	39	prep
# 41	the	DT	44	det
# 42	funniest	JJS	44	amod
# 43	one	CD	44	num
# 44	liners	NNS	40	pobj
# 45	ever	RB	44	advmod
# 46	.	.	4	punct
# --- Sentence ---
# 1	Set	NNP	22	nsubj
# 2	against	IN	1	prep
# 3	a	DT	5	det
# 4	piano	NN	5	nn
# 5	score	NN	2	pobj
# 6	which	WDT	7	nsubj
# 7	resonates	VBZ	5	rcmod
# 8	with	IN	7	prep
# 9	the	DT	11	det
# 10	inner	NN	11	nn
# 11	sense	NN	8	pobj
# 12	of	IN	11	prep
# 13	uncertainty	NN	12	pobj
# 14	and	CC	13	cc
# 15	suspicion	NN	13	conj
# 16	in	IN	13	prep
# 17	the	DT	18	det
# 18	dialogue	NN	16	pobj
# 19	,	,	1	punct
# 20	the	DT	21	det
# 21	movie	NN	1	appos
# 22	achieves	VBZ	0	root
# 23	some	DT	25	predet
# 24	the	DT	25	det
# 25	things	NNS	22	dobj
# 26	that	IN	32	dobj
# 27	the	DT	29	det
# 28	big	JJ	29	amod
# 29	stage	NN	32	nsubj
# 30	does	VBZ	32	aux
# 31	not	RB	32	neg
# 32	allow	VB	25	rcmod
# 33	,	,	32	punct
# 34	including	VBG	32	prep
# 35	flashbacks	NNS	34	pobj
# 36	and	CC	35	cc
# 37	scenes	NNS	35	conj
# 38	ranging	VBG	35	partmod
# 39	back	RB	38	advmod
# 40	and	CC	39	cc
# 41	forth	JJ	39	conj
# 42	between	IN	39	prep
# 43	the	DT	44	det
# 44	park	NN	42	pobj
# 45	and	CC	44	cc
# 46	Bohr	NNP	48	poss
# 47	's	POS	46	possessive
# 48	home	NN	44	conj
# 49	.	.	22	punct
# --- Sentence ---
# 1	In	IN	19	prep
# 2	an	DT	3	det
# 3	era	NN	1	pobj
# 4	where	WRB	8	advmod
# 5	cinematic	JJ	6	amod
# 6	palates	NNS	8	nsubjpass
# 7	seem	VBP	8	auxpass
# 8	titillated	VBN	3	rcmod
# 9	mostly	RB	10	advmod
# 10	by	IN	8	prep
# 11	fast	RB	13	advmod
# 12	action	NN	13	nn
# 13	thrillers	NNS	10	pobj
# 14	,	,	19	punct
# 15	this	DT	16	det
# 16	movie	NN	19	nsubj
# 17	is	VBZ	19	cop
# 18	another	DT	19	det
# 19	example	NN	0	root
# 20	of	IN	19	prep
# 21	how	WRB	23	advmod
# 22	well	RB	23	advmod
# 23	constructed	VBN	20	pcomp
# 24	dialogue	NN	23	dobj
# 25	makes	VBZ	19	dep
# 26	for	IN	19	prep
# 27	gripping	NN	26	pobj
# 28	cinematic	JJ	29	amod
# 29	drama	NN	19	dobj
# 30	when	WRB	32	advmod
# 31	it	PRP	32	nsubj
# 32	goes	VBZ	19	advcl
# 33	hand	NN	32	dobj
# 34	in	IN	32	prep
# 35	hand	NN	34	pobj
# 36	with	IN	32	prep
# 37	superb	NN	36	pobj
# 38	casting	VBG	37	dep
# 39	and	CC	38	cc
# 40	performance	NN	38	conj
# --- Sentence ---
# 1	Love	NNP	5	nsubj
# 2	and	CC	1	cc
# 3	Death	NNP	1	conj
# 4	is	VBZ	5	cop
# 5	full	JJ	0	root
# 6	of	IN	5	prep
# 7	the	DT	8	det
# 8	witty	NN	6	pobj
# 9	one	CD	10	num
# 10	liners	NNS	32	nsubj
# 11	and	CC	10	cc
# 12	pratfalls	NNS	10	conj
# 13	that	WDT	15	nsubj
# 14	were	VBD	15	cop
# 15	prevelant	JJ	10	rcmod
# 16	in	IN	15	prep
# 17	his	PRP$	27	amod
# 18	&	CC	17	cc
# 19	quot	NN	17	conj
# 20	;	:	27	punct
# 21	earlier	JJR	27	amod
# 22	,	,	27	punct
# 23	funnier	JJR	27	amod
# 24	&	CC	23	cc
# 25	quot	NN	23	conj
# 26	;	:	23	punct
# 27	works	NNS	16	pobj
# 28	...	:	10	punct
# 29	but	CC	32	cc
# 30	you	PRP	32	nsubj
# 31	can	MD	32	aux
# 32	see	VB	8	rcmod
# 33	in	IN	32	prep
# 34	the	DT	35	det
# 35	dialogue	NN	33	pobj
# 36	of	IN	35	prep
# 37	Love	NNP	36	pobj
# 38	and	CC	37	cc
# 39	Death	NNP	37	conj
# 40	that	IN	43	dobj
# 41	Woody	NNP	43	nsubj
# 42	was	VBD	43	aux
# 43	maturing	VBG	35	rcmod
# 44	.	.	5	punct
# --- Sentence ---
# 1	You	PRP	4	nsubjpass
# 2	'll	MD	4	aux
# 3	be	VB	4	auxpass
# 4	sucked	VBN	0	root
# 5	in	IN	4	advmod
# 6	,	,	4	punct
# 7	and	CC	4	cc
# 8	surprised	VBD	4	conj
# 9	,	,	8	punct
# 10	within	IN	4	prep
# 11	the	DT	14	det
# 12	first	JJ	14	amod
# 13	two	CD	14	num
# 14	minutes	NNS	10	pobj
# 15	,	,	4	punct
# 16	and	CC	4	cc
# 17	there	EX	18	expl
# 18	's	VBZ	4	conj
# 19	very	RB	20	advmod
# 20	little	JJ	21	amod
# 21	dialogue	NN	18	nsubj
# 22	so	IN	24	mark
# 23	you	PRP	24	nsubj
# 24	need	VBP	18	advcl
# 25	not	RB	26	neg
# 26	worry	JJ	24	dobj
# 27	about	IN	26	prep
# 28	too	RB	29	advmod
# 29	much	JJ	31	amod
# 30	subtitle	NN	31	nn
# 31	reading	NN	27	pobj
# 32	.	.	4	punct
# --- Sentence ---
# 1	It	PRP	2	nsubj
# 2	seems	VBZ	0	root
# 3	rare	JJ	4	amod
# 4	today	NN	2	tmod
# 5	to	TO	6	aux
# 6	find	VB	2	xcomp
# 7	such	JJ	9	amod
# 8	rich	JJ	9	amod
# 9	dialogue	NN	6	dobj
# 10	.	.	2	punct
# --- Sentence ---
# 1	Other	JJ	2	amod
# 2	People	NNS	4	poss
# 3	's	POS	2	possessive
# 4	Money	NNP	8	nsubj
# 5	is	VBZ	8	cop
# 6	a	DT	8	det
# 7	wonderful	JJ	8	amod
# 8	movie	NN	0	root
# 9	,	,	8	punct
# 10	full	JJ	8	amod
# 11	of	IN	10	prep
# 12	smart	NN	13	nn
# 13	dialogue	NN	11	pobj
# 14	,	,	13	punct
# 15	good	JJ	16	amod
# 16	music	NN	13	conj
# 17	,	,	8	punct
# 18	and	CC	8	cc
# 19	a	DT	23	det
# 20	terrific	JJ	23	amod
# 21	Danny	NNP	22	nn
# 22	DeVito	NNP	23	nn
# 23	performance	NN	8	conj
# 24	.	.	8	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	5	nsubj
# 3	is	VBZ	5	cop
# 4	n't	RB	5	neg
# 5	hard-boiled	JJ	0	root
# 6	except	IN	5	prep
# 7	for	IN	6	pcomp
# 8	a	DT	10	det
# 9	few	JJ	10	amod
# 10	lines	NNS	7	pobj
# 11	delivered	VBN	10	partmod
# 12	by	IN	11	prep
# 13	Vicky	NNP	12	pobj
# 14	.	.	5	punct
# --- Sentence ---
# 1	i	PRP	2	nsubj
# 2	appreciated	VBD	0	root
# 3	the	DT	4	det
# 4	effects	NNS	2	dobj
# 5	-	:	4	punct
# 6	nice	JJ	7	amod
# 7	touch	NN	4	dep
# 8	-	:	4	punct
# 9	but	CC	4	cc
# 10	i	PRP	13	nsubj
# 11	would	MD	13	aux
# 12	have	VB	13	aux
# 13	liked	VBN	4	conj
# 14	to	TO	15	aux
# 15	see	VB	13	xcomp
# 16	some	DT	18	det
# 17	real	JJ	18	amod
# 18	dialogue	NN	15	dobj
# 19	there	EX	15	dep
# 20	.	.	2	punct
# --- Sentence ---
# 1	As	IN	4	nsubj
# 2	is	VBZ	4	cop
# 3	the	DT	4	det
# 4	dialogue	NN	0	root
# 5	,	,	4	punct
# 6	as	IN	4	prep
# 7	always	RB	6	pcomp
# 8	.	.	4	punct
# --- Sentence ---
# 1	Relying	VBG	11	partmod
# 2	on	IN	1	prep
# 3	sharp	JJ	4	amod
# 4	dialogue	NN	2	pobj
# 5	and	CC	4	cc
# 6	facial	JJ	7	amod
# 7	expressions	NNS	4	conj
# 8	,	,	11	punct
# 9	the	DT	10	det
# 10	actors	NNS	11	nsubj
# 11	manage	VBP	0	root
# 12	to	TO	13	aux
# 13	weave	VB	11	xcomp
# 14	a	DT	17	det
# 15	gorgeous	JJ	17	amod
# 16	sensual	JJ	17	amod
# 17	dance	NN	13	dobj
# 18	together	RB	13	advmod
# 19	,	,	11	punct
# 20	both	DT	21	det
# 21	lighting	NN	11	dobj
# 22	up	RP	11	prt
# 23	the	DT	24	det
# 24	screen	NN	11	dobj
# 25	and	CC	11	cc
# 26	creating	VBG	11	conj
# 27	two	CD	26	dobj
# 28	of	IN	27	prep
# 29	the	DT	33	det
# 30	most	RBS	31	advmod
# 31	smolderingly	RB	32	advmod
# 32	complex	JJ	33	amod
# 33	characters	NNS	28	pobj
# 34	ever	RB	35	advmod
# 35	seen	VBN	33	partmod
# 36	in	IN	35	prep
# 37	film	NN	36	pobj
# 38	.	.	11	punct
# --- Sentence ---
# 1	Now	RB	20	advmod
# 2	,	,	20	punct
# 3	not	RB	4	neg
# 4	only	RB	7	preconj
# 5	is	VBZ	7	cop
# 6	the	DT	7	det
# 7	plot	NN	20	nsubj
# 8	and	CC	7	cc
# 9	the	DT	13	det
# 10	dialogue	NN	13	nn
# 11	and	CC	10	cc
# 12	everything	NN	10	conj
# 13	true-to-life	NN	7	conj
# 14	but	CC	7	cc
# 15	this	DT	16	det
# 16	film	NN	7	conj
# 17	is	VBZ	20	cop
# 18	also	RB	20	advmod
# 19	absolutely	RB	20	advmod
# 20	hilarious	JJ	0	root
# 21	.	.	20	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	quick-witted	JJ	0	root
# 5	,	,	4	punct
# 6	some	DT	8	predet
# 7	the	DT	8	det
# 8	scenes	NNS	11	nsubj
# 9	have	VBP	11	aux
# 10	become	VBN	11	cop
# 11	classics	NNS	4	ccomp
# 12	(	:	11	punct
# 13	Allen	NNP	14	nn
# 14	sneezing	NN	11	conj
# 15	on	IN	11	prep
# 16	the	DT	17	det
# 17	cocaine	NN	15	pobj
# 18	)	:	4	punct
# 19	.	.	4	punct
# --- Sentence ---
# 1	The	DT	3	det
# 2	'plain	JJ	3	amod
# 3	'	POS	4	dep
# 4	dialogue	NN	0	root
# 5	among	IN	4	prep
# 6	the	DT	7	det
# 7	'elders	NNS	5	pobj
# 8	'	POS	7	possessive
# 9	is	VBZ	11	aux
# 10	painfully	RB	11	advmod
# 11	numbing	VBG	4	dep
# 12	,	,	11	punct
# 13	choppy	JJ	11	conj
# 14	,	,	11	punct
# 15	and	CC	11	cc
# 16	stilted	VBD	11	conj
# 17	.	.	4	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	soundtrack	NN	4	nsubjpass
# 3	is	VBZ	4	auxpass
# 4	awesome	VBN	14	dep
# 5	,	,	9	punct
# 6	the	DT	7	det
# 7	cinematography	NN	9	nsubj
# 8	is	VBZ	9	cop
# 9	great	JJ	4	acomp
# 10	,	,	14	punct
# 11	the	DT	12	det
# 12	dialogue	NN	14	nsubj
# 13	is	VBZ	14	cop
# 14	realistic	JJ	0	root
# 15	,	,	14	punct
# 16	and	CC	14	cc
# 17	for	IN	14	advmod
# 18	once	RB	17	advmod
# 19	,	,	14	punct
# 20	a	DT	22	det
# 21	movie	NN	22	nn
# 22	set	NN	14	dep
# 23	in	IN	22	prep
# 24	a	DT	26	det
# 25	foreign	JJ	26	amod
# 26	land	NN	23	pobj
# 27	that	WDT	29	nsubj
# 28	actually	RB	29	advmod
# 29	uses	VBZ	26	rcmod
# 30	actors	NNS	29	dobj
# 31	from	IN	29	prep
# 32	that	DT	33	det
# 33	area	NN	31	pobj
# 34	speaking	VBG	33	partmod
# 35	the	DT	36	det
# 36	language	NN	34	dobj
# 37	of	IN	36	prep
# 38	that	DT	39	det
# 39	area	NN	37	pobj
# 40	!	.	14	punct
# --- Sentence ---
# 1	Some	DT	7	nsubjpass
# 2	of	IN	1	prep
# 3	my	PRP$	5	poss
# 4	favorite	JJ	5	amod
# 5	actors	NNS	2	pobj
# 6	are	VBP	7	auxpass
# 7	wasted	VBN	21	ccomp
# 8	,	,	21	punct
# 9	either	DT	21	nsubj
# 10	by	IN	9	prep
# 11	being	VBG	12	auxpass
# 12	given	VBN	10	pcomp
# 13	cliched	JJ	14	amod
# 14	dialogue	NN	12	dobj
# 15	,	,	21	punct
# 16	over	IN	21	prep
# 17	acting	JJ	16	pobj
# 18	,	,	21	punct
# 19	or	CC	21	cc
# 20	being	VBG	21	auxpass
# 21	put	VBN	0	root
# 22	there	EX	21	dobj
# 23	merely	RB	21	advmod
# 24	for	IN	21	prep
# 25	their	PRP$	27	poss
# 26	brand	NN	27	nn
# 27	name	NN	24	pobj
# 28	with	IN	21	prep
# 29	no	DT	30	det
# 30	script	NN	28	pobj
# 31	to	TO	32	aux
# 32	support	VB	21	xcomp
# 33	their	PRP$	34	poss
# 34	presence	NN	32	dobj
# 35	.	.	21	punct
# --- Sentence ---
# 1	Because	IN	7	mark
# 2	most	JJS	7	nsubjpass
# 3	of	IN	2	prep
# 4	the	DT	5	det
# 5	dialogue	NN	3	pobj
# 6	is	VBZ	7	auxpass
# 7	made	VBN	18	advcl
# 8	up	RP	7	prt
# 9	as	RB	12	advmod
# 10	the	DT	11	det
# 11	cameras	NNS	12	nsubj
# 12	roll	VBP	7	dobj
# 13	,	,	18	punct
# 14	a	DT	15	det
# 15	film	NN	18	nsubj
# 16	like	IN	15	prep
# 17	this	DT	16	pobj
# 18	takes	VBZ	0	root
# 19	a	DT	21	det
# 20	special	JJ	21	amod
# 21	cast	NN	18	dobj
# 22	of	IN	21	prep
# 23	actors	NNS	22	pobj
# 24	.	.	18	punct
# --- Sentence ---
# 1	I	PRP	3	nsubjpass
# 2	fast	VBP	3	auxpass
# 3	forwarded	VBN	0	root
# 4	through	IN	3	prep
# 5	this	DT	4	pobj
# 6	after	IN	3	prep
# 7	the	DT	9	det
# 8	first	JJ	9	amod
# 9	half	DT	6	pobj
# 10	,	,	3	punct
# 11	pausing	VBG	3	xcomp
# 12	occasionally	RB	11	advmod
# 13	to	TO	14	aux
# 14	hear	VB	11	xcomp
# 15	dialogue	NN	14	dobj
# 16	that	WDT	17	nsubj
# 17	made	VBN	15	rcmod
# 18	Dumb	NNP	21	nn
# 19	and	CC	18	cc
# 20	Dumber	NNP	18	conj
# 21	look	NN	17	dobj
# 22	like	IN	21	prep
# 23	Hemingway	NNP	22	pobj
# 24	.	.	3	punct
# --- Sentence ---
# 1	Worse	NNP	5	nsubj
# 2	still	RB	5	advmod
# 3	is	VBZ	5	cop
# 4	the	DT	5	det
# 5	dialogue	NN	0	root
# 6	,	,	5	punct
# 7	the	DT	10	det
# 8	painfully	RB	9	advmod
# 9	unfunny	JJ	10	amod
# 10	one-liners	NNS	5	conj
# 11	,	,	5	punct
# 12	and	CC	5	cc
# 13	the	DT	15	det
# 14	see-saw	NNP	15	nn
# 15	animation	NN	5	conj
# 16	that	WDT	19	nsubj
# 17	is	VBZ	19	cop
# 18	either	DT	19	det
# 19	dull	NN	15	rcmod
# 20	or	CC	19	cc
# 21	like	IN	0	root
# 22	a	DT	24	det
# 23	pinball	NN	24	nn
# 24	machine	NN	21	pobj
# 25	with	IN	24	prep
# 26	sight	NN	27	nn
# 27	gags	NNS	25	pobj
# 28	and	CC	27	cc
# 29	explosions	NNS	27	conj
# 30	.	.	21	pobj
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	14	nsubj
# 3	(	:	6	punct
# 4	especially	RB	6	dep
# 5	a	DT	6	det
# 6	lot	NN	2	dep
# 7	of	IN	6	prep
# 8	Sebastion	NNP	10	poss
# 9	's	POS	8	possessive
# 10	lines	NNS	7	pobj
# 11	)	:	6	punct
# 12	was	VBD	14	cop
# 13	really	RB	14	advmod
# 14	witty	RB	0	root
# 15	and	CC	14	cc
# 16	smart	NN	14	conj
# 17	.	.	14	punct
# --- Sentence ---
# 1	Though	IN	5	mark
# 2	the	DT	3	det
# 3	plot	NN	5	nsubj
# 4	is	VBZ	5	cop
# 5	great	JJ	13	advcl
# 6	and	CC	5	cc
# 7	really	RB	8	advmod
# 8	moves	VBZ	5	conj
# 9	,	,	13	punct
# 10	it	PRP	13	nsubj
# 11	is	VBZ	13	cop
# 12	the	DT	13	det
# 13	smart	NN	0	root
# 14	``	``	13	punct
# 15	fantasy-revenge	JJ	17	amod
# 16	``	``	17	punct
# 17	ideas	NNS	0	root
# 18	,	,	17	punct
# 19	dialogue	NN	17	conj
# 20	and	CC	17	cc
# 21	strong	JJ	22	amod
# 22	characterizations	NNS	17	conj
# 23	that	WDT	24	nsubj
# 24	keep	VB	17	rcmod
# 25	this	DT	24	dobj
# 26	from	IN	24	prep
# 27	becoming	VBG	26	pcomp
# 28	mean-spirited	JJ	27	acomp
# 29	and	CC	27	cc
# 30	thereby	JJ	33	amod
# 31	enable	JJ	33	amod
# 32	this	DT	33	det
# 33	movie	NN	27	conj
# 34	to	TO	35	aux
# 35	work	VB	27	xcomp
# 36	so	RB	37	advmod
# 37	well	RB	35	advmod
# 38	for	IN	35	prep
# 39	a	DT	41	det
# 40	diverse	JJ	41	amod
# 41	audience	NN	38	pobj
# 42	.	.	17	punct
# --- Sentence ---
# 1	Vaughn	NNP	2	nsubj
# 2	speaks	VBZ	0	root
# 3	in	IN	2	prep
# 4	lightening	NN	5	nn
# 5	fast	NN	6	nn
# 6	dialogue	NN	3	pobj
# 7	most	JJS	2	dobj
# 8	of	IN	7	prep
# 9	the	DT	10	det
# 10	movie	NN	8	pobj
# 11	.	.	2	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	6	nsubj
# 3	and	CC	2	cc
# 4	dialogue	NN	2	conj
# 5	is	VBZ	6	cop
# 6	incredible	JJ	0	root
# 7	because	IN	9	mark
# 8	it	PRP	9	nsubj
# 9	explores	VBZ	6	advcl
# 10	all	DT	12	predet
# 11	the	DT	12	det
# 12	shades	NNS	9	dobj
# 13	of	IN	12	prep
# 14	grey	NN	13	pobj
# 15	in	IN	9	prep
# 16	the	DT	17	det
# 17	characters	NNS	15	pobj
# 18	.	.	6	punct
# --- Sentence ---
# 1	But	CC	12	cc
# 2	really	RB	12	advmod
# 3	,	,	12	punct
# 4	the	DT	5	det
# 5	sub	NN	12	nsubj
# 6	in	IN	5	prep
# 7	this	DT	8	det
# 8	case	NN	6	pobj
# 9	was	VBD	12	cop
# 10	a	DT	12	det
# 11	``	``	12	punct
# 12	set	NN	0	root
# 13	``	``	12	punct
# 14	for	IN	12	prep
# 15	the	DT	19	det
# 16	dialogue	NN	19	nn
# 17	and	CC	16	cc
# 18	character	NN	16	conj
# 19	development	NN	14	pobj
# 20	to	TO	21	aux
# 21	happen	VB	19	infmod
# 22	in	IN	21	prt
# 23	.	.	12	punct
# --- Sentence ---
# 1	``	``	0	root
# 2	The	DT	3	det
# 3	Carpetbaggers	NNP	8	nsubj
# 4	``	``	5	punct
# 5	is	VBZ	8	cop
# 6	a	DT	8	det
# 7	fantastic	JJ	8	amod
# 8	adaptation	NN	16	ccomp
# 9	of	IN	8	prep
# ...
# 9	to	TO	10	aux
# 10	say	VB	8	xcomp
# 11	I	PRP	14	nsubjpass
# 12	was	VBD	14	auxpass
# 13	enormously	RB	14	advmod
# 14	disappointed	VBN	10	ccomp
# 15	with	IN	14	prep
# 16	the	DT	17	det
# 17	dialogue	NN	15	pobj
# 18	and	CC	17	cc
# 19	some	DT	17	conj
# 20	of	IN	19	prep
# 21	the	DT	23	det
# 22	story	NN	23	nn
# 23	adaptation	NN	20	pobj
# 24	to	TO	25	aux
# 25	screen	VB	23	infmod
# 26	.	.	2	erased
# --- Sentence ---
# 1	For	IN	16	prep
# 2	the	DT	4	det
# 3	most	JJS	4	amod
# 4	part	NN	1	pobj
# 5	the	DT	7	det
# 6	bad	JJ	7	amod
# 7	dialogue	NN	4	dep
# 8	and	CC	7	cc
# 9	some	DT	7	conj
# 10	of	IN	9	prep
# 11	the	DT	13	det
# 12	terrible	JJ	13	amod
# 13	acting	NN	10	pobj
# 14	in	IN	4	prep
# 15	parts	NNS	14	pobj
# 16	were	VBD	0	root
# 17	just	RB	19	advmod
# 18	too	RB	19	advmod
# 19	painful	JJ	16	nsubj
# 20	to	TO	21	aux
# 21	sit	VB	19	infmod
# 22	through	IN	21	prt
# 23	.	.	16	punct
# --- Sentence ---
# 1	All	DT	3	predet
# 2	the	DT	3	det
# 3	characters	NNS	5	nsubj
# 4	were	VBD	5	cop
# 5	severely	RB	0	root
# 6	and	CC	5	cc
# 7	tragically	RB	8	advmod
# 8	2-dimensional	JJ	5	conj
# 9	with	IN	8	prep
# 10	none	NN	9	pobj
# 11	of	IN	10	prep
# 12	the	DT	13	det
# 13	depth	NN	11	pobj
# 14	you	PRP	15	nsubj
# 15	get	VBP	10	rcmod
# 16	from	IN	15	prep
# 17	reading	NN	16	pobj
# 18	the	DT	20	det
# 19	graphic	JJ	20	amod
# 20	novel	NN	16	tmod
# 21	and	CC	15	cc
# 22	very	RB	23	advmod
# 23	little	RB	24	amod
# 24	attention	NN	15	conj
# 25	was	VBD	26	auxpass
# 26	paid	VBN	5	dep
# 27	to	TO	26	prep
# 28	developing	VBG	27	pcomp
# 29	better	JJR	30	amod
# 30	dialogue	NN	28	dobj
# 31	suitable	JJ	30	amod
# 32	for	IN	30	prep
# 33	a	DT	36	det
# 34	big	JJ	36	amod
# 35	screen	NN	36	nn
# 36	experience	NN	32	pobj
# 37	.	.	5	punct
# --- Sentence ---
# 1	Purists	NNS	11	nsubj
# 2	and	CC	1	cc
# 3	rabid	VBD	1	conj
# 4	fans	NNS	3	dobj
# 5	of	IN	4	prep
# 6	the	DT	8	det
# 7	graphic	JJ	8	amod
# 8	novel	NN	5	pobj
# 9	may	MD	11	aux
# 10	be	VB	11	cop
# 11	capable	JJ	0	root
# 12	of	IN	11	prep
# 13	somehow	NN	14	nn
# 14	finding	NN	12	pobj
# 15	a	DT	16	det
# 16	way	NN	14	dep
# 17	to	TO	18	aux
# 18	look	VB	16	infmod
# 19	past	JJ	18	acomp
# 20	all	DT	26	det
# 21	the	DT	23	det
# 22	terrible	JJ	23	amod
# 23	acting	NN	26	nn
# 24	and	CC	23	cc
# 25	awful	JJ	23	conj
# 26	dialogue	NN	18	dobj
# 27	that	WDT	29	nsubj
# 28	is	VBZ	29	cop
# 29	rife	VBP	26	rcmod
# 30	throughout	IN	29	prep
# 31	the	DT	32	det
# 32	film	NN	30	pobj
# 33	.	.	11	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	desert	NN	0	root
# 3	,	,	2	punct
# 4	the	DT	5	det
# 5	sex	NN	2	appos
# 6	,	,	2	punct
# 7	the	DT	8	det
# 8	dialogue	NN	2	appos
# 9	,	,	2	punct
# 10	the	DT	11	det
# 11	suspense	NN	2	appos
# 12	,	,	2	punct
# 13	the	DT	14	det
# 14	horror	NN	2	appos
# 15	.	.	2	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	Devil	NNP	4	nsubj
# 3	,	,	2	punct
# 4	voiced	VBD	0	root
# 5	by	IN	4	prep
# 6	Alan	NNP	7	nn
# 7	Cumming	NNP	5	pobj
# 8	,	,	4	punct
# 9	is	VBZ	12	cop
# 10	a	DT	12	det
# 11	loveable	JJ	12	amod
# 12	troublemaker	NN	4	conj
# 13	and	CC	12	cc
# 14	the	DT	15	det
# 15	banter	NN	12	conj
# 16	between	IN	15	prep
# 17	him	PRP	16	pobj
# 18	and	CC	17	cc
# 19	God	NNP	17	conj
# 20	is	VBZ	21	cop
# 21	some	DT	4	dobj
# 22	of	IN	21	prep
# 23	the	DT	25	det
# 24	best	JJS	25	amod
# 25	dialogue	NN	22	pobj
# 26	of	IN	25	prep
# 27	the	DT	28	det
# 28	show	NN	26	pobj
# 29	.	.	4	punct
# --- Sentence ---
# 1	Starring	VBG	33	csubj
# 2	Lionel	NNP	3	nn
# 3	Barrymore	NNP	1	dobj
# 4	,	,	3	punct
# 5	Lionel	NNP	6	nn
# 6	Atwill	NNP	3	appos
# 7	,	,	3	punct
# 8	and	CC	3	cc
# 9	Bela	NNP	10	nn
# 10	Lugosi	NNP	3	conj
# 11	,	,	3	punct
# 12	who	WP	14	nsubj
# 13	only	RB	14	advmod
# 14	has	VBZ	3	rcmod
# 15	several	JJ	17	amod
# 16	actual	JJ	17	amod
# 17	lines	NNS	14	dobj
# 18	of	IN	17	prep
# 19	dialogue	NN	18	pobj
# 20	,	,	3	punct
# 21	and	CC	3	cc
# 22	in	IN	3	conj
# 23	the	DT	25	det
# 24	final	JJ	25	amod
# 25	scene	NN	22	pobj
# 26	,	,	3	punct
# 27	the	DT	28	det
# 28	film	NN	3	appos
# 29	is	VBZ	33	cop
# 30	actually	RB	33	advmod
# 31	a	DT	33	det
# 32	murder	NN	33	nn
# 33	mystery	NN	34	nsubj
# 34	disguised	VBD	0	root
# 35	as	IN	34	prep
# 36	a	DT	38	det
# 37	horror	NN	38	nn
# 38	movie	NN	35	pobj
# 39	,	,	34	punct
# 40	and	CC	34	cc
# 41	one	CD	0	root
# 42	which	WDT	44	nsubj
# 43	continuously	RB	44	advmod
# 44	cheats	VBZ	41	rcmod
# 45	at	IN	44	prep
# 46	the	DT	48	det
# 47	misleading	NN	48	nn
# 48	game	NN	45	pobj
# 49	it	PRP	50	nsubj
# 50	plays	VBZ	44	ccomp
# 51	with	IN	50	prep
# 52	its	PRP$	53	poss
# 53	audience	NN	51	pobj
# 54	.	.	41	punct
# --- Sentence ---
# 1	All	DT	5	nsubj
# 2	of	IN	1	prep
# 3	the	DT	4	det
# 4	characters	NNS	2	pobj
# 5	have	VBP	0	root
# 6	good	JJ	7	amod
# 7	chemistry	NN	5	dobj
# 8	together	RB	5	advmod
# 9	and	CC	5	cc
# 10	the	DT	12	det
# 11	dialogue	NN	12	nn
# 12	tends	NNS	16	nsubj
# 13	to	TO	16	aux
# 14	be	VB	16	cop
# 15	very	RB	16	advmod
# 16	witty	JJ	5	conj
# 17	at	IN	16	prep
# 18	times	NNS	17	pobj
# 19	(	:	5	punct
# 20	esp	NN	5	dobj
# 21	.	.	5	punct
# --- Sentence ---
# 1	With	IN	8	prep
# 2	almost	RB	4	advmod
# 3	no	DT	4	det
# 4	dialogue	NN	1	pobj
# 5	,	,	8	punct
# 6	Kim	NNP	7	nn
# 7	Ki-duk	NNP	8	nsubj
# 8	creates	VBZ	0	root
# 9	an	DT	10	det
# 10	atmosphere	NN	8	dobj
# 11	that	IN	14	nsubj
# 12	is	VBZ	14	cop
# 13	quite	RB	14	advmod
# 14	intense	JJ	10	rcmod
# 15	.	.	8	punct
# --- Sentence ---
# 1	Each	DT	2	det
# 2	episode	NN	5	nsubjpass
# 3	is	VBZ	5	auxpass
# 4	brilliantly	RB	5	advmod
# 5	written	VBN	0	root
# 6	with	IN	5	prep
# 7	the	DT	9	det
# 8	perfect	NN	9	nn
# 9	amount	NN	6	pobj
# 10	of	IN	9	prep
# 11	tension/drama	NNP	10	pobj
# 12	and	CC	9	cc
# 13	very	RB	14	advmod
# 14	believable	JJ	15	amod
# 15	dialogue	NN	9	conj
# 16	and	CC	9	cc
# 17	characters	NNS	9	conj
# 18	.	.	5	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	witty	JJ	0	root
# 5	and	CC	4	cc
# 6	inventive	JJ	4	conj
# 7	,	,	4	punct
# 8	and	CC	4	cc
# 9	it	PRP	11	nsubj
# 10	certainly	RB	11	advmod
# 11	rings	VBZ	4	conj
# 12	true	JJ	11	acomp
# 13	.	.	4	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	storylines	NNS	10	nsubj
# 3	for	IN	2	prep
# 4	the	DT	5	det
# 5	episodes	NNS	3	pobj
# 6	are	VBP	10	cop
# 7	n't	RB	10	neg
# 8	always	RB	10	advmod
# 9	so	RB	10	advmod
# 10	bad	JJ	0	root
# 11	;	:	10	punct
# 12	it	PRP	15	nsubj
# 13	's	VBZ	15	cop
# 14	the	DT	15	det
# 15	dialogue	NN	10	parataxis
# 16	that	IN	18	nsubj
# 17	really	RB	18	advmod
# 18	catches	VBZ	15	rcmod
# 19	the	DT	20	det
# 20	writers	NNS	18	dobj
# 21	.	.	10	punct
# --- Sentence ---
# 1	I	PRP	4	nsubj
# 2	could	MD	4	aux
# 3	n't	RB	4	neg
# 4	help	VB	0	root
# 5	thinking	VBG	4	xcomp
# 6	of	IN	5	prep
# 7	BUFFY	NNP	10	nn
# 8	THE	NNP	10	nn
# 9	VAMPIRE	NNP	10	nn
# 10	SLAYER	NNP	6	pobj
# 11	throughout	IN	5	prep
# 12	this	DT	13	det
# 13	season	NN	11	pobj
# 14	;	:	4	punct
# 15	how	WRB	32	advmod
# 16	witty	NN	18	num
# 17	the	DT	18	det
# 18	dialogue	NN	32	nsubj
# 19	was	VBD	32	parataxis
# 20	,	,	19	punct
# 21	how	WRB	22	advmod
# 22	ingenious	JJ	24	dep
# 23	the	DT	24	det
# 24	storylines	NNS	19	nsubj
# 25	,	,	24	punct
# 26	how	WRB	28	advmod
# 27	utterly	RB	28	advmod
# 28	flawless	JJ	30	amod
# 29	the	DT	30	det
# 30	show	NN	31	dep
# 31	was	VBD	24	rcmod
# 32	.	.	4	advcl
# --- Sentence ---
# 1	The	DT	2	det
# 2	mood	NN	16	nsubj
# 3	,	,	16	punct
# 4	the	DT	6	det
# 5	sensuous	JJ	6	amod
# 6	dialogue	NN	16	conj
# 7	;	:	11	punct
# 8	This	DT	11	nsubj
# 9	is	VBZ	11	cop
# 10	just	RB	11	advmod
# 11	noir	JJ	6	dep
# 12	at	IN	6	prep
# 13	it	PRP	15	nsubj
# 14	's	VBZ	15	cop
# 15	best	JJS	12	pobj
# 16	.	.	0	root
# --- Sentence ---
# 1	The	DT	2	det
# 2	script	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	razor	NN	0	root
# 5	sharp	JJ	4	amod
# 6	with	IN	5	prep
# 7	crackling	JJ	8	amod
# 8	dialogue	NN	6	pobj
# 9	,	,	4	punct
# 10	I	PRP	12	nsubj
# 11	can	MD	12	aux
# 12	recite	VB	4	rcmod
# 13	whole	JJ	14	amod
# 14	passages	NNS	12	dobj
# 15	by	IN	12	prep
# 16	heart	NN	15	pobj
# 17	.	.	4	punct
# --- Sentence ---
# 1	Great	NNP	2	nn
# 2	dialogue	NN	0	root
# 3	,	,	2	punct
# 4	fantastic	JJ	5	amod
# 5	acting	NN	2	appos
# 6	,	,	2	punct
# 7	and	CC	2	cc
# 8	bring	VBG	2	conj
# 9	some	DT	10	det
# 10	Kleenex	NNP	8	dobj
# 11	.	.	2	punct
# --- Sentence ---
# 1	There	EX	2	expl
# 2	is	VBZ	0	root
# 3	also	RB	2	advmod
# 4	underlying	VBG	5	amod
# 5	humor	NN	2	nsubj
# 6	in	IN	5	prep
# 7	a	DT	8	det
# 8	lot	NN	6	pobj
# 9	of	IN	8	prep
# 10	Cheyenne	NNP	12	poss
# 11	's	POS	10	possessive
# 12	dialogue	NN	9	pobj
# 13	which	WDT	15	dobj
# 14	I	PRP	15	nsubj
# 15	missed	VBD	12	rcmod
# 16	as	IN	15	prep
# 17	a	DT	18	det
# 18	child	NN	16	pobj
# 19	,	,	2	punct
# 20	but	CC	2	cc
# 21	as	IN	26	mark
# 22	an	DT	23	det
# 23	adult	NN	26	dobj
# 24	I	PRP	26	nsubj
# 25	thoroughly	RB	26	advmod
# 26	enjoyed	VBD	2	conj
# 27	.	.	2	punct
# --- Sentence ---
# 1	There	EX	2	expl
# 2	is	VBZ	0	root
# 3	only	RB	4	advmod
# 4	sporadic	JJ	7	amod
# 5	and	CC	4	cc
# 6	incidental	JJ	4	conj
# 7	dialogue	NN	2	nsubj
# 8	,	,	2	punct
# 9	but	CC	2	cc
# 10	sound	VB	11	dep
# 11	effects	NNS	13	nsubj
# 12	are	VBP	13	cop
# 13	vital	JJ	2	conj
# 14	to	TO	13	prep
# 15	the	DT	16	det
# 16	movie	NN	14	pobj
# 17	,	,	13	punct
# 18	as	IN	13	prep
# 19	subtle	JJ	22	dep
# 20	and	CC	19	cc
# 21	amusing	JJ	19	conj
# 22	as	IN	18	pcomp
# 23	what	WP	25	dobj
# 24	we	PRP	25	nsubj
# 25	see	VBP	22	pcomp
# 26	.	.	2	punct
# --- Sentence ---
# 1	The	DT	3	det
# 2	dream	NN	3	nn
# 3	sequence	NN	0	root
# 4	which	WDT	6	rel
# 5	features	NNS	6	nsubj
# 6	Claire	VBP	3	rcmod
# 7	Bloom	NNP	10	nsubj
# 8	is	VBZ	10	cop
# 9	both	DT	10	preconj
# 10	witty	NN	6	ccomp
# 11	and	CC	10	cc
# 12	touching	VBG	10	conj
# 13	,	,	3	punct
# 14	with	IN	3	prep
# 15	some	DT	14	pobj
# 16	of	IN	15	prep
# 17	the	DT	18	det
# 18	dialogue	NN	16	pobj
# 19	reaching	VBG	18	partmod
# 20	the	DT	21	det
# 21	heights	NNS	19	dobj
# 22	of	IN	21	prep
# 23	Oscar	NNP	24	nn
# 24	Wilde	NNP	22	pobj
# 25	,	,	0	root
# 26	while	IN	0	root
# 27	the	DT	28	det
# 28	scene	NN	0	root
# 29	in	IN	0	root
# 30	which	WDT	29	pobj
# 31	Calvero	NNP	34	poss
# 32	's	POS	31	possessive
# 33	manager	NN	34	nn
# 34	tells	NNS	0	root
# 35	him	PRP	34	dep
# 36	,	,	34	punct
# 37	``	``	41	punct
# 38	your	PRP$	39	poss
# 39	name	NN	41	nsubj
# 40	is	VBZ	41	cop
# 41	poison	NN	34	appos
# 42	``	``	41	punct
# 43	...	:	41	punct
# 44	well	RB	50	advmod
# 45	it	PRP	50	nsubj
# 46	's	VBZ	50	cop
# 47	a	DT	50	det
# 48	grim	JJ	50	amod
# 49	,	,	50	punct
# 50	unflinching	VBG	41	dep
# 51	,	,	50	punct
# 52	and	CC	50	cc
# 53	completely	RB	54	advmod
# 54	honest	VBP	50	conj
# 55	look	NN	54	dobj
# 56	at	IN	54	prep
# 57	exactly	RB	59	advmod
# 58	the	DT	59	det
# 59	tone	NN	56	pobj
# 60	Chaplin	NNP	62	poss
# 61	's	POS	60	possessive
# 62	life	NN	64	nsubj
# 63	had	VBD	64	aux
# 64	taken	VBN	59	rcmod
# 65	at	IN	64	prep
# 66	the	DT	67	det
# 67	time	NN	65	pobj
# 68	.	.	34	punct
# --- Sentence ---
# 1	There	EX	2	expl
# 2	's	VBZ	0	root
# 3	no	DT	4	det
# 4	action	NN	2	nsubj
# 5	here	RB	4	advmod
# 6	,	,	2	punct
# 7	and	CC	2	cc
# 8	very	RB	9	advmod
# 9	little	RB	15	advmod
# 10	actually	RB	11	advmod
# 11	happens	VBZ	9	ccomp
# 12	,	,	15	punct
# 13	but	CC	15	cc
# 14	the	DT	15	det
# 15	dialogue	NN	2	conj
# 16	and	CC	15	cc
# 17	the	DT	18	det
# 18	attention	NN	15	conj
# 19	to	TO	15	prep
# 20	details	NNS	19	pobj
# 21	are	VBP	23	cop
# 22	so	RB	23	advmod
# 23	strong	JJ	2	nsubj
# 24	,	,	2	punct
# 25	you	PRP	26	nsubj
# 26	find	VBP	2	ccomp
# 27	you	PRP	30	nsubj
# 28	do	VBP	30	aux
# 29	n't	RB	30	neg
# 30	need	VB	26	ccomp
# 31	anything	NN	30	dobj
# 32	more	JJR	31	amod
# 33	;	:	2	punct
# 34	you	PRP	37	nsubj
# 35	can	MD	37	aux
# 36	simply	RB	37	advmod
# 37	revel	VB	2	parataxis
# 38	in	IN	37	prep
# 39	each	DT	40	det
# 40	actor	NN	42	poss
# 41	's	POS	40	possessive
# 42	beauty	NN	38	pobj
# 43	and	CC	42	cc
# 44	condition	NN	42	conj
# 45	.	.	2	punct
# --- Sentence ---
# 1	Though	IN	23	mark
# 2	,	,	4	punct
# 3	there	EX	4	expl
# 4	is	VBZ	23	parataxis
# 5	minimal	JJ	6	amod
# 6	dialogue	NN	4	nsubj
# 7	toward	IN	6	prep
# 8	the	DT	9	det
# 9	end	NN	7	pobj
# 10	(	:	4	punct
# 11	and	CC	4	cc
# 12	one	CD	13	num
# 13	sentence	NN	14	nsubj
# 14	uttered	VBD	4	conj
# 15	early	RB	14	advmod
# 16	on	IN	14	prep
# 17	)	CD	16	pobj
# 18	,	,	14	punct
# 19	Chaplin	NNP	14	dobj
# 20	and	CC	19	cc
# 21	his	PRP$	22	poss
# 22	co-stars	NNS	19	conj
# 23	stick	VBP	36	advcl
# 24	to	TO	23	prep
# 25	the	DT	27	det
# 26	broad	JJ	27	amod
# 27	accessiblity	NN	24	pobj
# 28	of	IN	27	prep
# 29	physical	JJ	30	amod
# 30	comedy	NN	28	pobj
# 31	and	CC	30	cc
# 32	facial	JJ	33	amod
# 33	expressions	NNS	30	conj
# 34	,	,	36	punct
# 35	to	TO	36	aux
# 36	convey	NN	0	root
# 37	to	TO	36	prep
# 38	the	DT	39	det
# 39	audience	NN	37	pobj
# 40	what	WP	42	nsubj
# 41	is	VBZ	42	aux
# 42	going	VBG	39	rcmod
# 43	on	IN	42	prep
# 44	in	IN	43	pcomp
# 45	the	DT	46	det
# 46	plot	NN	44	pobj
# 47	.	.	36	punct
# --- Sentence ---
# 1	)	NN	9	nsubj
# 2	As	IN	5	mark
# 3	you	PRP	5	nsubj
# 4	can	MD	5	aux
# 5	tell	VB	1	infmod
# 6	,	,	9	punct
# 7	I	PRP	9	nsubj
# 8	've	VBP	9	aux
# 9	seen	VBN	0	root
# 10	this	DT	11	det
# 11	movie	NN	9	dobj
# 12	so	IN	0	root
# 13	many	JJ	14	amod
# 14	times	NNS	12	pobj
# 15	I	PRP	18	nsubj
# 16	've	VBP	18	aux
# 17	inadvertently	RB	18	advmod
# 18	memorized	VBN	14	rcmod
# 19	whole	JJ	20	amod
# 20	sections	NNS	18	dobj
# 21	of	IN	20	prep
# 22	dialogue	NN	21	pobj
# 23	.	.	12	pobj
# --- Sentence ---
# 1	The	DT	2	det
# 2	dialogue	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	wonderful	JJ	0	root
# 5	,	,	4	punct
# 6	mind-blowing	JJ	4	conj
# 7	.	.	4	punct
# --- Sentence ---
# 1	This	DT	2	det
# 2	tart	NN	9	nsubj
# 3	,	,	9	punct
# 4	well-scripted	JJ	5	amod
# 5	comedy	NN	9	nsubj
# 6	is	VBZ	9	cop
# 7	a	DT	8	det
# 8	little	RB	9	npadvmod
# 9	light	JJ	0	root
# 10	on	IN	9	prep
# 11	the	DT	12	det
# 12	dancing	NN	10	pobj
# 13	,	,	9	punct
# 14	but	CC	9	cc
# 15	features	NNS	33	dep
# 16	some	DT	33	dep
# 17	of	IN	16	prep
# 18	the	DT	22	det
# 19	best	JJS	22	amod
# 20	,	,	22	punct
# 21	briskest	JJS	22	amod
# 22	dialogue	NN	17	pobj
# 23	that	WDT	24	nsubj
# 24	came	VBD	22	rcmod
# 25	Astaire	NNP	27	poss
# 26	's	POS	25	possessive
# 27	way	NN	24	dobj
# 28	,	,	16	punct
# 29	and	CC	16	cc
# 30	a	DT	31	det
# 31	fine	NN	16	conj
# 32	supporting	VBG	33	amod
# 33	cast	JJ	9	conj
# 34	,	,	9	punct
# 35	including	VBG	9	prep
# 36	the	DT	0	root
# 37	famous	JJ	0	root
# 38	Hollywood	NNP	0	root
# 39	&	CC	38	cc
# 40	quot	NN	38	conj
# 41	;	:	38	punct
# 42	double-talker	NN	38	conj
# 43	,	,	38	punct
# 44	&	CC	38	cc
# 45	quot	NN	38	conj
# 46	;	:	38	punct
# 47	Cliff	NNP	48	nn
# 48	Nazarro	NNP	38	conj
# 49	,	,	0	root
# 50	going	VBG	0	root
# 51	through	IN	50	prep
# 52	his	PRP$	53	poss
# 53	routine	NN	51	pobj
# 54	in	IN	53	prep
# 55	numerous	JJ	56	amod
# 56	scenes	NNS	54	pobj
# 57	.	.	50	erased
# --- Sentence ---
# 1	Having	VBG	2	aux
# 2	mentioned	VBN	0	root
# 3	it	PRP	6	nsubj
# 4	's	VBZ	6	cop
# 5	good	JJ	6	amod
# 6	points	NNS	2	ccomp
# 7	I	PRP	8	nsubj
# 8	have	VBP	6	ccomp
# 9	to	TO	10	aux
# 10	say	VB	8	xcomp
# 11	I	PRP	14	nsubjpass
# 12	was	VBD	14	auxpass
# 13	enormously	RB	14	advmod
# 14	disappointed	VBN	10	ccomp
# 15	with	IN	14	prep
# 16	the	DT	17	det
# 17	dialogue	NN	15	pobj
# 18	and	CC	17	cc
# 19	some	DT	17	conj
# 20	of	IN	19	prep
# 21	the	DT	23	det
# 22	story	NN	23	nn
# 23	adaptation	NN	20	pobj
# 24	to	TO	25	aux
# 25	screen	VB	23	infmod
# 26	.	.	2	erased
# --- Sentence ---
# 1	For	IN	16	prep
# 2	the	DT	4	det
# 3	most	JJS	4	amod
# 4	part	NN	1	pobj
# 5	the	DT	7	det
# 6	bad	JJ	7	amod
# 7	dialogue	NN	4	dep
# 8	and	CC	7	cc
# 9	some	DT	7	conj
# 10	of	IN	9	prep
# 11	the	DT	13	det
# 12	terrible	JJ	13	amod
# 13	acting	NN	10	pobj
# 14	in	IN	4	prep
# 15	parts	NNS	14	pobj
# 16	were	VBD	0	root
# 17	just	RB	19	advmod
# 18	too	RB	19	advmod
# 19	painful	JJ	16	nsubj
# 20	to	TO	21	aux
# 21	sit	VB	19	infmod
# 22	through	IN	21	prt
# 23	.	.	16	punct
# --- Sentence ---
# 1	All	DT	3	predet
# 2	the	DT	3	det
# 3	characters	NNS	5	nsubj
# 4	were	VBD	5	cop
# 5	severely	RB	0	root
# 6	and	CC	5	cc
# 7	tragically	RB	8	advmod
# 8	2-dimensional	JJ	5	conj
# 9	with	IN	8	prep
# 10	none	NN	9	pobj
# 11	of	IN	10	prep
# 12	the	DT	13	det
# 13	depth	NN	11	pobj
# 14	you	PRP	15	nsubj
# 15	get	VBP	10	rcmod
# 16	from	IN	15	prep
# 17	reading	NN	16	pobj
# 18	the	DT	20	det
# 19	graphic	JJ	20	amod
# 20	novel	NN	16	tmod
# 21	and	CC	15	cc
# 22	very	RB	23	advmod
# 23	little	RB	24	amod
# 24	attention	NN	15	conj
# 25	was	VBD	26	auxpass
# 26	paid	VBN	5	dep
# 27	to	TO	26	prep
# 28	developing	VBG	27	pcomp
# 29	better	JJR	30	amod
# 30	dialogue	NN	28	dobj
# 31	suitable	JJ	30	amod
# 32	for	IN	30	prep
# 33	a	DT	36	det
# 34	big	JJ	36	amod
# 35	screen	NN	36	nn
# 36	experience	NN	32	pobj
# 37	.	.	5	punct
# --- Sentence ---
# 1	Purists	NNS	11	nsubj
# 2	and	CC	1	cc
# 3	rabid	VBD	1	conj
# 4	fans	NNS	3	dobj
# 5	of	IN	4	prep
# 6	the	DT	8	det
# 7	graphic	JJ	8	amod
# 8	novel	NN	5	pobj
# 9	may	MD	11	aux
# 10	be	VB	11	cop
# 11	capable	JJ	0	root
# 12	of	IN	11	prep
# 13	somehow	NN	14	nn
# 14	finding	NN	12	pobj
# 15	a	DT	16	det
# 16	way	NN	14	dep
# 17	to	TO	18	aux
# 18	look	VB	16	infmod
# 19	past	JJ	18	acomp
# 20	all	DT	26	det
# 21	the	DT	23	det
# 22	terrible	JJ	23	amod
# 23	acting	NN	26	nn
# 24	and	CC	23	cc
# 25	awful	JJ	23	conj
# 26	dialogue	NN	18	dobj
# 27	that	WDT	29	nsubj
# 28	is	VBZ	29	cop
# 29	rife	VBP	26	rcmod
# 30	throughout	IN	29	prep
# 31	the	DT	32	det
# 32	film	NN	30	pobj
# 33	.	.	11	punct
# --- Sentence ---
# 1	The	DT	5	det
# 2	dialogue	NN	5	nn
# 3	&	CC	2	cc
# 4	plot	NN	2	conj
# 5	situations	NNS	8	nsubj
# 6	are	VBP	8	cop
# 7	very	RB	8	advmod
# 8	funny	JJ	0	root
# 9	.	.	8	punct
# --- Sentence ---
# 1	The	DT	3	det
# 2	sound	NN	3	nn
# 3	quality	NN	12	nsubj
# 4	,	,	12	punct
# 5	however	RB	10	advmod
# 6	,	,	10	punct
# 7	is	VBZ	10	cop
# 8	not	RB	10	neg
# 9	very	RB	10	advmod
# 10	good	JJ	12	dep
# 11	,	,	12	punct
# 12	making	VBG	0	root
# 13	it	PRP	14	nsubj
# 14	difficult	VBD	12	ccomp
# 15	at	IN	18	prep
# 16	times	NNS	15	pobj
# 17	to	TO	18	aux
# 18	understand	VB	14	ccomp
# 19	the	DT	20	det
# 20	dialogue	NN	18	dobj
# 21	.	.	12	punct

# %% [markdown]
# Note that it is not possible to give an arbitrary aspect word as input to the <code style="background-color: #F5F5F5;">load_parsed_dvd_sentences</code> function that we have provided. Since it takes considerable computational resource to produce these data sets, we have pre-assembled a limited amount of suitable data for you to use for your experimentation.
#
# Below is a full list of the aspects words that you can pass to the <code style="background-color: #F5F5F5;">load_parsed_dvd_sentences</code> function. The aspects in blue are the ones that you should definitely explore during these lab sessions (the others are for those interested in further exploration).
#
# - <span style="color:#0000CD">plot</span>
# - <span style="color:#0000CD">characters</span>
# - <span style="color:#0000CD">cinematography</span>
# - <span style="color:#0000CD">dialogue</span>
# - effects
# - acting
# - choreography

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>For each of the aspect words "plot", "characters", "cinematography" and "dialogue", use the function <code style="background-color: #F5F5F5;color:#8B0000">load_parsed_dvd_sentences</code> to retrieve the parses for that aspect and find out how many parsed sentences are retrieved for that aspect.</li>
# </ul>
# </div>

# %% [markdown]
# ## Extracting content from ParsedSentence

# %% [markdown]
# When you call <code style="background-color: #F5F5F5;">load_parsed_dvd_sentences("plot")</code>, you know that each sentence in the list that is returned contains at least one occurrence of the word "plot". However, you do not know the position(s) in the sentence where "plot" occurs. For that you need a reference to the <code style="background-color: #F5F5F5;">BasicToken</code> objects for the occurrences of "plot". A BasicToken object provides access to the token's head and dependants.
#
# The <code style="background-color: #F5F5F5;">ParsedSentence</code> object has a function called <code style="background-color: #F5F5F5;">get_query_tokens</code> which will return a list of occurrences of the string given as its argument in that sentence as BasicToken</code> objects. The example below shows you how to get all the aspect tokens in a sentence and print them out.

# %%
aspect = "dialogue"

# If you have a ParsedSentence object, you can get all the tokens whose form matches the aspect as shown below.
# So instead of just printing the parsed_sentence as in the previous section, get its aspect tokens and print them.
aspect_tokens = parsed_sentence.get_query_tokens(aspect)

# You could iterate over them and print them for inspection
for aspect_token in aspect_tokens:
    print aspect_token
    
# Remember that each token in a ParsedSentence object is BasicToken object
# Out:
# 20	dialogue	NN	18	dobj

# %% [markdown]
# The <code style="background-color: #F5F5F5;">ParsedSentence</code> object has a function for getting the dependants of a token. The code below shows how to use it, and how to print the result.

# %%
# Given a ParsedSentence object, and an aspect token acquired from it (as in the previous section)
# Get all of the dependants of that aspect token.
dependants = parsed_sentence.get_dependants(aspect_token)

# You could print them out for inspection
for dependant in dependants:
    print dependant
# Out:
# 19	the	DT	20	det

# %% [markdown]
# The <code style="background-color: #F5F5F5;">ParsedSentence</code> object has a function for getting the head of a token. The code below shows how to use it, and how to print the result.

# %%
# Given a ParsedSentence object, and an aspect token acquired from it (as in the previous section)
# Get the head of the aspect token

head_token = parsed_sentence.get_head(aspect_token)
print head_token
# Out:
# 18	understand	VB	14	ccomp

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Write a function that takes an aspect ("plot", "characters", "cinematography", and "dialogue") and returns a list of all of the dependants of that aspect in the parsed dvd sentences.</li>
# <li>Write a function that takes an aspect ("plot", "characters", "cinematography", and "dialogue") and returns a list of all of the heads of that aspect in the parsed dvd sentences.</li>
# </ul>
# </div>

# %%
def dependants(aspect):
    dependant_list = []
    parsed_sentences = load_parsed_dvd_sentences(aspect)
    for parsed_sentence in parsed_sentences:
        aspect_tokens = parsed_sentence.get_query_tokens(aspect)
        for aspect_token in aspect_tokens:
            dependants = parsed_sentence.get_dependants(aspect_token)
            for dependant in dependants:
                dependant_list.append(dependant)
    return dependant_list

# %%
def heads(aspect):
    head_list = []
    parsed_sentences = load_parsed_dvd_sentences(aspect)
    for parsed_sentence in parsed_sentences:
        aspect_tokens = parsed_sentence.get_query_tokens(aspect)
        for aspect_token in aspect_tokens:
            head_token = parsed_sentence.get_head(aspect_token)
            head_list.append(head_token)
    return head_list

# %%
a = "plot"
l=dependants(a)
m=heads(a)
for i in l:
    print i
# Out:
# 1	The	DT	2	det
# 15	the	DT	16	det
# 2	the	DT	3	det
# 1	The	DT	3	det
# 2	movie	NN	3	nn
# 33	wonderful	JJ	34	amod
# 5	a	DT	6	det
# 17	the	DT	19	det
# 18	silly	RB	19	advmod
# 13	the	DT	14	det
# 6	the	DT	7	det
# 2	the	DT	3	det
# 1	The	DT	2	det
# 12	a	DT	15	det
# 13	nice	JJ	15	amod
# 14	simple	NN	15	nn
# 1	This	DT	2	det
# 12	a	DT	15	det
# 14	tighter	RBR	15	amod
# 16	than	IN	15	prep
# 10	the	DT	11	det
# 12	of	IN	11	prep
# 9	the	DT	10	det
# 7	the	DT	9	det
# 8	same	JJ	9	amod
# 2	the	DT	3	det
# 6	the	DT	7	det
# 12	revealed	VBN	7	dep
# 1	The	DT	2	det
# 12	the	DT	13	det
# 14	of	IN	13	prep
# 1	The	DT	2	det
# 3	the	DT	4	det
# 7	dark	JJ	9	amod
# 8	hearted	VBN	9	amod
# 4	really	RB	7	advmod
# 5	any	DT	7	det
# 6	other	JJ	7	amod
# 7	the	DT	8	det
# 1	The	DT	2	det
# 18	the	DT	19	det
# 1	Poor	NNP	2	nsubj
# 3	,	,	2	punct
# 4	script	NN	2	dobj
# 5	,	,	2	punct
# 6	acting	VBG	2	xcomp
# 7	,	,	2	punct
# 10	poor	JJ	2	ccomp
# 11	.	.	2	punct
# 19	the	DT	20	det
# 21	,	,	20	punct
# 23	is	VBZ	20	rcmod
# 3	the	DT	4	det
# 1	The	DT	2	det
# 11	the	DT	12	det
# 7	the	DT	8	det
# 20	it	PRP	23	nsubj
# 21	's	VBZ	23	cop
# 22	unique	JJ	23	amod
# 24	and	CC	23	cc
# 26	delivery	NN	23	conj
# 1	The	DT	2	det
# 10	was	VBD	12	cop
# 11	the	DT	12	det
# 36	tries	VBZ	12	rcmod
# 1	The	DT	2	det
# 3	a	DT	7	det
# 4	strong	JJ	7	amod
# 5	,	,	7	punct
# 6	fun	NN	7	nn
# 6	the	DT	7	det
# 8	with	IN	7	prep
# 40	their	PRP$	42	poss
# 41	family	NN	42	nn
# 1	animation	NN	4	nsubj
# 2	=	``	4	punct
# 3	5	CD	4	num
# 5	=	:	4	punct
# 2	the	DT	3	det
# 13	the	DT	14	det
# 9	the	DT	10	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 10	the	DT	11	det
# 12	and	CC	11	cc
# 13	or	CC	11	conj
# 15	flow	NN	11	dep
# 13	the	DT	14	det
# 17	no	DT	19	det
# 18	real	JJ	19	amod
# 20	,	,	19	punct
# 25	features	NNS	19	rcmod
# 26	a	DT	28	det
# 27	fantastic	JJ	28	amod
# 29	and	CC	28	cc
# 31	dialogue	NN	28	conj
# 3	a	DT	5	det
# 4	solid	JJ	5	amod
# 20	the	DT	21	det
# 1	The	DT	3	det
# 2	tenuous	JJ	3	amod
# 4	,	,	3	punct
# 7	serves	VBZ	3	rcmod
# 14	,	,	3	punct
# 20	Garnett	NNP	3	appos
# 23	)	:	3	punct
# 24	,	,	3	punct
# 26	gambler	NN	3	conj
# 27	and	CC	3	cc
# 29	dancer	NN	3	conj
# 15	the	DT	17	det
# 16	underlying	VBG	17	amod
# 9	a	DT	10	det
# 11	by	IN	10	prep
# 4	a	DT	5	det
# 3	the	DT	4	det
# 5	to	TO	4	prep
# 14	the	DT	15	det
# 56	the	DT	57	det
# 1	the	DT	2	det
# 18	a	DT	19	det
# 1	Superb	NNP	2	nsubj
# 3	.	.	2	punct
# 1	More	JJR	2	amod
# 4	the	DT	5	det
# 1	The	DT	2	det
# 31	to	TO	34	aux
# 32	be	VB	34	cop
# 33	a	DT	34	det
# 7	the	DT	8	det
# 1	The	DT	2	det
# 21	the	DT	24	det
# 22	same	JJ	24	amod
# 23	romantic	JJ	24	amod
# 2	the	DT	3	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 9	around	IN	2	prep
# 16	,	,	2	punct
# 3	a	DT	5	det
# 4	good	JJ	5	amod
# 31	logical	JJ	33	amod
# 32	)	NN	33	nn
# 8	the	DT	9	det
# 18	the	DT	19	det
# 1	The	DT	2	det
# 3	a	DT	6	det
# 5	interesting	JJ	6	amod
# 7	,	,	6	punct
# 9	visuals	NNS	6	conj
# 10	,	,	6	punct
# 11	and	CC	6	cc
# 14	characters	NNS	6	conj
# 4	timely	RB	5	advmod
# 27	only	RB	29	advmod
# 28	the	DT	29	det
# 25	a	DT	27	det
# 26	mediocre	NN	27	nn
# 1	An	DT	3	det
# 2	intricate	JJ	3	amod
# 4	.	.	3	punct
# 11	the	DT	12	det
# 1	The	DT	3	det
# 2	main	JJ	3	amod
# 1	It	PRP	6	nsubj
# 2	's	VBZ	6	cop
# 3	not	RB	6	neg
# 4	a	DT	6	det
# 5	revolutionary	JJ	6	amod
# 7	,	,	6	punct
# 8	and	CC	6	cc
# 16	executed	VBN	6	conj
# 29	)	NN	6	dep
# 42	up	IN	6	advmod
# 43	.	.	6	punct
# 7	its	PRP$	9	poss
# 8	minimalist	NN	9	nn
# 1	The	DT	2	det
# 29	,	,	28	punct
# 30	dialogue	NN	28	conj
# 2	the	DT	3	det
# 4	and	CC	3	cc
# 5	actors	NNS	3	conj
# 18	scenes.The	DT	19	det
# 8	a	DT	11	det
# 9	fantastic	JJ	11	amod
# 10	continous	JJ	11	amod
# 12	,	,	11	punct
# 15	sequences	NNS	11	conj
# 17	(	:	19	punct
# 18	and	CC	19	dep
# 20	as	IN	19	prep
# 1	The	DT	2	det
# 6	the	DT	7	det
# 8	the	DT	9	det
# 10	of	IN	9	prep
# 17	a	DT	19	det
# 18	good	JJ	19	amod
# 20	and	CC	19	cc
# 25	lady	NN	19	conj
# 27	shows	VBZ	19	rcmod
# 23	the	DT	24	det
# 25	and	CC	24	cc
# 26	characters	NNS	24	conj
# 15	the	DT	16	det
# 4	The	DT	5	det
# 37	without	IN	36	prep
# 33	a	DT	35	det
# 34	sinister	JJ	35	amod
# 3	the	DT	4	det
# 5	involving	VBG	4	partmod
# 10	brought	VBD	4	partmod
# 5	the	DT	6	det
# 39	a	DT	42	det
# 41	conceived	VBN	42	amod
# 9	the	DT	10	det
# 4	the	DT	5	det
# 6	of	IN	5	prep
# 10	well	RB	5	advmod
# 11	,	,	5	punct
# 10	the	DT	11	det
# 4	the	DT	5	det
# 27	the	DT	28	det
# 1	The	DT	2	det
# 12	an	DT	16	det
# 14	tunnel	NN	16	nn
# 15	escape	NN	16	nn
# 17	,	,	16	punct
# 18	sabotage	NN	16	conj
# 19	and	CC	16	cc
# 24	attempt	NN	16	conj
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	The	DT	2	det
# 10	lifted	VBN	2	dep
# 5	the	DT	6	det
# 7	of	IN	6	prep
# 6	the	DT	8	det
# 7	difficult	NN	8	nn
# 22	an	DT	24	det
# 23	actual	JJ	24	amod
# 11	an	DT	13	det
# 12	intriguing	VBG	13	amod
# 16	requires	VBZ	13	rcmod
# 19	a	DT	21	det
# 20	murder	NN	21	nn
# 13	the	DT	14	det
# 1	The	DT	2	det
# 11	the	DT	12	det
# 11	the	DT	12	det
# 7	the	DT	8	det
# 25	the	DT	26	det
# 19	a	DT	22	det
# 20	tiny	NN	22	nn
# 21	sub	NN	22	nn
# 23	with	IN	22	prep
# 13	the	DT	15	det
# 14	predictable	JJ	15	amod
# 4	the	DT	5	det
# 12	the	DT	13	det
# 1	The	DT	2	det
# 12	clever	NN	13	nn
# 17	the	DT	18	det
# 10	the	DT	11	det
# 30	the	DT	31	det
# 1	The	DT	2	det
# 2	the	DT	3	det
# 9	the	DT	10	det
# 9	they	PRP	10	nsubj
# 12	get	VB	10	xcomp
# 1	Basic	JJ	2	amod
# 3	:	:	2	punct
# 4	Ted	JJ	2	amod
# 7	bellhop	NN	2	dep
# 21	.	.	2	punct
# 1	The	DT	2	det
# 6	well-described	JJ	2	dep
# 1	It	PRP	5	nsubj
# 2	is	VBZ	5	cop
# 3	the	DT	5	det
# 4	necessary	JJ	5	amod
# 6	of	IN	5	prep
# 11	.	.	5	punct
# 3	the	DT	4	det
# 8	little	RB	4	infmod
# 9	farfetched	VBN	4	partmod
# 1	The	DT	3	det
# 2	basic	JJ	3	amod
# 17	the	DT	18	det
# 5	the	DT	6	det
# 10	turned	VBN	6	rcmod
# 12	,	,	6	punct
# 15	hate	VBP	6	dep
# 8	the	DT	9	det
# 11	no	DT	13	det
# 12	logical	JJ	13	amod
# 14	to	TO	13	prep
# 8	the	DT	9	det
# 1	The	DT	2	det
# 25	the	DT	26	det
# 27	of	IN	26	prep
# 1	The	DT	2	det
# 5	the	DT	6	det
# 19	Matrix	NNP	20	nn
# 21	's	POS	20	possessive
# 11	the	DT	12	det
# 9	this	DT	11	det
# 10	crackling	NN	11	nn
# 3	a	DT	4	det
# 6	the	DT	7	det
# 8	or	CC	7	cc
# 9	any	DT	7	conj
# 17	one	CD	18	num
# 21	movie	NN	22	nn
# 24	a	DT	25	det
# 4	the	DT	5	det
# 5	the	DT	6	det
# 1	The	DT	2	det
# 8	a	DT	9	det
# 7	the	DT	8	det
# 11	so.	NN	8	dep
# 6	the	DT	7	det
# 10	give	VB	7	rcmod
# 5	the	DT	6	det
# 8	the	DT	9	det
# 9	detailed	JJ	10	amod
# 3	the	DT	5	det
# 4	basic	JJ	5	amod
# 6	of	IN	5	prep
# 9	a	DT	11	det
# 10	oft-used	JJ	11	amod
# 9	the	DT	10	det
# 23	a	DT	24	det
# 25	:	:	24	punct
# 27	reunion	NN	24	dep
# 1	The	DT	2	det
# 2	the	DT	3	det
# 21	another	DT	22	det
# 29	time	NN	22	dep
# 1	The	DT	2	det
# 12	the	DT	13	det
# 14	and	CC	13	cc
# 15	effects	NNS	13	conj
# 7	and	CC	6	cc
# 8	characters	NNS	6	conj
# 9	(	:	6	punct
# 17	)	VB	6	rcmod
# 1	This	DT	4	nsubj
# 2	was	VBD	4	cop
# 3	the	DT	4	det
# 20	.	.	4	rcmod
# 25	the	DT	26	det
# 25	a	DT	27	det
# 26	horrible	JJ	27	amod
# 29	than	IN	28	prep
# 4	a	DT	6	det
# 5	gripping	JJ	6	amod
# 25	this	DT	26	det
# 1	The	DT	2	det
# 40	about	IN	42	amod
# 41	the	DT	42	det
# 9	assassination	NN	10	nn
# 5	the	DT	6	det
# 7	rebellion	NN	8	nn
# 2	its	PRP$	3	poss
# 11	a	DT	13	det
# 12	unbelievable	JJ	13	amod
# 7	the	DT	8	det
# 11	a	DT	13	det
# 12	secondary	JJ	13	amod
# 15	assassinate	VB	13	infmod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 7	the	DT	9	det
# 8	story	NN	9	nn
# 17	the	DT	18	det
# 5	the	DT	7	det
# 6	general	JJ	7	amod
# 8	and	CC	7	cc
# 11	scheme	NN	7	conj
# 3	the	DT	4	det
# 4	the	DT	5	det
# 15	a	DT	16	det
# 3	a	DT	5	det
# 4	magnificent	NN	5	nn
# 37	the	DT	38	det
# 40	easier	JJR	38	amod
# 1	Very	NNP	3	nn
# 2	predictable	JJ	3	amod
# 4	from	IN	3	prep
# 7	end	VB	3	infmod
# 2	first	JJ	5	nsubj
# 3	is	VBZ	5	cop
# 4	the	DT	5	det
# 6	itself	PRP	5	dep
# 7	.	.	5	punct
# 1	The	DT	2	det
# 4	an	DT	6	det
# 5	incomprehensible	JJ	6	amod
# 7	,	,	6	punct
# 12	sets	VBZ	6	rcmod
# 1	The	DT	2	det
# 18	the	DT	19	det
# 28	an	DT	31	det
# 29	utterly	RB	31	advmod
# 30	dumb	NN	31	nn
# 32	with	IN	31	prep
# 35	company	NN	31	rcmod
# 1	The	DT	2	det
# 1	Very	NNP	5	nn
# 2	interesting	JJ	5	amod
# 6	.	.	5	punct
# 20	a	DT	21	det
# 2	Soldier	NNP	4	poss
# 5	and	CC	4	cc
# 6	acting	VBG	4	conj
# 4	a	DT	9	det
# 6	coherent	JJ	9	amod
# 1	And	CC	5	cc
# 3	about	IN	5	amod
# 4	the	DT	5	det
# 6	?	.	5	punct
# 9	the	DT	10	det
# 11	the	DT	12	det
# 1	The	DT	3	det
# 2	sub	NN	3	nn
# 4	here	RB	3	advmod
# 1	Crazy	NNP	2	nsubj
# 3	twist	NN	2	dobj
# 4	,	,	2	punct
# 5	no	DT	2	dobj
# 6	?	.	2	punct
# 4	a	DT	7	det
# 6	good	JJ	7	amod
# 25	a	DT	26	det
# 1	The	DT	2	det
# 2	acting	JJ	9	nsubj
# 3	is	VBZ	9	cop
# 5	(	NN	9	nn
# 8	The	NNP	9	nn
# 31	this	DT	32	det
# 10	no	DT	11	det
# 12	the	DT	13	det
# 1	Basic	JJ	2	amod
# 3	:	:	2	punct
# 8	outsourcing	VBG	2	dep
# 4	no	DT	5	det
# 41	the	DT	42	det
# 2	series	NN	3	nn
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	on	IN	2	prep
# 1	The	DT	2	det
# 47	the	DT	49	det
# 48	slapped-together	JJ	49	amod
# 1	The	DT	2	det
# 2	the	DT	3	det
# 31	a	DT	35	det
# 32	cloak	NN	35	nn
# 1	The	DT	3	det
# 2	basic	JJ	3	amod
# 4	of	IN	3	prep
# 4	the	DT	6	det
# 5	simple	JJ	6	amod
# 4	a	DT	6	det
# 5	real	JJ	6	amod
# 1	That	DT	5	nsubj
# 2	's	VBZ	5	cop
# 3	basically	RB	5	advmod
# 4	the	DT	5	det
# 6	of	IN	5	prep
# 9	.	.	5	punct
# 29	the	DT	31	det
# 30	main	JJ	31	amod
# 32	of	IN	31	prep
# 1	The	DT	2	det
# 3	:	:	2	punct
# 10	criminal	NN	2	dep
# 17	.	.	2	punct
# 13	no	DT	14	det
# 10	a	DT	11	det
# 15	guess	VB	11	rcmod
# 17	the	DT	18	det
# 19	of	IN	18	prep
# 1	This	DT	7	nsubj
# 4	is	VBZ	7	cop
# 5	a	DT	7	det
# 6	well-used	JJ	7	amod
# 8	.	.	7	punct
# 25	the	DT	27	det
# 26	labyrinth	NN	27	nn
# 18	long	RB	19	advmod
# 22	present	JJ	19	rcmod
# 23	this	DT	25	det
# 24	devious	JJ	25	amod
# 1	The	DT	2	det
# 3	the	DT	4	det
# 16	the	DT	18	det
# 17	``	``	18	punct
# 19	``	``	18	punct
# 20	to	TO	18	prep
# 26	an	DT	28	det
# 27	intelligent	NN	28	nn
# 15	a	DT	16	det
# 17	with	IN	16	prep
# 18	a	DT	19	det
# 20	of	IN	19	prep
# 22	in	IN	19	prep
# 27	bury	VB	19	rcmod
# 1	The	DT	2	det
# 7	the	DT	8	det
# 12	an	DT	14	det
# 13	interesting	JJ	14	amod
# 5	a	DT	8	det
# 6	failed	VBN	8	amod
# 7	assasination	NN	8	nn
# 1	The	DT	2	det
# 4	redundant	JJ	5	amod
# 15	a	DT	18	det
# 17	funny	JJ	18	amod
# 10	apparent	NN	11	nn
# 24	the	DT	26	det
# 25	gay	NN	26	nn
# 27	and	CC	26	cc
# 29	ending	NN	26	conj
# 1	The	DT	2	det
# 5	in	IN	4	prep
# 32	the	DT	33	det
# 4	great	JJ	5	amod
# 6	,	,	5	punct
# 8	moments	NNS	5	conj
# 9	and	CC	5	cc
# 11	characters	NNS	5	conj
# 1	The	DT	2	det
# 8	the	DT	9	det
# 6	this	DT	7	det
# 9	this	DT	10	det
# 6	the	DT	7	det
# 11	the	DT	12	det
# 3	a	DT	6	det
# 5	simple	JJ	6	amod
# 10	characters	NNS	6	rcmod
# 19	-	:	6	punct
# 20	each	DT	6	dep
# 21	with	IN	6	prep
# 7	the	DT	8	det
# 12	the	DT	13	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 5	to	TO	2	prep
# 1	Okay	NNP	8	nsubj
# 2	,	,	8	punct
# 4	there	RB	8	nsubj
# 5	is	VBZ	8	cop
# 6	not	RB	8	neg
# 7	much	JJ	8	amod
# 9	here	RB	8	advmod
# 10	.	.	8	punct
# 6	the	DT	7	det
# 3	the	DT	4	det
# 4	no	DT	5	det
# 1	The	DT	2	det
# 17	a	DT	19	det
# 18	dumb	NN	19	nn
# 12	the	DT	14	det
# 13	main	JJ	14	amod
# 15	and	CC	14	cc
# 17	bit	NN	14	conj
# 13	a	DT	15	det
# 14	decent	NN	15	nn
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	in	IN	2	prep
# 8	:	:	2	punct
# 10	dictator	NN	2	dep
# 3	a	DT	5	det
# 4	secret	NN	5	nn
# 8	revealed	VBN	5	dep
# 8	the	DT	10	det
# 9	basic	JJ	10	amod
# 42	a	DT	43	det
# 44	against	IN	43	prep
# 7	the	DT	8	det
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 7	side-kick	JJ	2	conj
# 1	The	DT	3	det
# 2	basic	JJ	3	amod
# 4	of	IN	3	prep
# 15	this	DT	16	det
# 1	The	DT	2	det
# 2	a	DT	3	det
# 6	foreshadowed	VBD	3	rcmod
# 1	The	DT	2	det
# 5	contrived	VBN	2	dep
# 6	,	,	2	punct
# 9	value	NN	2	appos
# 6	a	DT	8	det
# 7	great	JJ	8	amod
# 15	the	DT	16	det
# 17	including	VBG	16	prep
# 28	the	DT	29	det
# 1	the	DT	2	det
# 2	movie	NN	4	poss
# 10	a	DT	13	det
# 11	rich	JJ	13	amod
# 12	espionage	NN	13	nn
# 6	bad	JJ	7	amod
# 8	and	CC	7	cc
# 13	plague	NN	7	conj
# 1	The	DT	2	det
# 11	the	DT	12	det
# 14	drawn	VBN	12	partmod
# 1	The	DT	2	det
# 9	the	DT	12	det
# 10	time	NN	12	nn
# 11	travel	NN	12	nn
# 13	the	DT	14	det
# 4	not	RB	9	neg
# 6	much	RB	9	advmod
# 7	a	DT	9	det
# 8	``	``	9	punct
# 10	``	``	9	punct
# 11	as	IN	9	prep
# 1	This	DT	7	nsubj
# 2	may	MD	7	aux
# 3	not	RB	7	neg
# 4	be	VB	7	cop
# 5	a	DT	7	det
# 6	strongly	RB	7	advmod
# 8	driven	RB	7	advmod
# 9	selection	NN	7	dep
# 10	,	,	7	punct
# 11	but	CC	7	cc
# 14	gets	VBZ	7	conj
# 19	the	DT	20	det
# 5	the	DT	6	det
# 7	or	CC	6	cc
# 8	story	NN	6	conj
# 8	a	DT	11	det
# 9	good	JJ	11	amod
# 10	spy	NN	11	nn
# 12	with	IN	11	prep
# 3	thing	NN	9	nsubj
# 7	is	VBZ	9	cop
# 8	its	PRP$	9	poss
# 10	and	CC	9	cc
# 12	acting	NN	9	conj
# 13	.	.	9	punct
# 15	the	DT	16	det
# 1	The	DT	2	det
# 4	an	DT	6	det
# 5	entertaining	JJ	6	amod
# 7	with	IN	6	prep
# 1	The	DT	3	det
# 2	story	NN	3	nn
# 2	season	NN	7	tmod
# 3	,	,	7	punct
# 5	season	NN	7	nsubj
# 6	long	RB	7	advmod
# 1	The	DT	2	det
# 28	the	DT	30	det
# 29	overall	JJ	30	amod
# 31	of	IN	30	prep
# 36	the	DT	37	det
# 42	the	DT	43	det
# 13	a	DT	15	det
# 14	military	JJ	15	amod
# 1	Overall	JJ	3	amod
# 2	the	DT	3	det
# 22	a	DT	23	det
# 24	or	CC	23	cc
# 26	merit	NN	23	conj
# 1	The	DT	2	det
# 3	the	DT	5	det
# 4	general	JJ	5	amod
# 36	a	DT	40	det
# 37	powerful	JJ	40	amod
# 38	,	,	40	punct
# 39	coherent	NN	40	nn
# 42	powers	NNS	40	rcmod
# 18	a	DT	20	det
# 19	rich	JJ	20	amod
# 9	the	DT	10	det
# 11	of	IN	10	prep
# 13	beautiful	JJ	10	amod
# 1	The	DT	2	det
# 3	piece	NN	8	nsubj
# 4	is	VBZ	8	cop
# 5	a	DT	8	det
# 6	separate	JJ	8	amod
# 7	short	NN	8	nn
# 9	unto	IN	8	prep
# 11	,	,	8	punct
# 15	supposed	VBN	8	rcmod
# 22	.	.	8	punct
# 2	the	DT	3	det
# 13	a	DT	15	det
# 14	good	JJ	15	amod
# 16	and	CC	15	cc
# 17	movie	NN	15	conj
# 8	the	DT	9	det
# 10	great	JJ	11	amod
# 1	The	DT	2	det
# 17	the	DT	18	det
# 35	that	IN	41	complm
# 36	have	VBP	41	dep
# 39	,	,	41	punct
# 40	strong	JJ	41	amod
# 42	or	CC	41	cc
# 45	message	NN	41	conj
# 9	the	DT	10	det
# 12	that	IN	17	complm
# 13	it	PRP	17	nsubj
# 14	is	VBZ	17	cop
# 15	one	CD	17	num
# 16	continuous	JJ	17	amod
# 1	What	WP	2	nsubj
# 3	?	.	2	punct
# 13	the	DT	14	det
# 13	to	TO	14	aux
# 15	point	NN	14	dobj
# 12	the	DT	13	det
# 14	of	IN	13	prep
# 1	Its	PRP$	2	poss
# 1	The	DT	2	det
# 11	a	DT	14	det
# 13	incendiary	JJ	14	amod
# 40	a	DT	42	det
# 41	linear	JJ	42	amod
# 10	flimsy	NN	11	nn
# 1	The	DT	2	det
# 11	the	DT	12	det
# 36	the	DT	37	det
# 12	the	DT	13	det
# 9	and	CC	8	cc
# 10	story	NN	8	conj
# 16	funny	JJ	17	amod
# 10	though	IN	12	mark
# 11	the	DT	12	det
# 1	The	DT	2	det
# 15	the	DT	16	det
# 14	the	DT	15	det
# 1	The	DT	2	det
# 4	the	DT	5	det
# 6	's	POS	5	possessive
# 18	the	DT	19	det
# 22	the	DT	24	det
# 23	family	NN	24	nn
# 25	-	:	24	punct
# 28	refused	VBN	24	rcmod
# 7	the	DT	8	det
# 23	charming	VBG	24	amod
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 20	substantial	JJ	21	amod
# 11	an	DT	13	det
# 12	amazing	VBG	13	amod
# 14	and	CC	13	cc
# 15	characters	NNS	13	conj
# 18	enjoy	VB	13	rcmod
# 3	a	DT	5	det
# 4	simple-enough	JJ	5	amod
# 4	the	DT	5	det
# 33	often	RB	35	advmod
# 34	silly	RB	35	advmod
# 7	the	DT	8	det
# 9	for	IN	8	prep
# 15	the	DT	16	det
# 21	say	VB	16	rcmod
# 3	the	DT	4	det
# 12	the	DT	13	det
# 20	movie	NN	22	poss
# 50	the	DT	51	det
# 12	the	DT	13	det
# 14	a	DT	18	det
# 16	science	NN	18	nn
# 17	fiction	NN	18	nn
# 1	The	DT	2	det
# 6	a	DT	7	det
# 5	the	DT	6	det
# 4	minor	NN	5	nn
# 1	The	DT	2	det
# 11	the	DT	12	det
# 1	In	IN	17	prep
# 3	,	,	17	punct
# 6	thing	NN	17	nsubj
# 15	is	VBZ	17	cop
# 16	the	DT	17	det
# 18	.	.	17	punct
# 16	a	DT	18	det
# 17	horrible	JJ	18	amod
# 19	,	,	18	punct
# 21	director	NN	18	conj
# 12	the	DT	13	det
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 4	dialog	NN	2	conj
# 24	hardly	RB	26	advmod
# 25	a	DT	26	det
# 46	the	DT	47	det
# 4	The	DT	6	det
# 5	``	``	6	punct
# 7	``	``	6	punct
# 8	and	CC	6	cc
# 9	characters	NNS	6	conj
# 12	of	IN	11	prep
# 2	the	DT	3	det
# 4	a	DT	5	det
# 8	follow	VB	5	rcmod
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 11	around	IN	2	prep
# 15	,	,	2	punct
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 6	with	IN	2	prep
# 4	the	DT	5	det
# 6	and	CC	5	cc
# 8	action	NN	5	conj
# 22	the	DT	24	det
# 23	entire	JJ	24	amod
# 4	the	DT	5	det
# 10	sense	NN	5	dep
# 3	a	DT	4	det
# 8	a	DT	9	det
# 1	The	DT	2	det
# 8	the	DT	9	det
# 4	the	DT	5	det
# 1	The	DT	2	det
# 16	each	DT	17	det
# 18	and	CC	17	cc
# 21	progresses	NNS	17	conj
# 1	The	DT	2	det
# 12	excellent	NN	13	nn
# 1	The	DT	2	det
# 37	The	DT	38	det
# 3	Sturges	NNP	5	poss
# 1	The	DT	2	det
# 1	The	DT	2	det
# 7	the	DT	8	det
# 9	and	CC	8	cc
# 11	suspense	NN	8	conj
# 19	a	DT	21	det
# 20	clear-cut	JJ	21	amod
# 8	that	IN	13	complm
# 9	this	DT	13	nsubj
# 10	was	VBD	13	cop
# 11	a	DT	13	det
# 12	flimsy	NN	13	nn
# 14	and	CC	13	cc
# 16	of	IN	13	conj
# 3	the	DT	4	det
# 1	This	DT	6	nsubj
# 2	is	VBZ	6	cop
# 3	n't	RB	6	neg
# 4	a	DT	6	det
# 5	new	JJ	6	amod
# 7	;	:	6	punct
# 10	seen	VBN	6	parataxis
# 21	.	.	6	punct
# 11	more	RBR	12	advmod
# 7	a	DT	8	det
# 9	the	DT	12	det
# 11	man	NN	12	nn
# 13	of	IN	12	prep
# 1	The	DT	2	det
# 22	so	RB	24	advmod
# 23	the	DT	24	det
# 4	a	DT	5	det
# 6	with	IN	5	prep
# 24	a	DT	27	det
# 26	clumsy	JJ	27	amod
# 1	The	DT	2	det
# 13	the	DT	14	det
# 1	The	DT	2	det
# 17	the	DT	18	det
# 11	the	DT	12	det
# 12	a	DT	13	det
# 11	minor	NN	12	nn
# 19	a	DT	20	det
# 21	based	VBN	20	partmod
# 29	a	DT	30	det
# 31	driven	VBN	30	partmod
# 19	the	DT	21	det
# 20	surface	NN	21	nn
# 5	good.The	JJ	6	amod
# 4	the	DT	5	det
# 1	The	DT	2	det
# 7	the	DT	8	det
# 10	the	DT	11	det
# 1	The	DT	2	det
# 7	the	DT	8	det
# 12	horror	NN	13	nn
# 3	such	JJ	5	amod
# 4	a	DT	5	det
# 21	the	DT	22	det
# 23	to	TO	22	prep
# 36	)	:	41	punct
# 37	and	CC	41	dep
# 38	an	DT	41	det
# 39	intricate	JJ	41	amod
# 40	byzantine	NN	41	nn
# 43	keeps	VBZ	41	rcmod
# 1	The	DT	2	det
# 3	's	POS	2	possessive
# 5	simple	JJ	2	amod
# 7	Janey	NNP	2	dep
# 17	the	DT	18	det
# 4	the	DT	5	det
# 1	The	DT	3	det
# 2	Rambaldi	NNP	3	nn
# 1	The	DT	2	det
# 1	The	DT	2	det
# 7	satellite	NN	8	nn
# 25	the	DT	26	det
# 28	think	VBP	26	rcmod
# 1	The	DT	4	det
# 2	overall	JJ	4	amod
# 3	season	NN	4	nn
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	The	DT	2	det
# 1	The	DT	3	det
# 2	main	JJ	3	amod
# 4	enough	RB	5	advmod
# 7	understand	VB	5	xcomp
# 13	.	.	5	punct
# 25	the	DT	26	det
# 5	the	DT	6	det
# 7	the	DT	8	det
# 26	the	DT	27	det
# 8	no	DT	9	det
# 10	,	,	9	punct
# 12	theme	NN	9	appos
# 13	,	,	9	punct
# 15	characterisation	NN	9	appos
# 15	the	DT	16	det
# 35	the	DT	36	det
# 3	the	DT	4	det
# 13	)	NNP	18	poss
# 15	ailing	VBG	18	amod
# 17	cannabis	NNS	18	nn
# 19	,	,	18	punct
# 20	and	CC	18	cc
# 24	blooms	NNS	18	conj
# 1	The	DT	2	det
# 23	forrgetible	JJ	25	amod
# 24	the	DT	25	det
# 29	the	DT	30	det
# 31	to	TO	30	prep
# 33	the	DT	35	det
# 34	implausible	JJ	35	amod
# 12	``	``	13	punct
# 14	``	``	13	punct
# 15	in	IN	13	prep
# 33	the	DT	34	det
# 5	the	DT	6	det
# 60	the	DT	61	det
# 62	of	IN	61	prep
# 10	the	DT	11	det
# 12	of	IN	11	prep
# 1	The	DT	2	det
# 3	the	DT	4	det
# 22	the	DT	23	det
# 11	the	DT	12	det
# 3	the	DT	4	det
# 5	and	CC	4	cc
# 8	art	NN	4	conj
# 9	and	CC	4	cc
# 12	draw	VB	4	conj
# 2	the	DT	3	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 17	the	DT	18	det
# 1	The	DT	2	det
# 3	in	IN	2	prep
# 5	the	DT	6	det
# 29	the	DT	30	det
# 1	The	DT	2	det
# 1	This	DT	2	det
# 14	the	DT	15	det
# 8	the	DT	9	det
# 10	of	IN	9	prep
# 13	pilot	NN	9	tmod
# 1	The	DT	3	det
# 2	central	JJ	3	amod
# 4	of	IN	3	prep
# 8	from	IN	3	prep
# 24	the	DT	25	det
# 29	is	VBZ	25	ccomp
# 14	his	PRP$	15	poss
# 3	's	POS	7	dep
# 4	about	IN	7	amod
# 5	the	DT	7	det
# 6	entire	JJ	7	amod
# 8	of	IN	7	prep
# 11	.	.	7	erased
# 1	In	IN	10	prep
# 3	,	,	10	punct
# 4	it	PRP	10	nsubj
# 5	's	VBZ	10	cop
# 6	the	DT	10	det
# 7	simple	JJ	10	amod
# 9	SNATCHERS	NNP	10	nn
# 11	.	.	10	punct
# 8	a	DT	11	det
# 10	acted	VBN	11	amod
# 12	combined	VBN	11	partmod
# 19	the	DT	21	det
# 20	indistinct	NN	21	nn
# 22	and	CC	21	cc
# 23	characters	NNS	21	conj
# 11	the	DT	12	det
# 20	the	DT	21	det
# 8	the	DT	9	det
# 1	The	DT	2	det
# 8	the	DT	9	det
# 3	a	DT	5	det
# 4	shadowy	NN	5	nn
# 6	involving	VBG	5	partmod
# 10	,	,	5	punct
# 13	movement	NN	5	conj
# 14	and	CC	5	cc
# 15	guns	NNS	5	conj
# 42	a	DT	43	det
# 45	blow	VB	43	infmod
# 11	the	DT	12	det
# 1	Just	RB	4	advmod
# 2	an	DT	4	det
# 3	interesting	JJ	4	amod
# 6	flows	VBZ	4	rcmod
# 2	no	DT	3	det
# 1	The	DT	2	det
# 8	the	DT	9	det
# 6	the	DT	7	det
# 10	the	DT	11	det
# 20	the	DT	21	det
# 22	and	CC	21	cc
# 25	kick	NN	21	conj
# 26	in	IN	21	prep
# 1	The	DT	2	det
# 10	the	DT	12	det
# 11	silly	RB	12	advmod
# 1	The	DT	2	det
# 15	a	DT	16	det
# 3	the	DT	4	det
# 8	adorable	JJ	9	amod
# 23	the	DT	24	det
# 8	the	DT	9	det
# 1	The	DT	2	det
# 26	and	CC	25	cc
# 27	some	DT	25	conj
# 36	the	DT	38	det
# 37	murder	NN	38	nn
# 1	The	DT	2	det
# 16	the	DT	17	det
# 10	the	DT	11	det
# 12	of	IN	11	prep
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 5	an	DT	7	det
# 6	interesting	JJ	7	amod
# 3	the	DT	4	det
# 15	the	DT	16	det
# 17	,	,	16	punct
# 18	something	NN	16	appos
# 8	the	DT	9	det
# 1	The	DT	2	det
# 3	's	POS	2	possessive
# 5	simple	JJ	2	amod
# 7	in	IN	2	dep
# 13	teraformed	VBN	2	rcmod
# 20	.	.	2	punct
# 6	a	DT	7	det
# 30	good	JJ	31	amod
# 1	The	DT	3	det
# 2	convoluted	VBN	3	amod
# 4	and	CC	3	cc
# 1	The	DT	2	det
# 11	an	DT	13	det
# 12	assassination	NN	13	nn
# 41	a	DT	43	det
# 42	formulaic	JJ	43	amod
# 40	a	DT	42	det
# 41	good	JJ	42	amod
# 43	with	IN	42	prep
# 11	the	DT	12	det
# 1	Now	RB	15	advmod
# 2	,	,	15	punct
# 4	of	IN	15	prep
# 12	,	,	15	punct
# 13	but	CC	15	cc
# 14	probably	RB	15	advmod
# 16	less	JJR	15	dobj
# 17	.	.	15	punct
# 15	the	DT	17	det
# 16	``	``	17	punct
# 18	``	``	17	punct
# 19	of	IN	17	prep
# 3	the	DT	5	det
# 4	basic	JJ	5	amod
# 6	by	IN	5	prep
# 8	:	:	5	punct
# 14	Captain	NNP	5	dep
# 15	,	,	5	punct
# 16	and	CC	5	cc
# 17	hijacks	NNS	5	conj
# 20	,	,	5	punct
# 21	and	CC	5	cc
# 22	sets	NNS	5	conj
# 1	The	DT	2	det
# 2	the	DT	5	det
# 3	perfect	NN	5	nn
# 4	murder	NN	5	nn
# 14	cause	VB	12	infmod
# 8	the	DT	10	det
# 9	alluring	NN	10	nn
# 1	The	DT	2	det
# 1	The	DT	2	det
# 40	this	DT	41	det
# 11	a	DT	12	det
# 16	outstanding	JJ	12	rcmod
# 17	the	DT	18	det
# 1	The	DT	2	det
# 2	A	DT	3	det
# 17	to	TO	18	aux
# 19	revenge	NN	18	dobj
# 9	thief	NN	4	ccomp
# 24	his	PRP$	29	poss
# 25	ex-wife	JJ	29	amod
# 26	then	RB	29	advmod
# 27	the	DT	29	det
# 28	revenge	NN	29	nn
# 31	charted	VBD	29	rcmod
# 1	The	DT	2	det
# 37	a	DT	38	det
# 39	for	IN	38	prep
# 5	a	DT	6	det
# 13	the	DT	14	det
# 6	the	DT	7	det
# 3	the	DT	4	det
# 3	the	DT	4	det
# 1	The	DT	2	det
# 4	the	DT	5	det
# 1	The	DT	2	det
# 3	's	POS	2	possessive
# 2	the	DT	4	det
# 3	wacky	JJ	4	amod
# 7	Wallace	NN	4	dep
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 18	secondary	JJ	19	amod
# 1	The	DT	2	det
# 49	the	DT	50	det
# 7	the	DT	8	det
# 17	a	DT	19	det
# 18	non-formulaic	JJ	19	amod
# 1	The	DT	2	det
# 12	the	DT	13	det
# 25	a	DT	28	det
# 26	forced	VBN	28	amod
# 27	love	NN	28	nn
# 1	The	DT	2	det
# 29	the	DT	30	det
# 9	a	DT	11	det
# 10	simple	JJ	11	amod
# 13	went	VBD	11	rcmod
# 1	The	DT	2	det
# 4	a	DT	5	det
# 6	to	TO	5	prep
# 5	that	IN	8	complm
# 6	there	EX	8	expl
# 7	also	RB	8	advmod
# 9	elements	NNS	8	dobj
# 10	about	IN	8	prep
# 27	the	DT	28	det
# 13	an	DT	15	det
# 14	actual	JJ	15	amod
# 16	a	DT	18	det
# 17	goofy	NN	18	nn
# 1	The	DT	2	det
# 29	a	DT	31	det
# 30	little	RB	31	advmod
# 1	The	DT	4	det
# 3	simple	JJ	4	amod
# 7	brothers	NNS	4	dep
# 1	The	DT	2	det
# 2	the	DT	3	det
# 6	the	DT	7	det
# 8	of	IN	7	prep
# 14	the	DT	15	det
# 16	here	RB	15	advmod
# 7	evil	JJ	8	amod
# 9	but	CC	8	cc
# 12	more	RBR	8	advmod
# 10	the	DT	12	det
# 11	main	JJ	12	amod
# 1	The	DT	2	det
# 20	the	DT	21	det
# 22	itself	PRP	21	dep
# 23	(	:	21	punct
# 25	due	JJ	21	dep
# 14	the	DT	15	det
# 29	interesting	JJ	30	amod
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	The	DT	2	det
# 2	the	DT	3	det
# 32	this	DT	34	det
# 33	particular	JJ	34	amod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 9	the	DT	10	det
# 23	kill	VB	21	infmod
# 9	profound	NN	10	nn
# 15	one	CD	16	num
# 9	no	DT	10	det
# 5	the	DT	6	det
# 11	the	DT	13	det
# 12	major	JJ	13	amod
# 1	The	DT	2	det
# 8	the	DT	9	det
# 18	the	DT	20	det
# 19	nonexistent	NN	20	nn
# 1	Simple	NNP	2	nsubj
# 3	.	.	2	punct
# 10	a	DT	11	det
# 14	unravels	VBZ	11	rcmod
# 9	insulting	VBG	10	amod
# 11	and	CC	10	cc
# 13	acting	NN	10	conj
# 16	.	.	10	erased
# 1	The	DT	2	det
# 35	the	DT	36	det
# 27	film	NN	29	poss
# 2	The	DT	4	det
# 3	basic	JJ	4	amod
# 31	a	DT	32	det
# 34	give	VB	32	infmod
# 21	the	DT	23	det
# 22	flimsy	NN	23	nn
# 1	The	DT	2	det
# 17	million	NN	18	nn
# 13	a	DT	14	det
# 15	for	IN	14	prep
# 6	the	DT	7	det
# 8	of	IN	7	prep
# 1	The	DT	2	det
# 12	the	DT	13	det
# 2	the	DT	3	det
# 6	the	DT	7	det
# 35	a	DT	37	det
# 36	huge	JJ	37	amod
# 11	the	DT	14	det
# 12	Murai	NNP	14	nn
# 13	vaccine	NN	14	nn
# 22	that	IN	28	nsubj
# 23	are	VBP	28	cop
# 26	much	RB	28	amod
# 27	about	IN	28	amod
# 29	as	IN	28	prep
# 30	familiar	JJ	31	amod
# 33	goes	VBZ	31	rcmod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 7	The	DT	8	det
# 4	a	DT	5	det
# 6	like	IN	5	prep
# 8	...	:	5	punct
# 11	go	VBP	5	dep
# 8	it	PRP	14	nsubj
# 9	may	MD	14	aux
# 10	be	VB	14	cop
# 11	a	DT	14	det
# 12	far	JJ	14	amod
# 13	fetched	VBN	14	amod
# 15	like	IN	14	prep
# 1	The	DT	2	det
# 1	The	DT	2	det
# 5	a	DT	7	det
# 6	coherent	NN	7	nn
# 10	the	DT	11	det
# 2	the	DT	3	det
# 13	an	DT	15	det
# 14	intricate	JJ	15	amod
# 16	in	IN	15	prep
# 29	the	DT	30	det
# 1	The	DT	2	det
# 16	any	DT	18	det
# 17	old	JJ	18	amod
# 10	the	DT	11	det
# 4	the	DT	5	det
# 15	the	DT	17	det
# 16	main	JJ	17	amod
# 13	the	DT	15	det
# 14	entire	JJ	15	amod
# 16	in	IN	15	prep
# 8	the	DT	9	det
# 1	This	DT	2	det
# 4	the	DT	5	det
# 16	Kennedy	NNP	20	poss
# 18	eventual	JJ	20	amod
# 19	burial	NN	20	nn
# 21	to	TO	20	prep
# 5	excellent	NN	6	nn
# 43	vapid	JJ	44	amod
# 5	the	DT	6	det
# 1	The	DT	2	det
# 13	this	DT	14	det
# 17	the	DT	18	det
# 15	the	DT	16	det
# 1	The	DT	2	det
# 3	the	DT	4	det
# 5	of	IN	4	prep
# 1	A	DT	4	det
# 2	second	JJ	4	amod
# 3	sub	NN	4	nn
# 5	the	DT	7	det
# 6	annoying	NN	7	nn
# 9	the	DT	10	det
# 1	The	DT	2	det
# 26	,	,	25	punct
# 27	storyline	NN	25	conj
# 28	and	CC	25	cc
# 30	development	NN	25	conj
# 12	a	DT	13	det
# 15	grabs	VBZ	13	rcmod
# 11	the	DT	12	det
# 13	than	IN	12	prep
# 9	the	DT	10	det
# 1	The	DT	2	det
# 2	an	DT	4	det
# 3	intricate	JJ	4	amod
# 10	the	DT	11	det
# 19	the	DT	20	det
# 13	subtle	JJ	14	amod
# 7	a	DT	8	det
# 9	than	IN	8	prep
# 1	The	DT	2	det
# 3	to	TO	2	prep
# 6	or	CC	2	cc
# 8	called	VBN	2	conj
# 22	the	DT	23	det
# 1	The	DT	2	det
# 7	the	DT	8	det
# 4	the	DT	5	det
# 7	a	DT	9	det
# 8	twisting	NN	9	nn
# 59	)	:	9	dep
# 26	of	IN	25	prep
# 5	the	DT	6	det
# 7	of	IN	6	prep
# 3	The	DT	5	det
# 4	``	``	5	punct
# 11	the	DT	12	det
# 18	one	CD	20	num
# 19	effective	JJ	20	amod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 9	it	PRP	11	nsubj
# 10	's	VBZ	11	cop
# 30	a	DT	31	det
# 33	hates	NNS	31	dep
# 1	The	DT	2	det
# 28	the	DT	29	det
# 6	a	DT	8	det
# 7	sappy	NN	8	nn
# 22	a	DT	25	det
# 23	putative	JJ	25	amod
# 24	dramatic	JJ	25	amod
# 1	The	DT	2	det
# 2	the	DT	3	det
# 6	the	DT	7	det
# 8	's	POS	7	possessive
# 1	The	DT	2	det
# 30	the	DT	31	det
# 32	from	IN	31	prep
# 4	the	DT	5	det
# 6	in	IN	5	prep
# 8	the	DT	9	det
# 10	...	:	9	punct
# 12	dialogue	NN	9	dep
# 1	The	DT	2	det
# 4	a	DT	6	det
# 5	bland	NN	6	nn
# 17	a	DT	18	det
# 19	without	IN	18	prep
# 6	a	DT	8	det
# 7	good	JJ	8	amod
# 14	a	DT	16	det
# 15	credible	JJ	16	amod
# 17	and	CC	16	cc
# 19	things	NNS	16	conj
# 21	say	VB	16	infmod
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 4	motivations	NNS	2	conj
# 4	cute	JJ	5	amod
# 12	a	DT	13	det
# 14	,	,	13	punct
# 16	scenes	NNS	13	appos
# 17	,	,	13	punct
# 19	twist	NN	13	appos
# 22	,	,	13	punct
# 23	and	CC	13	cc
# 26	comedy	JJ	13	conj
# 5	the	DT	6	det
# 17	the	DT	18	det
# 1	A	DT	5	det
# 4	written	VBN	5	amod
# 6	and	CC	5	cc
# 23	spurs	NNS	25	dobj
# 24	the	DT	25	det
# 1	The	DT	2	det
# 5	a	DT	7	det
# 6	real	JJ	7	amod
# 1	The	DT	2	det
# 7	the	DT	8	det
# 19	the	DT	20	det
# 23	the	DT	24	det
# 26	bothered	VBN	24	rcmod
# 13	a	DT	15	det
# 14	definitive	JJ	15	amod
# 7	the	DT	8	det
# 11	an	DT	13	det
# 12	interesting	JJ	13	amod
# 5	the	DT	6	det
# 5	a	DT	6	det
# 8	seems	VBZ	6	rcmod
# 11	a	DT	13	det
# 12	detailed	JJ	13	amod
# 14	and	CC	13	cc
# 16	middle	NN	13	conj
# 15	the	DT	16	det
# 1	the	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	for	IN	2	prep
# 5	not	RB	7	neg
# 6	its	PRP$	7	poss
# 1	The	DT	2	det
# 53	an	DT	56	det
# 55	thickening	VBG	56	amod
# 58	keep	VB	56	infmod
# 21	the	DT	23	det
# 22	entire	JJ	23	amod
# 15	the	DT	16	det
# 17	about	IN	16	prep
# 13	the	DT	14	det
# 4	the	DT	5	det
# 1	This	DT	2	det
# 1	The	DT	2	det
# 30	the	DT	32	det
# 31	entire	JJ	32	amod
# 17	the	DT	18	det
# 1	The	DT	2	det
# 2	the	DT	3	det
# 4	of	IN	3	prep
# 10	a	DT	13	det
# 11	good	JJ	13	amod
# 12	story	NN	13	nn
# 20	the	DT	21	det
# 22	,	,	21	punct
# 24	gives	VBZ	21	rcmod
# 1	It	PRP	4	nsubj
# 2	is	VBZ	4	cop
# 3	a	DT	4	det
# 8	done	VBN	4	rcmod
# 10	,	,	4	punct
# 11	however	RB	4	advmod
# 13	Moore	NNP	4	dep
# 14	as	IN	4	prep
# 36	.	.	4	punct
# 2	short	JJ	4	amod
# 3	the	DT	4	det
# 1	The	DT	2	det
# 10	any	DT	11	det
# 13	distract	VB	11	infmod
# 1	cool	NN	2	nsubj
# 5	Way	NNP	2	dobj
# 6	to	TO	2	prep
# 16	,	,	2	punct
# 18	portrayed	VBD	2	ccomp
# 22	)	:	2	punct
# 29	pilot	NN	2	parataxis
# 35	!	.	2	punct
# 1	The	DT	2	det
# 17	the	DT	18	det
# 19	behind	IN	18	prep
# 1	Dumb	NNP	2	nsubj
# 3	-	:	2	punct
# 6	better	RBR	2	advmod
# 14	.	.	2	punct
# 7	the	DT	8	det
# 9	of	IN	8	prep
# 5	the	DT	6	det
# 17	big	JJ	18	amod
# 12	the	DT	13	det
# 1	The	DT	2	det
# 1	It	PRP	6	nsubj
# 2	is	VBZ	6	cop
# 3	such	JJ	6	amod
# 4	a	DT	6	det
# 5	unique	JJ	6	amod
# 7	and	CC	6	cc
# 9	acted	VBD	6	conj
# 10	.	.	6	punct
# 1	The	DT	2	det
# 1	Only	RB	4	advmod
# 2	the	DT	4	det
# 3	frame	NN	4	nn
# 5	involving	VBG	4	partmod
# 1	The	DT	2	det
# 4	the	DT	5	det
# 2	follows	VBZ	7	csubj
# 3	is	VBZ	7	cop
# 4	a	DT	7	det
# 6	complex	JJ	7	amod
# 6	the	DT	7	det
# 8	a	DT	9	det
# 10	or	CC	9	cc
# 13	story	NN	9	conj
# 8	the	DT	9	det
# 1	It	PRP	7	nsubj
# 2	's	VBZ	7	cop
# 3	not	RB	7	neg
# 5	much	RB	7	advmod
# 6	the	DT	7	det
# 19	characters	NNS	7	rcmod
# 26	.	.	7	punct
# 3	some	DT	4	det
# 5	there	RB	4	advmod
# 9	the	DT	10	det
# 11	or	CC	10	cc
# 13	acting	JJ	10	conj
# 4	the	DT	5	det
# 2	the	DT	3	det
# 12	the	DT	14	det
# 13	peculiar	NN	14	nn
# 22	an	DT	24	det
# 23	amazing	NN	24	nn
# 16	hypnosis	NN	18	nn
# 17	``	``	18	punct
# 14	a	DT	15	det
# 7	film	NN	9	poss
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	The	DT	2	det
# 17	to	TO	18	aux
# 19	development	NN	18	dobj
# 1	It	PRP	3	nsubjpass
# 2	is	VBZ	3	auxpass
# 4	driven	RB	3	advmod
# 5	,	,	3	punct
# 7	sticking	VBG	3	xcomp
# 12	,	,	3	punct
# 13	and	CC	3	cc
# 16	's	VBZ	3	conj
# 29	,	,	3	punct
# 32	gets	VBZ	3	ccomp
# 44	.	.	3	punct
# 6	the	DT	7	det
# 27	good	JJ	28	amod
# 21	the	DT	22	det
# 35	a	DT	37	det
# 36	sinister	JJ	37	amod
# 2	The	DT	3	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	A	DT	6	det
# 4	minded	VBN	6	amod
# 5	romantic	JJ	6	amod
# 7	with	IN	6	prep
# 8	the	DT	9	det
# 10	about	IN	9	prep
# 1	The	DT	2	det
# 3	,	,	2	punct
# 6	is	VBZ	2	rcmod
# 9	,	,	2	punct
# 10	deals	NNS	2	conj
# 14	,	,	2	punct
# 15	and	CC	2	cc
# 16	features	NNS	2	conj
# 24	takes	VBZ	2	rcmod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 2	the	DT	3	det
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 5	cast	NN	2	conj
# 1	Not	RB	5	neg
# 2	just	RB	5	advmod
# 3	an	DT	5	det
# 4	ordinary	JJ	5	amod
# 12	rather	RB	16	advmod
# 13	a	DT	16	det
# 14	wide	JJ	16	amod
# 15	ranging	NN	16	nn
# 18	covers	VBZ	16	rcmod
# 27	.	.	16	erased
# 9	the	DT	10	det
# 1	That	DT	6	nsubj
# 2	's	VBZ	6	cop
# 4	much	JJ	6	amod
# 5	the	DT	6	det
# 7	and	CC	6	cc
# 9	glory	NN	6	conj
# 17	plot	NN	6	dep
# 18	,	,	6	punct
# 19	but	CC	6	cc
# 22	journey	NN	6	conj
# 23	.	.	6	punct
# 14	is	VBZ	17	cop
# 15	not	RB	17	neg
# 16	its	PRP$	17	poss
# 1	Not	RB	5	neg
# 2	a	DT	5	det
# 4	involved	VBN	5	amod
# 6	,	,	5	punct
# 7	but	CC	5	cc
# 8	then	RB	5	advmod
# 11	seen	VBN	5	ccomp
# 17	,	,	5	punct
# 18	but	CC	5	cc
# 23	film	NN	5	conj
# 24	.	.	5	punct
# 7	the	DT	8	det
# 12	a	DT	15	det
# 13	halfway	NN	15	nn
# 14	decent	NN	15	nn
# 26	the	DT	27	det
# 4	the	DT	5	det
# 27	the	DT	28	det
# 1	Forget	NN	2	nsubj
# 5	comes	VBZ	2	advcl
# 9	.	.	2	punct
# 3	more	JJR	4	amod
# 5	and	CC	4	cc
# 7	anim	NN	4	conj
# 33	its	PRP$	37	poss
# 34	surreal	NN	37	nn
# 1	The	DT	2	det
# 3	the	DT	4	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 5	the	DT	6	det
# 4	the	DT	5	det
# 6	of	IN	5	prep
# 5	the	DT	6	det
# 14	no	DT	15	det
# 16	and	CC	15	cc
# 18	story	NN	15	conj
# 3	the	DT	4	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	The	DT	2	det
# 3	the	DT	4	det
# 10	it	PRP	15	nsubj
# 11	's	VBZ	15	cop
# 12	mostly	RB	15	advmod
# 13	a	DT	15	det
# 14	weak	JJ	15	amod
# 16	full	JJ	15	amod
# 1	The	DT	2	det
# 3	from	IN	2	prep
# 11	the	DT	12	det
# 13	of	IN	12	prep
# 35	a	DT	37	det
# 36	wonderful	JJ	37	amod
# 38	with	IN	37	prep
# 22	a	DT	25	det
# 24	unreeling	VBG	25	amod
# 26	,	,	25	punct
# 27	women	NNS	25	conj
# 28	and	CC	25	cc
# 29	peasants	NNS	25	conj
# 19	surprising	JJ	20	amod
# 1	The	DT	2	det
# 1	That	DT	5	nsubj
# 2	's	VBZ	5	cop
# 3	the	DT	5	det
# 4	whole	JJ	5	amod
# 6	.	.	5	punct
# 20	this	DT	21	det
# 10	the	DT	12	det
# 11	pregnancy	NN	12	nn
# 3	the	DT	4	det
# 3	a	DT	5	det
# 4	good	JJ	5	amod
# 6	movie	NN	8	poss
# 1	The	DT	2	det
# 7	typical	JJ	2	dep
# 34	the	DT	35	det
# 36	of	IN	35	prep
# 1	It	PRP	4	nsubj
# 2	's	VBZ	4	cop
# 3	a	DT	4	det
# 6	've	VBP	4	rcmod
# 37	.	.	4	punct
# 16	a	DT	19	det
# 18	focused	VBN	19	amod
# 20	and	CC	19	cc
# 21	cast	JJ	19	conj
# 2	the	DT	3	det
# 16	and	CC	15	cc
# 18	detail	NN	15	conj
# 1	The	DT	2	det
# 1	Special	JJ	3	amod
# 2	olympics	NNS	3	nn
# 4	(	:	3	punct
# 15	a	DT	17	det
# 16	detailed	JJ	17	amod
# 19	spoil	VB	17	infmod
# 1	The	DT	3	det
# 2	skimpy	NN	3	nn
# 4	a	DT	5	det
# 6	of	IN	5	prep
# 14	a	DT	20	det
# 16	simpler	JJR	20	amod
# 17	drug-induced	JJ	20	amod
# 7	the	DT	8	det
# 8	to	TO	9	aux
# 13	score	NN	9	dobj
# 38	bitter	JJ	39	amod
# 41	focuses	NNS	39	rcmod
# 1	A	DT	3	det
# 2	straight-forward	JJ	3	amod
# 1	The	DT	2	det
# 18	all	DT	19	det
# 12	the	DT	13	det
# 6	a	DT	7	det
# 8	or	CC	7	cc
# 11	meaning	NN	7	conj
# 17	less	RBR	18	advmod
# 24	it	PRP	26	nsubj
# 25	's	VBZ	26	cop
# 14	the	DT	16	det
# 15	crazy	NN	16	nn
# 21	once	NN	16	rcmod
# 10	the	DT	12	det
# 11	souffle-light	JJ	12	amod
# 18	that	IN	21	complm
# 19	cover	NN	21	nsubj
# 20	the	DT	21	det
# 14	a	DT	18	det
# 15	innovative	JJ	18	amod
# 19	,	,	18	punct
# 20	coupled	VBN	18	partmod
# 16	the	DT	17	det
# 16	a	DT	18	det
# 17	awesome	NN	18	nn
# 19	,	,	18	punct
# 21	characters	NNS	18	conj
# 22	,	,	18	punct
# 24	music	NN	18	conj
# 25	and	CC	18	cc
# 26	witty	NN	18	conj
# 27	and	CC	18	cc
# 29	dialogue	NN	18	conj
# 4	the	DT	5	det
# 5	this	DT	6	det
# 29	the	DT	30	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 10	just	RB	12	advmod
# 11	enough	RB	12	advmod
# 3	the	DT	4	det
# 12	the	DT	14	det
# 13	primary	JJ	14	amod
# 15	of	IN	14	prep
# 1	The	DT	2	det
# 20	the	DT	21	det
# 31	the	DT	32	det
# 11	the	DT	13	det
# 12	great	JJ	13	amod
# 14	and	CC	13	cc
# 16	acting	NN	13	conj
# 22	its	PRP$	23	poss
# 10	a	DT	12	det
# 11	better	JJR	12	amod
# 4	the	DT	5	det
# 14	the	DT	15	det
# 17	a	DT	19	det
# 18	brilliant	JJ	19	amod
# 20	to	TO	19	prep
# 11	the	DT	12	det
# 38	the	DT	39	det
# 40	and	CC	39	cc
# 41	execution	NN	39	conj
# 16	the	DT	17	det
# 1	The	DT	2	det
# 6	a	DT	8	det
# 7	predictable	JJ	8	amod
# 9	,	,	8	punct
# 11	dialog	NN	8	appos
# 12	...	:	8	punct
# 15	thing	NN	8	dep
# 27	her	PRP	32	dep
# 30	film	NN	32	poss
# 33	and	CC	32	cc
# 34	sure	NN	32	conj
# 1	The	DT	2	det
# 30	the	DT	31	det
# 32	itself	PRP	31	dep
# 1	Commodus	NNP	3	poss
# 5	kill	VB	3	infmod
# 22	,	,	3	punct
# 23	but	CC	3	cc
# 27	know	VB	3	conj
# 1	The	DT	2	det
# 1	The	DT	3	det
# 2	basic	JJ	3	amod
# 7	the	DT	8	det
# 6	the	DT	7	det
# 7	the	DT	8	det
# 18	the	DT	19	det
# 9	the	DT	10	det
# 11	the	DT	12	det
# 16	the	DT	17	det
# 12	the	DT	13	det
# 9	the	DT	10	det
# 1	The	DT	3	det
# 2	entire	JJ	3	amod
# 16	film	NN	18	poss
# 9	shocking	NN	10	nn
# 1	All	DT	10	nsubj
# 7	is	VBZ	10	cop
# 8	a	DT	10	det
# 9	small	JJ	10	amod
# 11	of	IN	10	prep
# 13	.	.	10	punct
# 26	a	DT	27	det
# 4	the	DT	5	det
# 11	the	DT	12	det
# 12	the	DT	13	det
# 1	The	DT	2	det
# 11	little	RB	12	advmod
# 12	a	DT	14	det
# 13	murder-mystery	JJ	14	amod
# 18	a	DT	19	det
# 21	sabotage	VB	19	infmod
# 29	a	DT	30	det
# 3	the	DT	4	det
# 15	the	DT	16	det
# 2	movie	NN	4	poss
# 1	The	DT	2	det
# 1	The	DT	2	det
# 8	the	DT	9	det
# 11	the	DT	12	det
# 20	a	DT	23	det
# 22	complicated	JJ	23	amod
# 24	a	DT	26	det
# 25	believable	JJ	26	amod
# 29	keep	VB	26	rcmod
# 9	the	DT	11	det
# 10	horrible	JJ	11	amod
# 8	the	DT	9	det
# 19	the	DT	20	det
# 3	the	DT	4	det
# 5	,	,	4	punct
# 7	as	IN	4	prep
# 4	the	DT	5	det
# 1	Good	NNP	2	nsubj
# 3	.	.	2	punct
# 14	the	DT	15	det
# 6	the	DT	7	det
# 8	and	CC	7	cc
# 9	details	NNS	7	conj
# 13	the	DT	14	det
# 14	the	DT	15	det
# 16	at	IN	15	prep
# 1	The	DT	2	det
# 1	The	DT	3	det
# 2	romantic	JJ	3	amod
# 4	of	IN	3	prep
# 8	,	,	3	punct
# 34	light	JJ	3	appos
# 40	.	.	3	punct
# 9	the	DT	10	det
# 29	of	IN	28	prep
# 1	The	DT	2	det
# 5	the	DT	6	det
# 11	was	VBD	13	cop
# 12	a	DT	13	det
# 14	on	IN	13	prep
# 16	up	IN	13	prep
# 3	photography	NN	11	nsubj
# 9	,	,	11	punct
# 10	and	CC	11	cc
# 13	audience	NN	11	conj
# 14	into	IN	11	prep
# 17	.	.	11	punct
# 2	the	DT	3	det
# 4	of	IN	3	prep
# 34	deeper	NN	35	nn
# 5	the	DT	6	det
# 7	's	POS	6	possessive
# 22	the	DT	23	det
# 4	enough	RB	5	advmod
# 15	the	DT	16	det
# 1	The	DT	2	det
# 13	the	DT	14	det
# 1	The	DT	2	det
# 9	the	DT	10	det
# 7	an	DT	9	det
# 8	elaborate	JJ	9	amod
# 10	,	,	9	punct
# 12	cast	NN	9	conj
# 13	,	,	9	punct
# 16	scenes	NNS	9	appos
# 17	;	:	9	punct
# 18	``	``	9	punct
# 24	simple	JJ	9	dep
# 20	Intentions	NNP	22	dep
# 21	``	``	22	punct
# 23	a	DT	24	det
# 25	featuring	VBG	24	partmod
# 18	,	,	23	punct
# 21	embraces	NNS	23	nsubj
# 22	its	PRP$	23	poss
# 24	and	CC	23	cc
# 25	characters	NNS	23	conj
# 1	the	DT	2	det
# 15	the	DT	16	det
# 16	a	DT	18	det
# 17	good	JJ	18	amod
# 1	The	DT	2	det
# 5	the	DT	6	det
# 5	the	DT	6	det
# 13	a	DT	16	det
# 14	nearly	RB	16	advmod
# 15	flawless	NN	16	nn
# 10	no	DT	11	det
# 12	in	IN	11	prep
# 1	The	DT	2	det
# 21	the	DT	22	det
# 5	develop	NN	6	nn
# 8	the	DT	9	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	1	LS	5	dep
# 2	)	``	5	punct
# 4	Weak	NNP	5	nn
# 6	.	.	5	punct
# 9	a	DT	10	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 11	an	DT	14	det
# 12	easy	JJ	14	amod
# 13	going	NN	14	nn
# 16	makes	VBZ	14	rcmod
# 14	the	DT	15	det
# 8	the	DT	9	det
# 26	the	DT	27	det
# 1	The	DT	2	det
# 31	haphazard	NN	32	nn
# 1	The	DT	2	det
# 4	the	DT	5	det
# 7	the	DT	8	det
# 1	First	NNP	11	nsubj
# 9	is	VBZ	11	cop
# 10	a	DT	11	det
# 16	see	VB	11	rcmod
# 21	:	:	11	punct
# 27	show	NN	11	dep
# 34	gets	VBZ	11	dep
# 35	in	IN	11	prep
# 42	and	CC	11	cc
# 44	forced	VBN	11	conj
# 48	,	,	11	punct
# 56	think	VBP	11	rcmod
# 66	?	.	11	punct
# 1	Good	NNP	2	nsubj
# 3	,	,	2	punct
# 5	kept	VBD	2	ccomp
# 11	.	.	2	punct
# 12	less	JJR	13	amod
# 14	compared	VBN	13	prep
# 13	boring	VBG	14	amod
# 3	the	DT	4	det
# 5	about	IN	4	prep
# 17	the	DT	18	det
# 19	and	CC	18	cc
# 22	occurs	NNS	18	conj
# 2	dress	NN	7	nsubj
# 4	was	VBD	7	cop
# 5	the	DT	7	det
# 6	actual	JJ	7	amod
# 8	,	,	7	punct
# 15	represented	VBN	7	advcl
# 38	.	.	7	punct
# 5	the	DT	6	det
# 1	The	DT	3	det
# 2	basic	JJ	3	amod
# 1	The	DT	3	det
# 2	basic	JJ	3	amod
# 4	of	IN	3	prep
# 8	the	DT	9	det
# 5	a	DT	7	det
# 6	good	JJ	7	amod
# 1	The	DT	2	det
# 5	the	DT	9	det
# 6	not-quite	JJ	9	amod
# 8	concept	NN	9	nn
# 10	of	IN	9	prep
# 1	The	DT	2	det
# 3	itself	PRP	2	dep
# 4	the	DT	5	det
# 20	the	DT	21	det
# 11	that	WDT	18	dobj
# 16	advance	NN	18	nsubj
# 17	the	DT	18	det
# 1	The	DT	2	det
# 5	a	DT	7	det
# 6	great	JJ	7	amod
# 20	and	CC	19	cc
# 21	story	NN	19	conj
# 1	The	DT	2	det
# 28	the	DT	29	det
# 15	this	DT	16	det
# 1	The	DT	2	det
# 24	a	DT	25	det
# 29	interested	JJ	25	rcmod
# 31	,	,	25	punct
# 32	and	CC	25	cc
# 35	part	NN	25	conj
# 5	depth	NN	6	nn
# 8	muddled	VBN	6	partmod
# 1	The	DT	2	det
# 6	movie	NN	8	poss
# 1	The	DT	3	det
# 2	great	JJ	3	amod
# 4	and	CC	3	cc
# 8	make	NN	3	conj
# 13	flick	NN	3	rcmod
# 14	.	.	3	punct
# 1	The	DT	2	det
# 12	the	DT	14	det
# 13	basic	JJ	14	amod
# 15	of	IN	14	prep
# 18	the	DT	19	det
# 7	the	DT	8	det
# 5	the	DT	6	det
# 6	the	DT	7	det
# 23	the	DT	24	det
# 3	the	DT	4	det
# 5	and	CC	4	cc
# 6	message	NN	4	conj
# 13	,	,	4	punct
# 14	and	CC	4	cc
# 15	debase	VB	4	conj
# 7	the	DT	9	det
# 8	silly	RB	9	advmod
# 10	and	CC	9	cc
# 12	episodes	NNS	9	conj
# 2	the	DT	3	det
# 15	the	DT	18	det
# 17	Man	NNP	18	nn
# 18	no	DT	19	det
# 1	The	DT	2	det
# 22	...	:	24	punct
# 23	stupid	JJ	24	amod
# 25	-	:	24	punct
# 28	holes	NNS	24	conj
# 29	and	CC	24	cc
# 31	ending	NN	24	conj
# 32	.	.	24	punct
# 20	the	DT	21	det
# 8	a	DT	10	det
# 9	shallow	JJ	10	amod
# 18	the	DT	19	det
# 7	the	DT	8	det
# 9	for	IN	8	prep
# 22	and	CC	21	cc
# 23	character	NN	21	conj
# 15	the	DT	16	det
# 26	the	DT	28	det
# 27	circular	JJ	28	amod
# 1	The	DT	2	det
# 3	,	,	2	punct
# 5	setting	NN	2	appos
# 6	,	,	2	punct
# 8	dialogues	NNS	2	appos
# 9	,	,	2	punct
# 10	and	CC	2	cc
# 12	music	NN	2	conj
# 13	,	,	2	punct
# 18	the	DT	19	det
# 20	...	:	19	punct
# 22	wild	NN	19	dep
# 23	,	,	19	punct
# 25	approach	NN	19	appos
# 28	,	,	19	punct
# 29	and	CC	19	cc
# 34	irreverent	NN	19	conj
# 12	further	RBR	15	advmod
# 13	any	DT	15	det
# 14	overall	JJ	15	amod
# 5	some	DT	7	det
# 6	outlandish	JJ	7	amod
# 8	to	TO	7	prep
# 9	the	DT	10	det
# 11	unconvincing	VBG	10	partmod
# 12	and	CC	10	cc
# 14	characters	NNS	10	conj
# 3	to	TO	6	aux
# 4	be	VB	6	cop
# 5	a	DT	6	det
# 7	,	,	6	punct
# 9	development	NN	6	conj
# 10	,	,	6	punct
# 11	and	CC	6	cc
# 12	redemption	NN	6	conj
# 15	,	,	6	punct
# 17	well	RB	6	cc
# 18	as	IN	6	conj
# 32	the	DT	33	det
# 1	This	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	was..well..stupid	JJ	2	amod
# 4	and	CC	2	cc
# 6	atmosphere	NN	2	conj
# 16	a	DT	17	det
# 6	the	DT	7	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 23	the	DT	24	det
# 10	the	DT	12	det
# 11	terrifying	NN	12	nn
# 14	the	DT	15	det
# 3	a	DT	4	det
# 8	speak	VB	4	rcmod
# 20	the	DT	21	det
# 1	The	DT	2	det
# 29	a	DT	32	det
# 30	tightly	RB	32	advmod
# 31	knit	NN	32	nn
# 1	The	DT	2	det
# 17	the	DT	18	det
# 24	a	DT	25	det
# 28	shock	VB	25	rcmod
# 1	This	DT	6	nsubj
# 2	is	VBZ	6	cop
# 3	the	DT	6	det
# 4	classic	JJ	6	amod
# 5	paranoid	NN	6	nn
# 7	.	.	6	punct
# 9	the	DT	10	det
# 16	the	DT	17	det
# 16	story	NN	17	nn
# 19	creates	VBZ	17	rcmod
# 33	kicks	NNS	37	nsubj
# 34	his	PRP$	37	poss
# 35	ill-conceived	JJ	37	amod
# 36	robbery	NN	37	nn
# 38	into	IN	37	prep
# 1	The	DT	2	det
# 3	containing	VBG	2	partmod
# 8	,	,	2	punct
# 15	the	DT	16	det
# 2	the	DT	3	det
# 31	the	DT	32	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 19	dvd	NN	20	nn
# 45	the	DT	46	det
# 24	the	DT	25	det
# 15	the	DT	16	det
# 5	the	DT	6	det
# 1	The	DT	3	det
# 2	main	JJ	3	amod
# 3	the	DT	4	det
# 1	Redford	NNP	4	poss
# 3	substitute	NN	4	nn
# 5	of	IN	4	prep
# 7	and	CC	4	cc
# 9	is	VBZ	4	conj
# 20	little	JJ	21	amod
# 22	and	CC	21	cc
# 23	cutsey	NN	21	conj
# 24	,	,	21	punct
# 26	characters	NNS	21	appos
# 16	the	DT	17	det
# 1	The	DT	2	det
# 18	.Overall	JJ	21	amod
# 19	a	DT	21	det
# 20	good	JJ	21	amod
# 25	the	DT	26	det
# 27	and	CC	26	cc
# 28	characters	NNS	26	conj
# 8	a	DT	9	det
# 1	The	DT	2	det
# 3	:	:	2	punct
# 11	boy	NN	2	dep
# 12	:	:	2	punct
# 14	finds	VBZ	2	dep
# 31	.	.	2	punct
# 1	The	DT	2	det
# 3	to	TO	2	prep
# 4	the	DT	5	det
# 9	adding	NN	11	nn
# 10	more	JJR	11	amod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 5	a	DT	7	det
# 6	confusing	NN	7	nn
# 10	went	VBD	7	rcmod
# 1	The	DT	2	det
# 25	the	DT	26	det
# 4	some	DT	5	det
# 10	the	DT	11	det
# 7	the	DT	8	det
# 11	a	DT	12	det
# 17	movie	NN	12	infmod
# 26	a	DT	29	det
# 28	government	NN	29	nn
# 31	kill	VB	29	infmod
# 9	the	DT	10	det
# 1	The	DT	2	det
# 7	the	DT	8	det
# 1	The	DT	2	det
# 1	The	DT	3	det
# 2	slim	NN	3	nn
# 9	the	DT	10	det
# 1	The	DT	2	det
# 28	the	DT	29	det
# 1	The	DT	2	det
# 4	the	DT	5	det
# 3	The	DT	4	det
# 5	's	POS	4	possessive
# 1	The	DT	2	det
# 4	a	DT	5	det
# 7	save	VB	5	infmod
# 7	no	DT	8	det
# 3	the	DT	4	det
# 1	The	DT	2	det
# 2	the	DT	3	det
# 36	bad	JJ	37	amod
# 1	The	DT	2	det
# 5	to	TO	2	prep
# 8	explain	VB	2	infmod
# 15	,	,	2	punct
# 16	but	CC	2	cc
# 18	sums	NNS	2	conj
# 27	,	,	2	punct
# 28	with	IN	2	prep
# 39	of	IN	2	prep
# 6	the	DT	7	det
# 5	its	PRP$	7	poss
# 6	intricate	JJ	7	amod
# 8	-	:	7	punct
# 12	awaited	VBD	7	dep
# 1	The	DT	2	det
# 4	being	VBG	13	cop
# 5	a	DT	13	det
# 7	good	JJ	13	amod
# 12	movie.The	NN	13	nn
# 14	of	IN	13	prep
# 6	the	DT	7	det
# 3	the	DT	4	det
# 5	of	IN	4	prep
# 5	the	DT	6	det
# 1	The	DT	2	det
# 3	the	DT	4	det
# 14	the	DT	15	det
# 4	the	DT	5	det
# 3	the	DT	4	det
# 5	of	IN	4	prep
# 32	,	,	31	punct
# 33	characters	NNS	31	conj
# 34	,	,	31	punct
# 35	and	CC	31	cc
# 36	settings	NNS	31	conj
# 15	the	DT	16	det
# 17	and	CC	16	cc
# 19	script	NN	16	conj
# 1	The	DT	2	det
# 19	the	DT	21	det
# 20	familiar	JJ	21	amod
# 29	be	VB	21	rcmod
# 5	a	DT	6	det
# 7	and	CC	6	cc
# 10	romance	NN	6	conj
# 1	The	DT	2	det
# 1	The	DT	2	det
# 6	the	DT	8	det
# 7	entire	JJ	8	amod
# 9	of	IN	8	prep
# 12	in	IN	8	prep
# 15	little	JJ	16	amod
# 4	the	DT	5	det
# 3	The	DT	4	det
# 5	of	IN	4	prep
# 3	this	DT	4	det
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 4	dialogue	NN	2	conj
# 26	the	DT	27	det
# 24	b	NN	26	nn
# 25	movie	NN	26	nn
# 1	The	DT	2	det
# 3	itself	PRP	2	dep
# 8	the	DT	9	det
# 8	bogus	NN	9	nn
# 6	the	DT	9	det
# 8	Man	NNP	9	nn
# 22	a	DT	24	det
# 23	complex	JJ	24	amod
# 26	taking	VBG	24	partmod
# 13	no	DT	14	det
# 16	the	DT	17	det
# 4	even	RB	6	advmod
# 5	a	DT	6	det
# 16	and	CC	15	cc
# 17	conclusion	NN	15	conj
# 1	The	DT	2	det
# 3	:	:	2	punct
# 4	Typical	JJ	2	dep
# 8	,	,	2	punct
# 12	kept	VBN	2	rcmod
# 16	.	.	2	punct
# 12	an	DT	14	det
# 13	inane	NN	14	nn
# 16	a	DT	18	det
# 17	murder	NN	18	nn
# 14	being	VBG	16	cop
# 15	the	DT	16	det
# 3	What	WP	6	nsubj
# 4	is	VBZ	6	cop
# 5	the	DT	6	det
# 18	that	IN	24	nsubj
# 19	's	POS	24	dep
# 20	the	DT	24	det
# 21	usual	JJ	24	amod
# 22	predictable	JJ	24	amod
# 23	romance	NN	24	nn
# 3	the	DT	4	det
# 14	the	DT	15	det
# 9	the	DT	10	det
# 1	The	DT	2	det
# 3	an	DT	5	det
# 4	intriguing	VBG	5	amod
# 9	immersed	VBD	5	ccomp
# 6	the	DT	7	det
# 16	the	DT	17	det
# 15	a	DT	17	det
# 16	indepth	NN	17	nn
# 18	with	IN	17	prep
# 46	(	:	47	punct
# 48	,	,	47	punct
# 49	interesting	JJ	47	amod
# 50	and	CC	47	cc
# 51	engaging	VBG	47	conj
# 54	etc	NN	47	dep
# 4	an	DT	6	det
# 5	interesting	JJ	6	amod
# 7	with	IN	6	prep
# 1	Rather	RB	3	advmod
# 2	formulaic	JJ	3	amod
# 4	;	:	3	punct
# 9	thing	NN	3	parataxis
# 15	the	DT	16	det
# 8	the	DT	9	det
# 20	the	DT	21	det
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 4	characters	NNS	2	conj
# 12	the	DT	13	det
# 12	the	DT	13	det
# 6	a	DT	8	det
# 7	well-developed	JJ	8	amod
# 9	,	,	8	punct
# 10	and	CC	8	cc
# 14	warmth	NN	8	conj
# 15	and	CC	8	cc
# 16	purity	NN	8	conj
# 24	this	DT	27	det
# 26	thin	NN	27	nn
# 1	The	DT	2	det
# 1	The	DT	2	det
# 26	the	DT	27	det
# 28	of	IN	27	prep
# 22	a	DT	23	det
# 1	The	DT	2	det
# 2	the	DT	3	det
# 17	a	DT	19	det
# 18	bad	JJ	19	amod
# 23	predictable	JJ	19	rcmod
# 26	their	PRP$	27	poss
# 10	the	DT	11	det
# 18	the	DT	19	det
# 20	due	JJ	19	amod
# 23	being	VBG	19	partmod
# 5	a	DT	6	det
# 10	one	CD	6	dep
# 2	the	DT	3	det
# 4	of	IN	3	prep
# 6	and	CC	3	cc
# 8	relationships	NNS	3	conj
# 3	and	CC	2	cc
# 4	dialogue	NN	2	conj
# 4	the	DT	6	det
# 5	paper-thin	JJ	6	amod
# 26	movie	NN	28	poss
# 29	of	IN	28	prep
# 10	as	IN	13	mark
# 11	far	RB	13	advmod
# 12	as	IN	13	amod
# 14	and	CC	13	cc
# 15	acting	VBG	13	conj
# 16	but	CC	13	cc
# 23	seeing	VBG	13	conj
# 31	,	,	13	punct
# 1	The	DT	2	det
# 29	the	DT	31	det
# 30	movie	NN	31	nn
# 5	an	DT	7	det
# 6	interesting	JJ	7	amod
# 1	Great	NNP	2	nsubj
# 3	!	.	2	punct
# 8	a	DT	9	det
# 11	progresses	VBZ	9	rcmod
# 24	the	DT	25	det
# 29	up	RB	25	advmod
# 32	.	.	25	erased
# 4	of	IN	3	prep
# 17	a	DT	19	det
# 18	real	JJ	19	amod
# 10	the	DT	11	det
# 6	the	DT	7	det
# 1	This	DT	2	det
# 18	the	DT	19	det
# 11	no	DT	13	det
# 12	real	JJ	13	amod
# 1	The	DT	2	det
# 8	the	DT	9	det
# 28	the	DT	29	det
# 25	the	DT	26	det
# 5	a	DT	7	det
# 6	strong	JJ	7	amod
# 1	The	DT	2	det
# 53	the	DT	55	det
# 54	actual	JJ	55	amod
# 56	of	IN	55	prep
# 1	The	DT	2	det
# 1	Terrific	NNP	2	nsubj
# 3	,	,	2	punct
# 4	actors	NNS	2	dobj
# 5	,	,	2	punct
# 6	dancing	VBG	2	xcomp
# 7	,	,	2	punct
# 10	HISS	NNP	2	dobj
# 11	,	,	2	punct
# 12	and	CC	2	cc
# 30	a	DT	32	det
# 31	too-slow-to-develop	JJ	32	amod
# 33	and	CC	32	cc
# 34	draw	NN	32	conj
# 36	out	RP	32	rcmod
# 1	The	DT	2	det
# 2	the	DT	3	det
# 4	of	IN	3	prep
# 9	movie	NN	11	poss
# 7	the	DT	8	det
# 11	went	VBD	8	rcmod
# 1	The	DT	2	det
# 13	a	DT	14	det
# 2	The	DT	3	det
# 21	the	DT	22	det
# 11	the	DT	12	det
# 29	the	DT	30	det
# 7	a	DT	8	det
# 5	the	DT	6	det
# 16	the	DT	17	det
# 18	and	CC	17	cc
# 19	characters	NNS	17	conj
# 26	a	DT	30	det
# 27	less-than-linier	JJ	30	amod
# 28	,	,	30	punct
# 29	episodic	JJ	30	amod
# 1	The	DT	2	det
# 12	the	DT	13	det
# 4	the	DT	5	det
# 1	It	PRP	6	nsubj
# 2	's	VBZ	6	cop
# 3	a	DT	6	det
# 5	simple	JJ	6	amod
# 7	,	,	6	punct
# 9	deer	NN	6	appos
# 10	(	:	6	punct
# 13	growing	VBG	6	parataxis
# 27	,	,	6	punct
# 29	feels	VBZ	6	rcmod
# 32	.	.	6	punct
# 6	the	DT	7	det
# 28	the	DT	30	det
# 29	tight	JJ	30	amod
# 33	his	PRP$	37	poss
# 36	Implausible	NNP	37	nn
# 43	bring	VB	37	rcmod
# 1	The	DT	2	det
# 12	a	DT	17	det
# 13	tight	JJ	17	amod
# 18	at	IN	17	prep
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 23	the	DT	24	det
# 19	the	DT	21	det
# 20	uneven	JJ	21	amod
# 22	and	CC	21	cc
# 24	twists	NNS	21	conj
# 6	the	DT	7	det
# 1	The	DT	2	det
# 9	the	DT	10	det
# 4	the	DT	5	det
# 8	there	RB	12	nsubj
# 9	would	MD	12	aux
# 10	be	VB	12	cop
# 11	no	RB	12	advmod
# 13	against	IN	12	prep
# 9	an	DT	11	det
# 10	insidious	JJ	11	amod
# 1	Not	RB	3	neg
# 2	much	JJ	3	amod
# 4	,	,	3	punct
# 9	gets	NNS	3	appos
# 12	.	.	3	punct
# 15	the	DT	16	det
# 2	movies	NNS	3	nsubj
# 7	confusing	VBG	3	xcomp
# 23	the	DT	25	det
# 24	fun	NN	25	nn
# 11	the	DT	13	det
# 12	robbery	NN	13	nn
# 14	and	CC	13	cc
# 17	half-way	NN	13	conj
# 19	or	CC	13	cc
# 21	character	NN	13	conj
# 22	among	IN	13	prep
# 7	the	DT	8	det
# 10	its	PRP$	12	poss
# 11	average	JJ	12	amod
# 13	,	,	12	punct
# 15	acting	NN	12	appos
# 16	(	:	12	punct
# 3	the	DT	7	det
# 4	expected	VBN	7	amod
# 5	pivotal	JJ	7	amod
# 6	kidnap	NN	7	nn
# 15	the	DT	17	det
# 16	weak	JJ	17	amod
# 1	The	DT	2	det
# 11	the	DT	12	det
# 18	about	IN	20	amod
# 19	the	DT	20	det
# 9	the	DT	10	det
# 6	the	DT	9	det
# 8	Man	NNP	9	nn
# 11	the	DT	12	det
# 5	the	DT	6	det
# 7	,	,	6	punct
# 8	storyline	NN	6	conj
# 9	and	CC	6	cc
# 11	photography	NN	6	conj
# 39	its	PRP$	40	poss
# 12	the	DT	14	det
# 13	horror	NN	14	nn
# 6	the	DT	7	det
# 19	the	DT	20	det
# 7	the	DT	8	det
# 12	the	DT	13	det
# 1	The	DT	3	det
# 2	main	JJ	3	amod
# 33	the	DT	34	det
# 35	and	CC	34	cc
# 37	way	NN	34	conj
# 1	The	DT	2	det
# 1	The	DT	2	det
# 9	a	DT	10	det
# 14	his	PRP$	15	poss
# 17	get	VB	15	infmod
# 6	cliche	NN	7	nn
# 1	The	DT	2	det
# 3	:	:	2	punct
# 6	kicks	VBZ	2	dep
# 12	.	.	2	punct
# 9	a	DT	11	det
# 10	great	JJ	11	amod
# 12	and	CC	11	cc
# 15	actors	NNS	11	conj
# 6	the	DT	7	det
# 8	of	IN	7	prep
# 1	The	DT	2	det
# 7	a	DT	8	det
# 10	kill	VB	8	infmod
# 20	upfront	NN	21	nn
# 6	the	DT	7	det
# 15	its	PRP$	17	poss
# 16	convoluted	VBN	17	amod
# 20	the	DT	21	det
# 5	the	DT	6	det
# 12	an	DT	14	det
# 13	enjoyable	JJ	14	amod
# 3	the	DT	4	det
# 5	's	POS	4	possessive
# 8	the	DT	9	det
# 10	of	IN	9	prep
# 2	the	DT	3	det
# 3	the	DT	4	det
# 6	the	DT	7	det
# 21	the	DT	22	det
# 16	the	DT	17	det
# 18	intriguing	VBG	17	partmod
# 9	the	DT	10	det
# 5	the	DT	6	det
# 7	and	CC	6	cc
# 9	suspense	NN	6	conj
# 10	and	CC	6	cc
# 11	thrills	NNS	6	conj
# 1	The	DT	2	det
# 25	the	DT	26	det
# 27	and	CC	26	cc
# 28	characters	NNS	26	conj
# 4	the	DT	5	det
# 6	,	,	5	punct
# 7	therefore	RB	5	advmod
# 4	the	DT	5	det
# 10	age	NN	14	nn
# 11	'em	JJ	14	amod
# 12	quickly	RB	14	advmod
# 13	``	``	14	punct
# 37	the	DT	39	det
# 38	terrible	JJ	39	amod
# 1	The	DT	2	det
# 23	the	DT	25	det
# 24	entire	JJ	25	amod
# 3	the	DT	4	det
# 4	the	DT	5	det
# 1	the	DT	2	det
# 5	the	DT	6	det
# 15	uninteresting	NN	16	nn
# 37	the	DT	38	det
# 1	The	DT	2	det
# 31	and	CC	30	cc
# 33	development	NN	30	conj
# 1	A	DT	3	det
# 2	simple	JJ	3	amod
# 5	was	VBD	3	rcmod
# 38	the	DT	39	det
# 3	a	DT	6	det
# 5	complicated	VBN	6	amod
# 10	a	DT	12	det
# 11	fascinating	NN	12	nn
# 13	and	CC	12	cc
# 15	performances	NNS	12	conj
# 10	an	DT	12	det
# 11	incredible	JJ	12	amod
# 10	the	DT	11	det
# 1	The	DT	2	det
# 9	the	DT	10	det
# 15	the	DT	16	det
# 11	a	DT	12	det
# 13	with	IN	12	prep
# 12	the	DT	13	det
# 10	a	DT	11	det
# 6	the	DT	7	det
# 3	the	DT	4	det
# 10	the	DT	11	det
# 4	the	DT	5	det
# 12	a	DT	14	det
# 13	thin	JJ	14	amod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 9	``	``	10	punct
# 11	``	``	10	punct
# 5	the	DT	6	det
# 17	the	DT	18	det
# 6	the	DT	8	det
# 7	intricate	JJ	8	amod
# 4	the	DT	5	det
# 11	the	DT	12	det
# 1	The	DT	2	det
# 6	gay	NN	7	nn
# 7	a	DT	8	det
# 10	a	DT	11	det
# 15	no	DT	16	det
# 12	the	DT	13	det
# 12	an	DT	14	det
# 13	evil	JJ	14	amod
# 9	the	DT	10	det
# 7	the	DT	8	det
# 9	out	IN	8	prep
# 2	the	DT	3	det
# 10	a	DT	12	det
# 11	compelling	NN	12	nn
# 10	complex	NN	11	nn
# 4	the	DT	5	det
# 6	and	CC	5	cc
# 7	scenery	NN	5	conj
# 7	his	PRP$	8	poss
# 10	a	DT	12	det
# 11	good	JJ	12	amod
# 3	a	DT	5	det
# 4	promising	NN	5	nn
# 10	in	IN	5	rcmod
# 4	the	DT	5	det
# 12	strong	JJ	13	amod
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 4	premise	VB	2	conj
# 12	a	DT	14	det
# 13	main	JJ	14	amod
# 15	of	IN	14	prep
# 1	The	DT	2	det
# 3	,	,	2	punct
# 5	as	IN	2	prep
# 3	a	DT	5	det
# 4	great	JJ	5	amod
# 17	the	DT	19	det
# 18	whole	JJ	19	amod
# 7	the	DT	8	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	,	,	2	punct
# 5	as	IN	2	prep
# 25	it	PRP	31	nsubj
# 26	's	VBZ	31	cop
# 27	just	RB	31	advmod
# 28	a	DT	31	det
# 30	convoluted	VBN	31	amod
# 8	the	DT	9	det
# 27	the	DT	28	det
# 12	the	DT	13	det
# 14	,	,	13	punct
# 17	tale	NN	13	conj
# 8	the	DT	9	det
# 3	the	DT	4	det
# 12	the	DT	13	det
# 14	to	TO	13	prep
# 1	The	DT	2	det
# 3	's	POS	2	possessive
# 12	neither	DT	14	predet
# 13	the	DT	14	det
# 10	the	DT	11	det
# 12	on	IN	11	prep
# 7	a	DT	9	det
# 8	great	JJ	9	amod
# 10	,	,	9	punct
# 13	script	NN	9	appos
# 14	,	,	9	punct
# 16	acting	NN	9	appos
# 17	,	,	9	punct
# 20	look	NN	9	conj
# 21	and	CC	9	cc
# ...
# 21	the	DT	23	det
# 22	incredible	JJ	23	amod
# 24	and	CC	23	cc
# 27	cliches	NNS	23	conj
# 4	the	DT	5	det
# 10	the	DT	11	det
# 14	the	DT	15	det
# 16	or	CC	15	cc
# 18	characters	NNS	15	conj
# 4	the	DT	5	det
# 7	the	DT	10	det
# 8	exact	JJ	10	amod
# 9	same	NN	10	nn
# 5	the	DT	6	det
# 1	The	DT	2	det
# 4	the	DT	5	det
# 4	the	DT	5	det
# 5	who	WP	17	dep
# 11	Rain	NNP	17	nsubj
# 12	is	VBZ	17	cop
# 13	a	DT	17	det
# 14	stupid	JJ	17	amod
# 1	The	DT	2	det
# 4	described	VBN	17	csubj
# 13	much	RB	17	advmod
# 14	becomes	VBZ	17	cop
# 15	the	DT	17	det
# 16	main	JJ	17	amod
# 18	by	IN	17	prep
# 23	,	,	17	punct
# 24	serving	VBG	17	partmod
# 35	and	CC	17	cc
# 37	come	VB	17	infmod
# 44	.	.	17	punct
# 1	The	DT	2	det
# 31	the	DT	32	det
# 1	The	DT	2	det
# 7	the	DT	8	det
# 12	the	DT	13	det
# 34	an	DT	37	det
# 36	complex	JJ	37	amod
# 1	The	DT	2	det
# 5	hate	JJ	7	amod
# 6	the	DT	7	det
# 8	of	IN	7	prep
# 12	the	DT	13	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	with	IN	2	prep
# 27	light	JJ	28	amod
# 29	for	IN	28	prep
# 35	sizzles	NNS	28	rcmod
# 16	the	DT	17	det
# 1	The	DT	3	det
# 2	intriguing	NN	3	nn
# 18	a	DT	20	det
# 19	supernatural	JJ	20	amod
# 21	with	IN	20	prep
# 3	an	DT	5	det
# 4	interesting	JJ	5	amod
# 25	the	DT	26	det
# 13	the	DT	14	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 3	to	TO	2	prep
# 6	the	DT	7	det
# 8	and	CC	7	cc
# 9	everything	NN	7	conj
# 1	Plot	NN	4	nsubj
# 3	what	WP	4	dep
# 5	.	.	4	punct
# 15	a	DT	18	det
# 17	predictable	JJ	18	amod
# 33	a	DT	34	det
# 36	backfires	VBZ	34	rcmod
# 25	an	DT	28	det
# 27	weak	JJ	28	amod
# 1	The	DT	2	det
# 11	and	CC	10	cc
# 12	character	NN	10	conj
# 1	A	DT	3	det
# 2	solid	JJ	3	amod
# 4	.	.	3	punct
# 4	the	DT	5	det
# 17	a	DT	20	det
# 19	good	JJ	20	amod
# 13	its	PRP$	16	poss
# 14	somewhat	NN	16	nn
# 15	improbable	JJ	16	amod
# 17	with	IN	16	prep
# 17	that	WDT	20	dobj
# 18	advance	NN	20	nsubj
# 19	the	DT	20	det
# 1	The	DT	2	det
# 10	movie	NN	12	poss
# 30	the	DT	31	det
# 3	no	DT	5	det
# 4	real	JJ	5	amod
# 6	here	RB	5	advmod
# 1	The	DT	2	det
# 41	this	DT	43	det
# 42	unconvincing	NN	43	nn
# 8	it	PRP	18	nsubj
# 12	lean	JJ	18	amod
# 16	the	DT	18	det
# 17	intriguing	NN	18	nn
# 19	or	CC	18	cc
# 22	amused	VBN	18	conj
# 5	Orai	NNP	6	nn
# 1	The	DT	2	det
# 8	the	DT	9	det
# 1	The	DT	2	det
# 1	When	WRB	5	advmod
# 2	reading	NN	5	nsubj
# 3	the	DT	5	det
# 4	above	NN	5	nn
# 17	an	DT	19	det
# 18	engaging	JJ	19	amod
# 20	with	IN	19	prep
# 1	The	DT	2	det
# 6	the	DT	7	det
# 8	and	CC	7	cc
# 9	characterization	NN	7	conj
# 1	The	DT	2	det
# 19	the	DT	20	det
# 19	the	DT	20	det
# 16	the	DT	17	det
# 24	nice	NN	25	nn
# 40	that	IN	41	amod
# 1	The	DT	2	det
# 4	a	DT	6	det
# 5	stupid	JJ	6	amod
# 1	The	DT	2	det
# 6	the	DT	7	det
# 6	the	DT	7	det
# 6	the	DT	7	det
# 19	a	DT	20	det
# 12	the	DT	13	det
# 1	In	IN	6	prep
# 3	it	PRP	6	nsubj
# 4	was	VBD	6	cop
# 5	a	DT	6	det
# 7	by	IN	6	prep
# 12	kill	VB	6	infmod
# 22	.	.	6	punct
# 18	the	DT	19	det
# 1	The	DT	3	det
# 2	only	JJ	3	amod
# 7	an	DT	9	det
# 8	interesting	JJ	9	amod
# 10	,	,	9	punct
# 12	acting	NN	9	conj
# 13	,	,	9	punct
# 14	decent	NN	9	conj
# 15	directing	VBG	9	partmod
# 16	and	CC	9	cc
# 20	comment	NN	9	conj
# 19	the	DT	21	det
# 20	backstage	NN	21	nn
# 5	intriguing	JJ	6	amod
# 7	the	DT	8	det
# 9	as	IN	8	prep
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 46	the	DT	47	det
# 9	the	DT	10	det
# 11	frightening	VBG	10	partmod
# 2	that	DT	3	det
# 14	the	DT	15	det
# 7	the	DT	9	det
# 8	entire	JJ	9	amod
# 10	of	IN	9	prep
# 33	a	DT	35	det
# 34	solid	JJ	35	amod
# 36	and	CC	35	cc
# 38	twists	NNS	35	conj
# 39	and	CC	35	cc
# 40	turns	NNS	35	conj
# 6	a	DT	7	det
# 8	about	IN	7	prep
# 10	fighting	VBG	7	partmod
# 1	The	DT	2	det
# 7	a	DT	9	det
# 8	predictable	JJ	9	amod
# 14	a	DT	15	det
# 17	turns	VBZ	15	rcmod
# 24	,	,	15	punct
# 26	direction	NN	15	conj
# 14	a	DT	15	det
# 1	The	DT	3	det
# 2	ostensible	JJ	3	amod
# 4	of	IN	3	prep
# 7	the	DT	8	det
# 12	a	DT	14	det
# 13	sincere	NN	14	nn
# 4	a	DT	6	det
# 5	good	JJ	6	amod
# 7	,	,	6	punct
# 9	acting	NN	6	appos
# 10	,	,	6	punct
# 11	and	CC	6	cc
# 12	potrays	NNS	6	conj
# 16	relationship	NN	6	dep
# 16	the	DT	17	det
# 26	the	DT	28	det
# 27	absent	NN	28	nn
# 15	the	DT	16	det
# 28	Russian	NNP	30	poss
# 19	they	PRP	20	nsubj
# 22	swipe	VB	20	xcomp
# 7	as	IN	9	mark
# 8	they	PRP	9	nsubj
# 11	husband	VBP	9	ccomp
# 28	the	DT	29	det
# 30	by	IN	29	prep
# 1	The	DT	2	det
# 3	's	POS	2	possessive
# 1	The	DT	2	det
# 15	the	DT	18	det
# 17	conventional	JJ	18	amod
# 1	used	VBD	2	auxpass
# 3	.	.	2	punct
# 6	the	DT	8	det
# 7	intense	NN	8	nn
# 9	and	CC	8	cc
# 12	dialogue	NN	8	conj
# 1	The	DT	2	det
# 12	the	DT	13	det
# 15	AND	CC	14	cc
# 16	character	NN	14	conj
# 16	no	DT	17	det
# 18	and	CC	17	cc
# 20	point	NN	17	conj
# 6	the	DT	7	det
# 1	The	DT	2	det
# 14	it	PRP	18	nsubj
# 15	is	VBZ	18	cop
# 16	just	RB	18	advmod
# 17	the	DT	18	det
# 1	The	DT	3	det
# 2	quirky	NN	3	nn
# 11	the	DT	12	det
# 1	The	DT	2	det
# 3	in	IN	2	prep
# 8	the	DT	10	det
# 9	basic	JJ	10	amod
# 11	of	IN	10	prep
# 23	a	DT	25	det
# 24	sub	NN	25	nn
# 26	revolving	VBG	25	partmod
# 5	the	DT	6	det
# 3	the	DT	4	det
# 5	of	IN	4	prep
# 10	the	DT	11	det
# 12	on	IN	11	prep
# 12	movie	NN	14	poss
# 1	The	DT	2	det
# 8	the	DT	9	det
# 21	the	DT	23	det
# 22	main	JJ	23	amod
# 2	a	DT	5	det
# 4	convoluted	VBN	5	amod
# 7	all	PDT	9	predet
# 8	the	DT	9	det
# 12	going	VBG	9	rcmod
# 13	the	DT	14	det
# 17	the	DT	18	det
# 8	the	DT	9	det
# 10	of	IN	9	prep
# 8	a	DT	10	det
# 9	good	JJ	10	amod
# 1	The	DT	2	det
# 26	a	DT	29	det
# 27	totally	RB	29	advmod
# 28	original	JJ	29	amod
# 31	is	VBZ	35	cop
# 32	a	DT	35	det
# 33	decent	NN	35	nn
# 34	basic	JJ	35	amod
# 39	less	JJR	35	amod
# 10	its	PRP$	11	poss
# 12	from	IN	11	prep
# 2	this	DT	3	det
# 9	Slevin	NNP	11	poss
# 12	other	JJ	11	amod
# 6	the	DT	7	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 2	movie	NN	4	poss
# 26	the	DT	27	det
# 7	the	DT	8	det
# 9	of	IN	8	prep
# 26	the	DT	27	det
# 8	all	DT	11	det
# 9	further	JJ	11	amod
# 10	the	DT	11	det
# 12	and	CC	11	cc
# 14	dove-tail	JJ	11	conj
# 15	so	IN	11	dep
# 11	the	DT	12	det
# 1	Basically	RB	3	advmod
# 2	the	DT	3	det
# 4	of	IN	3	prep
# 8	simple	JJ	3	dep
# 28	.	.	3	punct
# 1	From	IN	13	prep
# 9	,	,	13	punct
# 10	it	PRP	13	nsubj
# 11	is	VBZ	13	cop
# 12	a	DT	13	det
# 16	keep	VB	13	rcmod
# 25	!	.	13	punct
# 8	the	DT	9	det
# 8	confusing	NN	9	nn
# 2	the	DT	4	det
# 3	dumb	NN	4	nn
# 5	and	CC	4	cc
# 7	unfunny	NN	4	conj
# 9	the	DT	10	det
# 12	give	JJ	14	amod
# 13	the	DT	14	det
# 4	the	DT	5	det
# 1	The	DT	2	det
# 9	the	DT	10	det
# 11	or	CC	10	cc
# 13	meaning	NN	10	conj
# 8	a	DT	9	det
# 16	a	DT	18	det
# 17	detective	JJ	18	amod
# 1	The	DT	2	det
# 4	to	TO	5	aux
# 1	The	DT	2	det
# 3	moral	JJ	2	amod
# 4	,	,	2	punct
# 5	not	RB	2	neg
# 4	the	DT	5	det
# 3	the	DT	4	det
# 3	the	DT	5	det
# 4	basic	JJ	5	amod
# 6	and	CC	5	cc
# 7	ending	VBG	5	conj
# 8	the	DT	9	det
# 1	The	DT	2	det
# 7	the	DT	8	det
# 4	great	JJ	5	amod
# 4	an	DT	6	det
# 5	interesting	JJ	6	amod
# 9	the	DT	10	det
# 18	the	DT	19	det
# 27	and	CC	26	cc
# 28	character	NN	26	conj
# 14	an	DT	16	det
# 15	diabolical	JJ	16	amod
# 9	this	DT	11	det
# 10	ripped-off	JJ	11	amod
# 2	again	RB	4	advmod
# 3	a	DT	4	det
# 9	sciene	NN	4	rcmod
# 23	.	.	4	punct
# 7	a	DT	10	det
# 9	woven	VBN	10	amod
# 4	interconnected	VBN	5	amod
# 7	a	DT	8	det
# 13	the	DT	15	det
# 14	main	JJ	15	amod
# 16	of	IN	15	prep
# 19	,	,	15	punct
# 20	and	CC	15	cc
# 21	true	JJ	15	conj
# 36	before	IN	15	prep
# 6	the	DT	8	det
# 7	general	JJ	8	amod
# 7	and	CC	6	cc
# 8	character	NN	6	conj
# 1	The	DT	2	det
# 1	The	DT	2	det
# 15	the	DT	16	det
# 1	The	DT	2	det
# 5	the	DT	6	det
# 7	the	DT	8	det
# 6	a	DT	7	det
# 14	a	DT	17	det
# 15	great	JJ	17	amod
# 16	story	NN	17	nn
# 20	the	DT	21	det
# 1	The	DT	3	det
# 2	``	``	3	punct
# 26	escaped	VBN	3	dep
# 30	a	DT	31	det
# 8	the	DT	9	det
# 9	a	DT	12	det
# 11	believable	JJ	12	amod
# 4	this	DT	5	det
# 46	the	DT	47	det
# 1	Like	IN	12	prep
# 7	,	,	12	punct
# 9	sports	NNS	12	nsubj
# 10	the	DT	12	det
# 11	basic	JJ	12	amod
# 13	of	IN	12	prep
# 33	.	.	12	punct
# 6	a	DT	7	det
# 12	produced	VBN	7	rcmod
# 3	the	DT	4	det
# 14	movie	NN	18	nsubj
# 15	is	VBZ	18	cop
# 16	a	DT	18	det
# 17	half-assed	JJ	18	amod
# 19	,	,	18	punct
# 22	lesson	NN	18	conj
# 7	a	DT	9	det
# 8	funny	JJ	9	amod
# 6	the	DT	7	det
# 8	a	DT	10	det
# 9	senseless	NN	10	nn
# 1	The	DT	2	det
# 3	itself	PRP	2	dep
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 14	the	DT	15	det
# 14	a	DT	17	det
# 15	perfect	NN	17	nn
# 16	murder	NN	17	nn
# 20	the	DT	21	det
# 12	information	NN	14	nsubj
# 13	``	``	14	punct
# 30	any	DT	31	det
# 33	wanted	VBD	31	rcmod
# 26	the	DT	27	det
# 2	the	DT	3	det
# 4	the	DT	5	det
# 4	an	DT	6	det
# 5	interesting	JJ	6	amod
# 1	The	DT	2	det
# 21	the	DT	23	det
# 22	entire	JJ	23	amod
# 1	The	DT	2	det
# 6	the	DT	7	det
# 11	a	DT	12	det
# 6	the	DT	7	det
# 8	of	IN	7	prep
# 36	a	DT	38	det
# 37	great	JJ	38	amod
# 2	the	DT	3	det
# 9	a	DT	10	det
# 11	about	IN	10	prep
# 9	good	JJ	10	amod
# 9	any	DT	11	det
# 10	real	JJ	11	amod
# 5	a	DT	7	det
# 6	sensible	JJ	7	amod
# 3	a	DT	6	det
# 4	hardcore	JJR	6	amod
# 5	spy	NN	6	nn
# 22	the	DT	23	det
# 24	for	IN	23	prep
# 11	Doom	NNP	13	poss
# 15	destroy	VB	13	infmod
# 14	the	DT	15	det
# 9	the	DT	10	det
# 12	the	DT	13	det
# 34	the	DT	35	det
# 10	film	NN	12	poss
# 6	the	DT	7	det
# 10	thickens	VBZ	7	dep
# 11	the	DT	13	det
# 12	same	JJ	13	amod
# 2	movie	NN	4	poss
# 5	Palma	NNP	15	poss
# 7	`	``	15	punct
# 9	Fatale	NNP	15	nsubj
# 11	has	VBZ	15	aux
# 12	a	DT	15	det
# 14	tricky	JJ	15	amod
# 46	the	DT	47	det
# 21	a	DT	23	det
# 22	great	JJ	23	amod
# 24	and	CC	23	cc
# 26	acting	NN	23	conj
# 27	rather	RB	23	cc
# 29	tons	NNS	23	conj
# 21	no	DT	22	det
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 5	acting	JJ	2	conj
# 3	it	PRP	6	nsubj
# 4	is	VBZ	6	cop
# 5	the	DT	6	det
# 7	and	CC	6	cc
# 9	way	NN	6	conj
# 1	The	DT	2	det
# 3	,	,	2	punct
# 5	setting	NN	2	appos
# 6	,	,	2	punct
# 8	dialogues	NNS	2	appos
# 9	,	,	2	punct
# 12	effects	NNS	2	appos
# 13	,	,	2	punct
# 14	and	CC	2	cc
# 16	music	NN	2	conj
# 12	not	RB	16	neg
# 13	a	DT	16	det
# 14	strong	JJ	16	amod
# 15	enough	RB	16	advmod
# 18	rescue	VB	16	xcomp
# 5	of	IN	4	prep
# 8	the	DT	9	det
# 6	The	DT	7	det
# 7	an	DT	10	det
# 8	interesting	JJ	10	amod
# 9	enough	JJ	10	amod
# 13	as	IN	10	prep
# 1	The	DT	2	det
# 14	the	DT	15	det
# 1	The	DT	2	det
# 13	the	DT	14	det
# 3	the	DT	4	det
# 1	The	DT	3	det
# 2	entire	JJ	3	amod
# 4	and	CC	3	cc
# 5	suspense	NN	3	conj
# 9	the	DT	10	det
# 2	the	DT	3	det
# 8	meanders	NNS	13	nsubj
# 12	to	TO	13	aux
# 14	line	NN	13	dobj
# 18	the	DT	19	det
# 11	the	DT	12	det
# 1	This	DT	6	nsubj
# 2	is	VBZ	6	cop
# 3	basically	RB	6	advmod
# 4	the	DT	6	det
# 5	main	JJ	6	amod
# 7	of	IN	6	prep
# 10	,	,	6	punct
# 11	but	CC	6	cc
# 17	are	VBP	6	conj
# 25	.	.	6	punct
# 10	a	DT	15	det
# 12	good	JJ	15	amod
# 13	,	,	15	punct
# 14	detailed	JJ	15	amod
# 1	The	DT	2	det
# 19	a	DT	21	det
# 20	silly	RB	21	advmod
# 22	,	,	21	punct
# 25	imagery	NN	21	appos
# 26	(	:	21	punct
# 29	Judas	NNP	21	dep
# 33	)	:	21	punct
# 34	,	,	21	punct
# 35	and	CC	21	cc
# 36	not	RB	21	conj
# 42	moment	NN	21	dep
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 1	Wonderful	NNP	2	nsubj
# 3	.	.	2	punct
# 1	The	DT	2	det
# 1	And	CC	3	cc
# 2	the	DT	3	det
# 4	?	.	3	punct
# 15	the	DT	17	det
# 16	overall	JJ	17	amod
# 1	The	DT	2	det
# 34	the	DT	35	det
# 18	the	DT	19	det
# 2	The	DT	3	det
# 2	film	NN	10	nsubj
# 3	,	,	10	punct
# 6	said	VBD	10	dep
# 7	,	,	10	punct
# 8	is	VBZ	10	cop
# 9	less	JJR	10	amod
# 15	driven	RB	10	advmod
# 16	.	.	10	punct
# 1	The	DT	2	det
# 34	its	PRP$	37	poss
# 36	assassination	NN	37	nn
# 38	against	IN	37	prep
# 11	the	DT	12	det
# 28	the	DT	29	det
# 3	no	DT	4	det
# 6	speak	VB	4	infmod
# 2	comedy	NN	6	nsubj
# 3	is	VBZ	6	cop
# 4	the	DT	6	det
# 5	Cliff	NNP	6	nn
# 7	.	.	6	punct
# 1	The	DT	2	det
# 1	The	DT	2	det
# 32	end	NN	33	nn
# 5	the	DT	7	det
# 6	basic	JJ	7	amod
# 8	and	CC	7	cc
# 9	characters	NNS	7	conj
# 4	the	DT	5	det
# 12	the	DT	13	det
# 1	The	DT	2	det
# 8	THE	DT	13	det
# 11	The	NNP	13	nn
# 12	basic	JJ	13	amod
# 14	of	IN	13	prep
# 37	their	PRP$	38	poss
# 2	the	DT	3	det
# 15	the	DT	16	det
# 12	the	DT	13	det
# 14	and	CC	13	cc
# 15	characters	NNS	13	conj
# 7	the	DT	8	det
# 9	surrounding	VBG	8	partmod
# 19	a	DT	20	det
# 13	the	DT	14	det
# 1	``	``	8	punct
# 4	part	NN	8	nsubj
# 5	is	VBZ	8	cop
# 6	the	DT	8	det
# 7	Judah	NNP	8	nn
# 9	.	.	8	punct
# 2	obviously	RB	6	advmod
# 3	this	DT	6	nsubj
# 4	is	VBZ	6	cop
# 5	same	JJ	6	amod
# 7	used	VBN	6	partmod
# 29	,	,	31	punct
# 30	and	CC	31	cc
# 32	twists	NNS	31	conj
# 33	on	IN	31	prep
# 1	The	DT	2	det
# 1	Its	PRP$	2	poss
# 6	a	DT	8	det
# 7	PKD	NNP	8	nn
# 9	``	``	10	punct
# 11	``	``	10	punct
# 15	film	NN	10	conj
# 18	teenage	VBP	10	rcmod
# 16	a	DT	18	det
# 17	good	JJ	18	amod
# 7	the	DT	8	det
# 19	an	DT	24	det
# 21	clean	JJ	24	amod
# 43	the	DT	44	det
# 1	Excellent	NNP	2	nsubj
# 3	,	,	2	punct
# 4	action	NN	2	dobj
# 5	,	,	2	punct
# 8	cinematography	NN	2	dobj
# 11	.	.	2	punct
# 7	the	DT	8	det
# 1	The	DT	2	det
# 4	the	DT	7	det
# 6	suspenseful	JJ	7	amod
# 8	full	JJ	7	amod
# 18	complicated	JJ	19	amod
# 15	the	DT	16	det
# 10	about	IN	12	amod
# 11	the	DT	12	det
# 9	The	DT	10	det
# 6	the	DT	8	det
# 7	``	``	8	punct
# 9	``	``	8	punct
# 10	of	IN	8	prep
# 1	The	DT	2	det
# 3	and	CC	2	cc
# 5	acting	JJ	2	conj
# 22	the	DT	23	det
# 1	The	DT	2	det
# 3	the	DT	5	det
# 4	subtle	NN	5	nn
# 6	with	IN	5	prep
# 23	fun	NN	24	nn
# 3	the	DT	4	det
# 14	the	DT	18	det
# 15	stupid	JJ	18	amod
# 19	of	IN	18	prep
# 26	the	DT	27	det
# 3	the	DT	4	det
# 5	of	IN	4	prep
# 1	The	DT	2	det
# 24	a	DT	26	det
# 25	great	JJ	26	amod
# 22	Planes	NNP	24	poss
# 8	this	DT	9	det
# 5	the	DT	6	det
# 7	of	IN	6	prep
# 1	The	DT	2	det
# 17	the	DT	18	det
# 14	the	DT	15	det
# 2	the	DT	3	det
# 1	The	DT	2	det
# 11	the	DT	12	det
# 15	cycle	NN	12	dep
# 17	the	DT	18	det
# 19	of	IN	18	prep
# 1	The	DT	2	det
# 10	the	DT	11	det
# 28	,	,	27	punct
# 29	characterization	NN	27	conj
# 30	,	,	27	punct
# 31	pacing	VBG	27	amod
# 32	,	,	27	punct
# 33	and	CC	27	cc
# 35	like	NN	27	conj
# 11	the	DT	12	det
# 20	comprehensible	JJ	21	amod
# 1	the	DT	2	det
# 16	the	DT	17	det
# 15	a	DT	17	det
# 16	brilliant	JJ	17	amod
# 13	crazy	NN	14	nn
# 5	a	DT	6	det
# 7	or	CC	6	cc
# 8	story	NN	6	conj
# 1	The	DT	2	det
# 1	The	DT	2	det
# 5	no	DT	6	det
# 29	the	DT	30	det
# 13	the	DT	15	det
# 14	simplest	JJS	15	amod
# 16	of	IN	15	prep
# 23	no	DT	24	det
# 25	at	IN	24	prep
# 1	Exactly	RB	6	advmod
# 2	what	WP	6	nsubj
# 3	is	VBZ	6	cop
# 4	the	DT	6	det
# 5	``	``	6	punct
# 7	``	``	6	punct
# 8	?	.	6	punct
# 22	a	DT	23	det
# 25	delay	VB	23	infmod
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 12	the	DT	13	det
# 14	itself	PRP	13	dep
# 16	goofy	NN	17	nn
# 2	its	PRP$	5	poss
# 3	your	PRP$	5	poss
# 4	typical	JJ	5	amod
# 6	:	:	5	punct
# 8	honor	NN	5	dep
# 9	,	,	5	punct
# 10	protect	NN	5	appos
# 13	,	,	5	punct
# 17	the	DT	18	det
# 17	the	DT	19	det
# 18	overall	JJ	19	amod
# 25	his	PRP$	27	poss
# 26	evil	JJ	27	amod
# 16	the	DT	17	det
# 11	extremley	NN	13	nn
# 12	funny	NN	13	nn
# 11	a	DT	12	det
# 14	a	DT	16	det
# 15	new	JJ	16	amod
# 21	the	DT	22	det
# 1	The	DT	2	det
# 2	the	DT	3	det
# 3	the	DT	4	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 3	a	DT	6	det
# 5	unbelievable	JJ	6	amod
# 11	an	DT	13	det
# 12	escape	NN	13	nn
# 4	contradictory	NN	5	nn
# 8	a	DT	9	det
# 9	it	PRP	15	nsubj
# 10	's	VBZ	15	cop
# 11	not	RB	15	neg
# 13	much	RB	15	amod
# 14	the	DT	15	det
# 20	performances	NNS	15	dep
# 14	the	DT	15	det
# 49	wealthy	JJ	51	amod
# 50	teenagers	NNS	51	nn
# 53	other	JJ	51	amod
# 54	's	POS	51	possessive
# 55	downfalls	NNS	51	punct
# 18	a	DT	19	det
# 20	with	IN	19	prep
# 1	Great	NNP	2	nsubj
# 3	,	,	2	punct
# 4	had	VBD	2	conj
# 11	.	.	2	punct
# 11	the	DT	12	det
# 1	The	DT	2	det
# 3	of	IN	2	prep
# 7	no	DT	8	det
# 27	a	DT	28	det
# 3	an	DT	5	det
# 4	excellent	NN	5	nn
# 3	the	DT	4	det
# 23	the	DT	25	det
# 24	average	NN	25	nn
# 1	The	DT	2	det
# 4	it	PRP	11	nsubj
# 5	's	VBZ	11	cop
# 6	not	RB	11	neg
# 7	exactly	RB	11	advmod
# 8	the	DT	11	det
# 10	cliche-free	JJ	11	amod
# 12	as	IN	11	prep
# 14	an	DT	16	det
# 15	interesting	JJ	16	amod
# 14	the	DT	15	det
# 1	The	DT	2	det
# 15	the	DT	17	det
# 16	usual	JJ	17	amod
# 4	the	DT	5	det
# 6	of	IN	5	prep
# 4	the	DT	5	det
# 6	and	CC	5	cc
# 7	actors	NNS	5	conj
# 21	uninspired	VBN	22	amod
# 1	The	DT	2	det
# 21	terrorists	NNS	22	nn
# 1	The	DT	4	det
# 2	additional	JJ	4	amod
# 3	side	NN	4	nn
# 5	of	IN	4	prep
# 7	between	IN	4	prep
# 13	coachs	VBZ	4	rcmod
# 15	a	DT	17	det
# 16	consistent	NN	17	nn
# 19	the	DT	20	det
# 23	outlined	VBD	20	rcmod
# 36	the	DT	37	det
# 38	at	IN	37	prep
# 14	a	DT	15	det
# 16	brewing	VBG	15	partmod
# 11	the	DT	12	det
# 1	The	DT	2	det
# 24	script	NN	26	amod
# 1	The	DT	2	det
# 17	its	PRP$	21	poss
# 18	tedious	JJ	21	amod
# 1	The	DT	2	det
# 3	the	DT	6	det
# 4	little	JJ	6	amod
# 5	secondary	JJ	6	amod
# 7	of	IN	6	prep
# 7	the	DT	8	det
# 4	the	DT	5	det
# 6	's	POS	5	possessive
# 14	a	DT	15	det
# 4	a	DT	5	det
# 6	,	,	5	punct
# 8	writing	NN	5	conj
# 9	and	CC	5	cc
# 12	values	NNS	5	conj
# 11	or	CC	10	cc
# 12	ending	VBG	10	conj
# 18	the	DT	19	det
# 6	end	NN	7	nn
# 4	good	JJ	5	amod
# 6	,	,	5	punct
# 8	acting	NN	5	conj
# 9	and	CC	5	cc
# 12	stars	NNS	5	conj
# 22	the	DT	23	det
# 7	company	NN	8	nn
# 1	The	DT	2	det
# 3	the	DT	4	det
# 1	The	DT	2	det
# 1	The	DT	2	det
# 16	an	DT	18	det
# 17	awesome	NN	18	nn
# 7	the	DT	8	det
# 15	the	DT	17	det
# 16	sub	NN	17	nn
# 18	here	RB	17	advmod
# 19	,	,	17	punct
# 20	or	CC	17	cc
# 21	in	IN	17	conj
# 27	the	DT	29	det
# 28	actual	JJ	29	amod
# 22	the	DT	23	det
# 19	the	DT	20	det
# 9	a	DT	10	det
# 11	for	IN	10	prep
# 8	this	DT	10	det
# 9	single	JJ	10	amod
# 1	The	DT	2	det
# 11	a	DT	14	det
# 13	developed	VBN	14	amod
# 15	,	,	14	punct
# 17	characters	NNS	14	appos
# 18	,	,	14	punct
# 20	scenery	NN	14	appos
# 21	,	,	14	punct
# 23	music	NN	14	conj
# 5	a	DT	6	det
# 7	and	CC	6	cc
# 8	predict	NN	6	conj
# 22	innocent	JJ	6	dep
# 17	grisly	RB	18	advmod
# 16	a	DT	18	det
# 17	busy	JJ	18	amod
# 19	and	CC	18	cc
# 21	story	NN	18	conj
# 22	,	,	18	punct
# 24	unrealistic	JJ	18	conj
# 1	The	DT	2	det
# 3	itself	PRP	2	dep
# 7	one	CD	9	num
# 8	main	JJ	9	amod
# 9	the	DT	10	det
# 12	the	DT	13	det

# %% [markdown]
# ## Opinion extractor

# %% [markdown]
# Over the next two weeks you will be creating your own opinion extractor. In the code snippet below you will find a simple one to get you started.

# %% [markdown]
# <div style="background-color: #F0FFFF;border:1px solid #DCDCDC;padding: 5px;"><b>Function</b>: <code style="background-color: #F5F5F5;">opinion_extractor</code>
# <dl>
# <dt>Arguments</dt>
# <dd><code style="background-color: #F5F5F5;">aspect_token</code> is the <code style="background-color: #F5F5F5;">BasicToken</code> instance (for our aspect token) from the <code style="background-color: #F5F5F5;">ParsedSentence</code> that we're interested in.</dd>
# <dd><code style="background-color: #F5F5F5;">parsed_sentence</code> is the <code style="background-color: #F5F5F5;">ParsedSentence</code> instance containing the dependency tree information of our sentence of interest.</dd>
# <dt>Returns</dt>
# <dd>A list of the extracted opinions. <code style="background-color: #F5F5F5;">opinion_extractor</code> should always return a list (even if it's empty).</dd>
# </dl></div>

# %%
def opinion_extractor(aspect_token, parsed_sentence):
    
    # Your function will have 3 steps:
    
    # i. Initialise a list of opinions
    opinions = []
    
    # ii. Find opinions (as an example we get all the dependants of the aspect token that have the relation "det")
    opinions += [dependant.form for dependant in parsed_sentence.get_dependants(aspect_token) if dependant.deprel == "det"]
    # You can continue to add to "opinions". Remember you can get the head of a token, and filter by PoS tag or Deprel too!
    
    # iii. Return the (possibly empty) list of opinions
    return opinions

# %% [markdown]
# In the sections below, we will be describing a variety of ways in which you are asked to refine the simple <code style="background-color: #F5F5F5;">opinion_extractor</code> function shown above. When you are investigating how well the <code style="background-color: #F5F5F5;">opinion_extractor</code> you have built are working, you will want to view your opinion extractor's output for a substantial number of sentences. It would be wise to print your output to a file. You are shown how to do this below.
#
# Note that you will need to replace <code style="background-color: #F5F5F5;">"/path/to/file.txt"</code> with a suitable path.

# %%
from sussex_nltk.parse import load_parsed_dvd_sentences, load_parsed_example_sentences

aspect = "plot"   # Set this to the aspect token you're interested in
save_file_path = "output.txt"    # Set this to the location of the file you wish to create/overwrite with the saved output.

# Tracking these numbers will allow us to see what proportion of sentences we discovered features in
sentences_with_discovered_features = 0  # Number of sentences we discovered features in
total_sentences = 0  # Total number of sentences 

# This is a "with statement", it invokes a context manager, which handles the opening and closing of resources (like files)
with open(save_file_path, "w") as save_file:  # The 'w' says that we want to write to the file
    
    # Iterate over all the parsed sentences
    for parsed_sentence in load_parsed_dvd_sentences(aspect):   
        
        total_sentences += 1  # We've seen another sentence
        
        opinions = [] # Make a list for holding any opinions we extract in this sentence

        # Iterate over each of the aspect tokens in the sentences (in case there is more than one)
        for aspect_token in parsed_sentence.get_query_tokens(aspect):
            
            # Call your opinion extractor
            opinions += opinion_extractor(aspect_token, parsed_sentence)
        
        # If we found any opinions, write to the output file what we know.
        if opinions: 
            # Currently, the sentence will only be printed if opinions were found. But if you want to know what you're missing,
            # you could move the sentence printing outside the if-statement
            
            # Print a separator and the raw unparsed sentence
            save_file.write("--- Sentence: %s ---\n" % parsed_sentence.raw())  # "\n" starts a new line
            # Print the parsed sentence
            save_file.write("%s\n" % parsed_sentence) 
            # Print opinions extracted
            save_file.write("Opinions: %s\n" % opinions)
            
            sentences_with_discovered_features += 1  # We've found features in another sentence
            
print "%s sentences out of %s contained features" % (sentences_with_discovered_features, total_sentences)
# Out:
# 2057 sentences out of 3119 contained features

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Using the basic opinion extractor we provide and the above code for storing opinion words in files, find the opinion words for each of the aspect tokens under consideration.</li>
# </ul>
# </div>

# %% [markdown]
# ## Adapting the opinion extractor

# %% [markdown]
# In the sections below we will be asking you to adapt the opinion extractor in various ways. First, however, we give you examples of python code that will help you devise your adapted opinion extractor. You should refer to these examples when you are working on your own opinion extractors.
#
# The <code style="background-color: #F5F5F5;">BasicToken</code> object has a number of useful properties, include the following:
#
# - <code style="background-color: #F5F5F5;">form</code>: the actual form of the token, e.g. "plot"
# - <code style="background-color: #F5F5F5;">pos</code>: the part-of-speech of the token, e.g. "JJ" for adjective
# - <code style="background-color: #F5F5F5;">deprel</code>: the dependency relation that the <code style="background-color: #F5F5F5;">BasicToken</code> has with its head, e.g. "det" for determiner"
#
# As the code snippet shown below illustrates, we can do different things depending on these properties.

# %%
# Say for example we acquire a list of BasicToken objects by getting all the dependants of a token:
dependants = parsed_sentence.get_dependants(aspect_token)

# We could filter that list, keeping only those tokens whose dependency relations with the aspect token are "dobj", by doing the following:
dependants = [token for token in dependants if token.deprel == "dobj"] 

# Or we could filter that list, keeping only those tokens whose PoS tags are "RB" (for adverb)
dependants = [token for token in dependants if token.pos == "RB"]

# Or we could filter that list, keeping only those tokens whose form is NOT "main" or "special"
dependants = [token for token in dependants if token.form != "main" and token.form != "special"]

# Or if we had a single token, we could choose to add it to a list or not based on its properties
opinions = []
if token.pos.startswith("JJ"):  # If token is an adjective, then append its form to our list of opinions
    opinions.append(token.form)
    
# Or we could search tokens for a property we wish to know is present
found_det = False
for dependant in dependants:
    if dependant.deprel == "det":
        found_det = True
# Now subsequent code can use "found_det" to perform different tasks depending on
# whether or not there was a determiner relation in the dependants.

# %% [markdown]
# ## Extending the opinion extractor's functionality

# %% [markdown]
# For the assessed coursework you are asked to develop and assess several extensions to the opinion extractor given above. For full details of what is required for the coursework see the coursework specification document.
#
# All of the extensions below can be completed by adapting the examples shown in the previous sections. Look out for situations where you need to find the dependants or heads of tokens, or when you need to check the PoS or dependency type of a token.
#
# You will benefit greatly from reading the section Tips for de-bugging and exploration (see below). Note that this section describes how to use a tool for visualising dependency trees.

# %% [markdown]
# ### Examples Test Set

# %% [markdown]
# In order to check that the opinion extractor you are developing is correctly defined, we have provided easy access to all of the example sentences used in this document. This will be referred to as the examples test set. All of the sentences in the test data have been parsed.
#
# In order to access the examples test set you should do the following:
#
# - replace <code style="background-color: #F5F5F5;">load_parsed_dvd_sentences(aspect)</code> with <code style="background-color: #F5F5F5;">load_parsed_example_sentences()</code>, and
# - ensure that you're importing <code style="background-color: #F5F5F5;">load_parsed_example_sentences</code> from <code style="background-color: #F5F5F5;">sussex_nltk.parse</code>

# %%
from sussex_nltk.parse import load_parsed_example_sentences

parsed_example_sentences = load_parsed_example_sentences()
 
# To inspect the sentences, you could print them straight out
for parsed_sentence in parsed_example_sentences:
    print "--- Sentence ---"
    print parsed_sentence
# Out:
# --- Sentence ---
# 1	It	PRP	2	nsubj
# 2	has	VBZ	0	root
# 3	an	DT	6	det
# 4	exciting	JJ	6	amod
# 5	fresh	JJ	6	amod
# 6	plot	NN	2	dobj
# 7	.	.	2	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	4	nsubj
# 3	was	VBD	4	cop
# 4	dull	JJ	0	root
# 5	.	.	4	punct
# --- Sentence ---
# 1	It	PRP	2	nsubj
# 2	has	VBZ	0	root
# 3	an	DT	6	det
# 4	excessively	RB	5	advmod
# 5	dull	JJ	6	amod
# 6	plot	NN	2	dobj
# 7	.	.	2	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	5	nsubj
# 3	was	VBD	5	cop
# 4	excessively	RB	5	advmod
# 5	dull	JJ	0	root
# 6	.	.	5	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	5	nsubj
# 3	was	VBD	5	cop
# 4	n't	RB	5	neg
# 5	dull	JJ	0	root
# 6	.	.	5	punct
# --- Sentence ---
# 1	It	PRP	7	nsubj
# 2	was	VBD	7	cop
# 3	n't	RB	7	neg
# 4	an	DT	7	det
# 5	exciting	JJ	7	amod
# 6	fresh	JJ	7	amod
# 7	plot	NN	0	root
# 8	.	.	7	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	6	nsubj
# 3	was	VBD	6	cop
# 4	n't	RB	6	neg
# 5	excessively	RB	6	advmod
# 6	dull	JJ	0	root
# 7	.	.	6	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	4	nsubj
# 3	was	VBD	4	cop
# 4	cheesy	JJ	0	root
# 5	,	,	4	punct
# 6	but	CC	4	cc
# 7	fun	NN	4	conj
# 8	and	CC	4	cc
# 9	inspiring	VBG	4	conj
# 10	.	.	4	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	5	nsubj
# 3	was	VBD	5	cop
# 4	really	RB	5	advmod
# 5	cheesy	JJ	0	root
# 6	and	CC	5	cc
# 7	not	RB	9	neg
# 8	particularly	RB	9	advmod
# 9	special	JJ	5	conj
# 10	.	.	5	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	script	NN	7	nsubj
# 3	and	CC	2	cc
# 4	plot	NN	2	conj
# 5	are	VBP	7	cop
# 6	utterly	RB	7	advmod
# 7	excellent	JJ	0	root
# 8	.	.	7	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	script	NN	6	nsubj
# 3	and	CC	2	cc
# 4	plot	NN	2	conj
# 5	were	VBD	6	cop
# 6	unoriginal	JJ	0	root
# 7	and	CC	6	cc
# 8	boring	VBG	6	conj
# 9	.	.	6	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	5	nsubj
# 3	was	VBD	5	aux
# 4	n't	RB	5	neg
# 5	lacking	VBG	0	root
# 6	.	.	5	punct
# --- Sentence ---
# 1	The	DT	2	det
# 2	plot	NN	4	nsubj
# 3	is	VBZ	4	cop
# 4	full	JJ	0	root
# 5	of	IN	4	prep
# 6	holes	NNS	5	pobj
# 7	.	.	4	punct
# --- Sentence ---
# 1	There	EX	2	expl
# 2	was	VBD	0	root
# 3	no	DT	5	det
# 4	logical	JJ	5	amod
# 5	plot	NN	2	nsubj
# 6	to	TO	5	prep
# 7	this	DT	8	det
# 8	story	NN	6	pobj
# 9	.	.	2	punct
# --- Sentence ---
# 1	I	PRP	2	nsubj
# 2	loved	VBD	0	root
# 3	the	DT	4	det
# 4	plot	NN	2	dobj
# 5	.	.	2	punct
# --- Sentence ---
# 1	I	PRP	4	nsubj
# 2	did	VBD	4	aux
# 3	n't	RB	4	neg
# 4	mind	VB	0	root
# 5	the	DT	6	det
# 6	plot	NN	4	dobj
# 7	.	.	4	punct

# %% [markdown]
# Note that in your coursework you should discuss the effectiveness of your opinion extractor on the full set of parsed DVD reviews.

# %% [markdown]
# ### Extension 1: Adjectival modification

# %% [markdown]
# In this section, we are interested in adjectival modification. This is when we have a noun like "dog" or "plot", and there are one or more adjectives which are specifying the characteristics of that noun. E.g. "big brown dog" or "exciting fresh plot" ("big" and "brown" are both adjectivally modifying "dog").
#
# The dependency relation we use to show this relationship is "amod".
#
# Write a version of the opinion extraction function which, when given sentences such as the example below containing an aspects token (e.g. "plot"), uses the "amod" relations to extract a list of the adjectival modifiers of the aspect token (e.g. the two words "exciting" and "fresh" in this case).
#
# - "It has an exciting fresh plot." produces "fresh", "exciting"

# %% [markdown]
# ![Extension 1 example](./img/amod_example.png)

# %% [markdown]
# <div style="background-color: #FFDEAD;border:1px solid #DCDCDC;padding: 5px;">
# NOTE
# You may notice that certain aspect tokens are often described by non-opinion words. For example the phrase "main plot" is often used; "main" adjectivally modifies "plot", so your opinion extractor will find "main" as an opinion. In the code snippets above we show you how to filter tokens based on their form; you could filter out specific words like "main".
# </div>

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.</li>
# <li>Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "plot", "characters", "cinematography", and "dialogue".</li>
# </ul>
# </div>

# %% [markdown]
# ### Extension 2: Adjectives linked by copulae

# %% [markdown]
# In this section, we are interested in adjectives (PoS tag "JJ") which are linked to our aspect term via the copula (conjugations of "to be": "is", "was", "will be" etc.). Notice that if we were only looking for "amod" relations, we'd completely miss the word "dull" in the diagram below.
#
# Notice that when linked via a copula to an adjective, the noun is always in an "nsubj" relation with the adjective itself.
#
# Your opinion extraction function when given a sentences like the example below containing the aspect token "plot", should use appropriate dependency relations to output the term opinion word "dull".
#
# - "The plot was dull." produces "dull"

# %% [markdown]
# ![Extension 2 example](./img/copula_example.png)

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.</li>
# <li>Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "plot", "characters", "cinematography", and "dialogue".</li>
# </ul>
# </div>

# %% [markdown]
# ### Extension 3: Adverbial modifiers

# %% [markdown]
# If you used the extractor you have built so far on the example sentences below, it will only find the opinion "dull". It would not recover an indication of the strength of the opinion. Adverbs like "excessively" elaborate on the adjectives that they modify in adverbial modification relations.
#
# The relevant dependency relation we use to show this relationship is "advmod".
#
# Your opinion extraction function when given a sentence like those below containing the aspect token "plot", should use the advmod relation to output features like "excessively-dull" (if you have an adjective token in a variable <code style="background-color: #F5F5F5;">adj_token</code>, and an adverb in a variable <code style="background-color: #F5F5F5;">adv_token</code> then you could create this feature like this: <code style="background-color: #F5F5F5;">adv_token.form + "-" + adj_token.form</code>).
#
# - "It has an excessively dull plot." produces "excessively-dull"
# - "The plot was excessively dull." produces "excessively-dull"

# %% [markdown]
# ![Extension 3 example](./img/advmod_example.png)

# %% [markdown]
# <div style="background-color: #FFDEAD;border:1px solid #DCDCDC;padding: 5px;">
# NOTE
# If you have a list of strings, you can use python's <code style="background-color: #F5F5F5;">join</code> function to concatenate them into a single string. The following would join the strings together, placing a <code style="background-color: #F5F5F5;">"-"</code> between each:
# <code style="background-color: #F5F5F5;">joined_string = "-".join(listofstrings)</code>
# </div>

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.</li>
# <li>Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "plot", "characters", "cinematography", and "dialogue".</li>
# </ul>
# </div>

# %% [markdown]
# ### Extension 4: Negation

# %% [markdown]
# Look at the tree below; it is an example of an adjective linked by a copula. Your existing opinion extractor would extract "dull". However, notice that the example is saying that the plot was not dull! This is an example of the use of negation.
#
# The dependency relation we use to show this relationship is "neg".
#
# Your opinion extraction function when given sentences like those below containing the aspect token "plot", should use the "neg" relation to output features like "not-dull". If you have an adjective token called "token", then you could create this feature like this: <code style="background-color: #F5F5F5;">"not-" + token.form</code>.
#
# - "The plot wasn't dull." produces "not-dull"
# - "It wasn't an exciting fresh plot." produces "not-exciting", "not-fresh"
# - "The plot wasn't excessively dull." produces "not-excessively-dull"

# %% [markdown]
# ![Extension 4 example](./img/negation_example.png)

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.</li>
# <li>Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "plot", "characters", "cinematography", and "dialogue".</li>
# </ul>
# </div>

# %% [markdown]
# ### Extension 5: Conjunction

# %% [markdown]
# If you used your existing extractor on the tree below, it would only extract "cheesy". However, "fun" and "inspiring" are both conjoined with "cheesy"; this means that they all apply to the subject ("plot").
#
# This conjunction relation is shown via the "conj" dependency. Note that words other than adjectives can be the conjuncts. You could investigate whether this is a problem.
#
# Your opinion extraction function when given sentences like these containing the aspect token "plot" should uses the "conj" relation to extract all of the relevant features "cheesy, fun, inspiring".
#
# - "The plot was cheesy, but fun and inspiring." produces "cheesy", "fun", "inspiring"
# - "The plot was really cheesy and not particularly special." produces "really-cheesy", "not-particularly-special"

# %% [markdown]
# ![Extension 5 example](./img/conj_example.png)

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.</li>
# <li>Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "plot", "characters", "cinematography", and "dialogue".</li>
# </ul>
# </div>

# %% [markdown]
# ### Additional extensions

# %% [markdown]
# This section presents some examples on which your current opinion extractor will fail. In all of the examples below, "plot" is the aspect token.
#
# - "The script and plot are utterly excellent." produces "utterly-excellent"
# - "The script and plot were unoriginal and boring." produces "unoriginal", "boring"
# - "The plot wasn't lacking." produces "not-lacking"
# - "The plot is full of holes." produces "full-of-holes"
# - "There was no logical plot to this story." produces "no-logical"
# - "I loved the plot." produces "loved"
# - "I didn't mind the plot." produces "not-mind"

# %% [markdown]
# <div style="background-color: #FAFAD2;color:#8B0000;border:1px solid #DCDCDC;padding: 5px;">
# <h3>Things for you to do</h3>
# <ul>
# <li>Extend your extractor so that its output matches the expected output. Ensure that you make use of the dependencies relating the aspect token to the rest of the sentence. For example, do not just retrieve all of the adjectives in the sentence since this does not generalise well to more complex sentences.</li>
# </ul>
# </div>

# %% [markdown]
# ## Tips for de-bugging and exploration

# %% [markdown]
# ### Common sense

# %% [markdown]
# When you will be assessing whether your opinion extractor has been effective when analysing a given sentence. Before you look at what the dependency parser says, read the sentence carefully and determine for yourself the scope of the words. Consider the following sentence.
#
# "This film has excellent characters and an intriguing and engaging plot."
#
# It should be obvious to you that here the plot is described as both "intriguing" and "engaging". However, "excellent" is only used to describe the cinematography.
#
# If the parser suggests a structure which implies that plot is also described by "excellent" (for example), something has gone wrong.

# %% [markdown]
# ### Dependency tree visualisation tool

# %% [markdown]
# On the teaching drive under <code style="background-color: #F5F5F5;">Departments/Informatics/LanguageEngineering/</code>, there is a file called <code style="background-color: #F5F5F5;">"RunParserInLab4.bat"</code>. Double-click this file in Lab4 and it will run an interactive dependency parser.
#
# It performs two tasks, only one of which is relevant to you: in the pane labelled "Plain" you can copy-paste any <code style="background-color: #F5F5F5;">ParsedSentence</code> print-out (the token-per-line format), then press SHIFT+ENTER, and the dependency tree will be visualised.
#
# This may help you to understand the trees.
#
# You should probably avoid the text field at the bottom of the application. It uses a slightly different parser than the one in Sussex NLTK, so their answers will sometimes differ.
#
# If you would like to use the tool at home, you should instead use a copy of the <code style="background-color: #F5F5F5;">InteractiveParser.jar</code> file from the same directory. Ensure that your home computer uses Java 7 at the terminal by default. Then at the command prompt type:
#
# <code style="background-color: #F5F5F5;">java -Xmx2g -jar /path/to/InteractiveParser.jar</code>
#
# For reference, the following are links to the documents describing the [dependency relations](http://nlp.stanford.edu/downloads/dependencies_manual.pdf) and [parts-of-speech tags](http://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html) we are using.

# %% [markdown]
# ### Printing only documents relevant to the current task

# %% [markdown]
# You will find that your output is dominated by examples of adjectival modification and adjectives linked via the copula. This means that when you add a new function (extensions 3-5) it will be difficult to determine the impact of that new functionality.
#
# One way to solve this problem, is to (temporarily) output only those features produced by the new functionality.
#
# For example, imagine you have just completed extensions 1 and 2. Next, you write code that adds the adverbial features (extension 3). When assessing how well your code is working, let your extractor only extract the "new" adverb features.
#
# There are 2 easy ways to achieve this:
#
# 1. Comment out any extractor code that produces features that you're not currently interested in. Or
# 2. Introduce a boolean variable, which you only set to <code style="background-color: #F5F5F5;">True</code> when you have extracted the feature that you are interested in. Then always ouput an empty list if the variable is <code style="background-color: #F5F5F5;">False</code>, otherwise output the full opinion list.

# %% [markdown]
# ### Running the parser on your own example sentences (Beware, this can take ~40secs!)

# %% [markdown]
# If you want to test an idea out and have the parser attempt to parse one of your own examples. Take a look at the code below.

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from sussex_nltk.parse import dep_parse_sentences_arceager

sentences = ["This is the first example sentence",
             "This is the second example sentence",
             "This is the third example sentence"]

parsed_sents = dep_parse_sentences_arceager(pos_tag(word_tokenize(sentence)) for sentence in sentences)

for parsed_sentence in parsed_sents:
    print "--- Sentence ---"
    print parsed_sentence
